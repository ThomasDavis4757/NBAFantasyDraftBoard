# %%
import requests
from bs4 import BeautifulSoup
from IPython.core.display import HTML
import pandas as pd
import io
import numpy as np
import time
from fuzzywuzzy import fuzz, process
from unidecode import unidecode
from tqdm import tqdm

# %%
import requests
import pandas as pd

draft_id = '1223814632272052225'
url = f'https://api.sleeper.app/v1/draft/{draft_id}/picks'

response = requests.get(url, headers={'Cache-Control': 'no-cache'})
data = response.json()

df = pd.DataFrame(data)
df
# Out:
#                 draft_id  draft_slot is_keeper  \
# 0    1223808713538674688           1      None
# 1    1223808713538674688           2      None
# 2    1223808713538674688           3      None
# 3    1223808713538674688           4      None
# 4    1223808713538674688           5      None
# ..                   ...         ...       ...
# 115  1223808713538674688           4      None
# 116  1223808713538674688           5      None
# 117  1223808713538674688           6      None
# 118  1223808713538674688           7      None
# 119  1223808713538674688           8      None
#
#                                               metadata  pick_no  \
# 0    {'first_name': 'Nikola', 'injury_status': '', ...        1
# 1    {'first_name': 'Luka', 'injury_status': '', 'l...        2
# 2    {'first_name': 'Joel', 'injury_status': 'Out',...        3
# 3    {'first_name': 'Victor', 'injury_status': 'Out...        4
# 4    {'first_name': 'Giannis', 'injury_status': '',...        5
# ..                                                 ...      ...
# 115  {'first_name': 'Donte', 'injury_status': '', '...      116
# 116  {'first_name': 'Jakob', 'injury_status': 'Out'...      117
# 117  {'first_name': 'Russell', 'injury_status': '',...      118
# 118  {'first_name': 'Bobby', 'injury_status': '', '...      119
# 119  {'first_name': 'Zach', 'injury_status': '', 'l...      120
#
#               picked_by player_id reactions roster_id  round
# 0    996275504854568960      1658      None      None      1
# 1                            1970      None      None      1
# 2                            1511      None      None      1
# 3                            2577      None      None      1
# 4                            1380      None      None      1
# ..                  ...       ...       ...       ...    ...
# 115                          1964      None      None     15
# 116                          1718      None      None     15
# 117                          1434      None      None     15
# 118                          1589      None      None     15
# 119                          2718      None      None     15
#
# [120 rows x 10 columns]

# %%
import requests
import pandas as pd


url = 'https://api.sleeper.app/v1/players/nba'
    
response = requests.get(url)
data = response.json()

df = pd.DataFrame(data)
df
# Out:
#                                                          1875  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    225
# practice_participation                                   None
# birth_date                                         1996-04-09
# high_school                                  New Hampton (NH)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292335149240320'}
# competitions                                               []
# team_abbr                                                None
# active                                                  False
# search_last_name                                        lydon
# college                                              Syracuse
# injury_body_part                                         None
# player_id                                                1875
# depth_chart_order                                        None
# full_name                                         Tyler Lydon
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                       tyler
# yahoo_id                                                 None
# status                                                    RET
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                    #tylerlydon-NBA-FA
# number                                                   None
# sportradar_id            f9b41748-5ab8-4ff7-9fc8-ecfec9f12d4b
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     82
# last_name                                               Lydon
# swish_id                                                 None
# search_full_name                                   tylerlydon
# age                                                        29
# rotowire_id                                              None
# first_name                                              Tyler
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PF, SF]
# years_exp                                                   2
# news_updated                                             None
# position                                                   PF
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1408  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    205
# practice_participation                                   None
# birth_date                                         1986-09-15
# high_school                                  Samuel Fels (PA)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292564640583680'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                    christmas
# college                                                Temple
# injury_body_part                                         None
# player_id                                                1408
# depth_chart_order                                        None
# full_name                                    Dionte Christmas
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                      dionte
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                               #diontechristmas-NBA-FA
# number                                                   None
# sportradar_id            11612dd6-431c-486d-88aa-789f3adf8149
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     77
# last_name                                           Christmas
# swish_id                                                 None
# search_full_name                              diontechristmas
# age                                                        38
# rotowire_id                                              None
# first_name                                             Dionte
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                   1
# news_updated                                             None
# position                                                   SG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          2091  \
# espn_id                                                  None
# search_rank                                               143
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                             Out
# weight                                                    210
# practice_participation                                   None
# birth_date                                         1996-03-03
# high_school                 Our Lady of the Sacred Heart (PA)
# team                                                      BKN
# birth_city                                               None
# metadata                {'channel_id': '1113936501550350336'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                      johnson
# college                                        North Carolina
# injury_body_part                                         Back
# player_id                                                2091
# depth_chart_order                                           1
# full_name                                     Cameron Johnson
# pandascore_id                                            None
# depth_chart_position                                       PF
# team_changed_at                                          None
# search_first_name                                     cameron
# yahoo_id                                                 None
# status                                                    ACT
# oddsjam_id                                       C9AF28084D8F
# injury_notes                                           Bruise
# hashtag                             #cameronjohnson-NBA-BKN-2
# number                                                      2
# sportradar_id            2fe5b749-7bd4-4dbc-acfb-6d675f541e37
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     80
# last_name                                             Johnson
# swish_id                                               843005
# search_full_name                               cameronjohnson
# age                                                        29
# rotowire_id                                              4916
# first_name                                            Cameron
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PF, SF]
# years_exp                                                   5
# news_updated                                    1744488052747
# position                                                   PF
# rotoworld_id                                             None
# fantasy_data_id                                      20002289
#
#                                                          2508  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    215
# practice_participation                                   None
# birth_date                                         2000-03-05
# high_school                                   Belleville (MI)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1114318987795124224'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                        brown
# college                                        Michigan State
# injury_body_part                                         None
# player_id                                                2508
# depth_chart_order                                        None
# full_name                                          Gabe Brown
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                        gabe
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                     #gabebrown-NBA-FA
# number                                                   None
# sportradar_id            b1275a1f-6ede-44f7-b1a1-091399a6ff5a
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     80
# last_name                                               Brown
# swish_id                                              1133816
# search_full_name                                    gabebrown
# age                                                        25
# rotowire_id                                              5748
# first_name                                               Gabe
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PF, SF]
# years_exp                                                   1
# news_updated                                    1668158495240
# position                                                   PF
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          2199  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    210
# practice_participation                                   None
# birth_date                                         1993-02-07
# high_school                                Oakland Mills (MD)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292679090556928'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                  whittington
# college                                            Georgetown
# injury_body_part                                         None
# player_id                                                2199
# depth_chart_order                                        None
# full_name                                    Greg Whittington
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                        greg
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                               #gregwhittington-NBA-FA
# number                                                   None
# sportradar_id            d0cb08b3-51b4-4700-9311-4e111df81d49
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     80
# last_name                                         Whittington
# swish_id                                                 None
# search_full_name                              gregwhittington
# age                                                        32
# rotowire_id                                              3810
# first_name                                               Greg
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PF, SF]
# years_exp                                                   1
# news_updated                                    1617894045420
# position                                                   PF
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          2064  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    200
# practice_participation                                   None
# birth_date                                         1998-03-12
# high_school                                   Atascocita (TX)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292307227758592'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                      edwards
# college                                                Purdue
# injury_body_part                                         None
# player_id                                                2064
# depth_chart_order                                        None
# full_name                                      Carsen Edwards
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                      carsen
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                 #carsenedwards-NBA-FA
# number                                                   None
# sportradar_id            d1340a44-b873-425e-a1c6-2545a0ef8398
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     71
# last_name                                             Edwards
# swish_id                                               945110
# search_full_name                                carsenedwards
# age                                                        27
# rotowire_id                                              4764
# first_name                                             Carsen
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                   3
# news_updated                                    1657738242906
# position                                                   SG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1284  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    180
# practice_participation                                   None
# birth_date                                         1990-11-26
# high_school                                 Findlay Prep (NV)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292352975032320'}
# competitions                                               []
# team_abbr                                                None
# active                                                  False
# search_last_name                                      bradley
# college                                                 Texas
# injury_body_part                                         None
# player_id                                                1284
# depth_chart_order                                        None
# full_name                                       Avery Bradley
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                       avery
# yahoo_id                                                 None
# status                                                    RET
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                  #averybradley-NBA-FA
# number                                                   None
# sportradar_id            b23917d2-bb0d-49fa-a384-80d994561d0c
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     75
# last_name                                             Bradley
# swish_id                                               513607
# search_full_name                                 averybradley
# age                                                        34
# rotowire_id                                              3112
# first_name                                              Avery
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [SF, SG]
# years_exp                                                  12
# news_updated                                    1648865720916
# position                                                   SG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          2801  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    180
# practice_participation                                   None
# birth_date                                               None
# high_school                                              None
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1114062286198149120'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                         east
# college                                              Missouri
# injury_body_part                                         None
# player_id                                                2801
# depth_chart_order                                        None
# full_name                                           Sean East
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                        sean
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                      #seaneast-NBA-FA
# number                                                   None
# sportradar_id            5ec0b4b3-dd56-434f-9f08-81e40518b327
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     75
# last_name                                                East
# swish_id                                                 None
# search_full_name                                     seaneast
# age                                                      None
# rotowire_id                                              6347
# first_name                                               Sean
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                   0
# news_updated                                             None
# position                                                   PG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1073  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    175
# practice_participation                                   None
# birth_date                                         1984-04-17
# high_school                                Bishop Gorman (NV)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292613843963904'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                       watson
# college                                             Tennessee
# injury_body_part                                         None
# player_id                                                1073
# depth_chart_order                                        None
# full_name                                         C.J. Watson
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                          cj
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                      #cjwatson-NBA-FA
# number                                                   None
# sportradar_id            7671f7d9-b7f8-4602-a32d-19f4f1ddae75
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     74
# last_name                                              Watson
# swish_id                                                 None
# search_full_name                                     cjwatson
# age                                                        40
# rotowire_id                                              None
# first_name                                               C.J.
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                  10
# news_updated                                             None
# position                                                   PG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1982  ...  \
# espn_id                                                  None  ...
# search_rank                                               172  ...
# sport                                                     nba  ...
# practice_description                                     None  ...
# birth_state                                              None  ...
# injury_status                                            None  ...
# weight                                                    204  ...
# practice_participation                                   None  ...
# birth_date                                         1999-01-18  ...
# high_school                                Prolific Prep (CA)  ...
# team                                                      MIL  ...
# birth_city                                               None  ...
# metadata                {'channel_id': '1119029907645558784'}  ...
# competitions                                               []  ...
# team_abbr                                                None  ...
# active                                                   True  ...
# search_last_name                                        trent  ...
# college                                                  Duke  ...
# injury_body_part                                         None  ...
# player_id                                                1982  ...
# depth_chart_order                                           1  ...
# full_name                                          Gary Trent  ...
# pandascore_id                                            None  ...
# depth_chart_position                                       SG  ...
# team_changed_at                                          None  ...
# search_first_name                                        gary  ...
# yahoo_id                                                 None  ...
# status                                                    ACT  ...
# oddsjam_id                                       E742754A7BD0  ...
# injury_notes                                             None  ...
# hashtag                                  #garytrent-NBA-MIL-5  ...
# number                                                      5  ...
# sportradar_id            62daf16f-0c4c-46ae-9e54-0d34d6fdef85  ...
# opta_id                                                  None  ...
# injury_start_date                                        None  ...
# height                                                     77  ...
# last_name                                               Trent  ...
# swish_id                                              1060908  ...
# search_full_name                                    garytrent  ...
# age                                                        26  ...
# rotowire_id                                              4433  ...
# first_name                                               Gary  ...
# stats_id                                                 None  ...
# gsis_id                                                  None  ...
# birth_country                                            None  ...
# fantasy_positions                                    [PG, SG]  ...
# years_exp                                                   6  ...
# news_updated                                    1745978126089  ...
# position                                                   SG  ...
# rotoworld_id                                             None  ...
# fantasy_data_id                                      20002027  ...
#
#                                                          2757  \
# espn_id                                                  None
# search_rank                                               807
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    209
# practice_participation                                   None
# birth_date                                         2004-02-23
# high_school                                              None
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1113936511088197632'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                       urisic
# college                                                  None
# injury_body_part                                         None
# player_id                                                2757
# depth_chart_order                                        None
# full_name                                      Nikola Đurišić
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                      nikola
# yahoo_id                                                 None
# status                                                    NWT
# oddsjam_id                                       4723DD36A7E3
# injury_notes                                             None
# hashtag                                  #nikolaurisic-NBA-FA
# number                                                   None
# sportradar_id            8e0c0e99-7060-4dce-a76a-777c3ee22da8
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     79
# last_name                                             Đurišić
# swish_id                                              1373332
# search_full_name                                 nikolaurisic
# age                                                        21
# rotowire_id                                              5993
# first_name                                             Nikola
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PF, SF]
# years_exp                                                   0
# news_updated                                    1730083216629
# position                                                   PF
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1513  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    200
# practice_participation                                   None
# birth_date                                         1990-05-22
# high_school                                        North (CA)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292171743350784'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                          lee
# college                                                  UCLA
# injury_body_part                                         None
# player_id                                                1513
# depth_chart_order                                        None
# full_name                                         Malcolm Lee
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                     malcolm
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                    #malcolmlee-NBA-FA
# number                                                   None
# sportradar_id            57f717d5-0c6e-4079-a6d2-c73ba44979b2
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     77
# last_name                                                 Lee
# swish_id                                                 None
# search_full_name                                   malcolmlee
# age                                                        34
# rotowire_id                                              None
# first_name                                            Malcolm
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                   3
# news_updated                                             None
# position                                                   SG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1731  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    180
# practice_participation                                   None
# birth_date                                         1991-08-29
# high_school                                      Desert Pines
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292533728563200'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                      jackson
# college                                                Baylor
# injury_body_part                                         None
# player_id                                                1731
# depth_chart_order                                        None
# full_name                                      Pierre Jackson
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                      pierre
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                 #pierrejackson-NBA-FA
# number                                                   None
# sportradar_id            55e9d1e5-6ea3-4475-9877-d9d1f5f1910d
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     70
# last_name                                             Jackson
# swish_id                                                 None
# search_full_name                                pierrejackson
# age                                                        33
# rotowire_id                                              None
# first_name                                             Pierre
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                   1
# news_updated                                             None
# position                                                   PG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          2180  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    200
# practice_participation                                   None
# birth_date                                         2000-09-11
# high_school                                              None
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292441680367616'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                      bolmaro
# college                                                  None
# injury_body_part                                         None
# player_id                                                2180
# depth_chart_order                                        None
# full_name                                     Leandro Bolmaro
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                     leandro
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                #leandrobolmaro-NBA-FA
# number                                                   None
# sportradar_id            9a572392-b36d-4abd-a52d-98bf7f47c87d
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     78
# last_name                                             Bolmaro
# swish_id                                              1257425
# search_full_name                               leandrobolmaro
# age                                                        24
# rotowire_id                                              5234
# first_name                                            Leandro
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [SF, SG]
# years_exp                                                   1
# news_updated                                    1677771029688
# position                                                   SG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1473  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# ...
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                    thornwell
# college                                        South Carolina
# injury_body_part                                         None
# player_id                                                1834
# depth_chart_order                                        None
# full_name                                 Sindarius Thornwell
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                   sindarius
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                            #sindariusthornwell-NBA-FA
# number                                                   None
# sportradar_id            6bc2803e-4dd4-4db7-9404-9300acf9364d
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     76
# last_name                                           Thornwell
# swish_id                                                 None
# search_full_name                           sindariusthornwell
# age                                                        30
# rotowire_id                                              4133
# first_name                                          Sindarius
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                   3
# news_updated                                    1620611728974
# position                                                   SG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1077  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    260
# practice_participation                                   None
# birth_date                                         1984-11-28
# high_school                            Lake Ginninderra (AUS)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292122695159808'}
# competitions                                               []
# team_abbr                                                None
# active                                                  False
# search_last_name                                        bogut
# college                                                  Utah
# injury_body_part                                         None
# player_id                                                1077
# depth_chart_order                                        None
# full_name                                        Andrew Bogut
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                      andrew
# yahoo_id                                                 None
# status                                                    RET
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                   #andrewbogut-NBA-FA
# number                                                   None
# sportradar_id            26734851-dce6-4e5b-8291-594a7ebd6658
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     84
# last_name                                               Bogut
# swish_id                                                 None
# search_full_name                                  andrewbogut
# age                                                        40
# rotowire_id                                              2590
# first_name                                             Andrew
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                         [C]
# years_exp                                                  14
# news_updated                                    1606779001843
# position                                                    C
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          2251  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    188
# practice_participation                                   None
# birth_date                                         1999-07-02
# high_school                                              None
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292510391455744'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                      louzada
# college                                                  None
# injury_body_part                                         None
# player_id                                                2251
# depth_chart_order                                        None
# full_name                                        Didi Louzada
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                        didi
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                                   #didilouzada-NBA-FA
# number                                                   None
# sportradar_id            78df2636-a9fb-4a23-a29f-9c176d93123b
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     77
# last_name                                             Louzada
# swish_id                                              1172136
# search_full_name                                  didilouzada
# age                                                        25
# rotowire_id                                              4933
# first_name                                               Didi
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PG, SG]
# years_exp                                                   1
# news_updated                                    1661806809929
# position                                                   SG
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1185  \
# espn_id                                                  None
# search_rank                                              None
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                            None
# weight                                                    230
# practice_participation                                   None
# birth_date                                         1987-04-22
# high_school                                      Potomac (MD)
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1153292925732409344'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                   cunningham
# college                                             Villanova
# injury_body_part                                         None
# player_id                                                1185
# depth_chart_order                                        None
# full_name                                    Dante Cunningham
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                       dante
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                               None
# injury_notes                                             None
# hashtag                               #dantecunningham-NBA-FA
# number                                                   None
# sportradar_id            627e78c7-3f9e-4ac3-9b7d-686087c665ae
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     80
# last_name                                          Cunningham
# swish_id                                                 None
# search_full_name                              dantecunningham
# age                                                        37
# rotowire_id                                              None
# first_name                                              Dante
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                    [PF, SF]
# years_exp                                                  10
# news_updated                                             None
# position                                                   SF
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
#                                                          1591
# espn_id                                                  None
# search_rank                                               902
# sport                                                     nba
# practice_description                                     None
# birth_state                                              None
# injury_status                                             Out
# weight                                                    219
# practice_participation                                   None
# birth_date                                         1992-07-18
# high_school                                              None
# team                                                     None
# birth_city                                               None
# metadata                {'channel_id': '1121551437877231616'}
# competitions                                               []
# team_abbr                                                None
# active                                                   True
# search_last_name                                antetokounmpo
# college                                                  None
# injury_body_part                                     Achilles
# player_id                                                1591
# depth_chart_order                                        None
# full_name                              Thanasis Antetokounmpo
# pandascore_id                                            None
# depth_chart_position                                     None
# team_changed_at                                          None
# search_first_name                                    thanasis
# yahoo_id                                                 None
# status                                                     FA
# oddsjam_id                                       E6E2DACA5A03
# injury_notes                                             None
# hashtag                         #thanasisantetokounmpo-NBA-FA
# number                                                   None
# sportradar_id            64c0e4e5-8711-4b86-8072-745f6084df73
# opta_id                                                  None
# injury_start_date                                        None
# height                                                     79
# last_name                                       Antetokounmpo
# swish_id                                               803207
# search_full_name                        thanasisantetokounmpo
# age                                                        32
# rotowire_id                                              3634
# first_name                                           Thanasis
# stats_id                                                 None
# gsis_id                                                  None
# birth_country                                            None
# fantasy_positions                                 [C, PF, SF]
# years_exp                                                   6
# news_updated                                    1715207409404
# position                                                   SF
# rotoworld_id                                             None
# fantasy_data_id                                          None
#
# [51 rows x 1907 columns]
