# %%
import requests
from bs4 import BeautifulSoup
from IPython.core.display import HTML
import pandas as pd
import io
import numpy as np
import time
from fuzzywuzzy import fuzz, process
from unidecode import unidecode
from tqdm import tqdm

# %%
positions = pd.read_csv("../data/playerpositions.csv")
player_names_positions = positions['Players'].tolist()
players_pic_link = pd.read_csv("../data/positions2.csv")
player_pic_link_names = players_pic_link['Players'].tolist()

# %%
nba_team_abbreviations = {
    "Atlanta Hawks": "ATL",
    "Boston Celtics": "BOS",
    "Brooklyn Nets": "BRK",
    "Buffalo Braves": "BUF",
    "Charlotte Hornets": "CHO",
    "Charlotte Bobcats": "CHA",
    "Chicago Bulls": "CHI",
    "Cleveland Cavaliers": "CLE",
    "Dallas Mavericks": "DAL",
    "Denver Nuggets": "DEN",
    "Detroit Pistons": "DET",
    "Golden State Warriors": "GSW",
    "Houston Rockets": "HOU",
    "Indiana Pacers": "IND",
    "Kansas City Kings": "KCK",
    "Los Angeles Clippers": "LAC",
    "Los Angeles Lakers": "LAL",
    "Memphis Grizzlies": "MEM",
    "Miami Heat": "MIA",
    "Milwaukee Bucks": "MIL",
    "Minnesota Timberwolves": "MIN",
    "New Jersey Nets": "NJN",
    "New Orleans/Oklahoma City Hornets": "NOK",
    "New Orleans Pelicans": "NOP",
    "New Orleans Hornets": "NOH",
    "New Orleans Jazz": "NOJ",
    "New York Knicks": "NYK",
    "New York Nets": "NYN",
    "Oklahoma City Thunder": "OKC",
    "Orlando Magic": "ORL",
    "Philadelphia 76ers": "PHI",
    "Phoenix Suns": "PHO",
    "Portland Trail Blazers": "POR",
    "Sacramento Kings": "SAC",
    "San Antonio Spurs": "SAS",
    "San Diego Clippers": "SDC",
    "Seattle SuperSonics": "SEA",
    "Toronto Raptors": "TOR",
    "Utah Jazz": "UTA",
    "Vancouver Grizzlies": "VAN",
    "Washington Bullets": "WSB",
    "Washington Wizards": "WAS"
    }


nba_team_names = {
    "ATL": "Atlanta Hawks",
    "BOS": "Boston Celtics",
    "BRK": "Brooklyn Nets",
    "BUF": "Buffalo Braves",
    "CHO": "Charlotte Hornets",
    "CHA": "Charlotte Bobcats",
    "CHI": "Chicago Bulls",
    "CLE": "Cleveland Cavaliers",
    "DAL": "Dallas Mavericks",
    "DEN": "Denver Nuggets",
    "DET": "Detroit Pistons",
    "GSW": "Golden State Warriors",
    "HOU": "Houston Rockets",
    "IND": "Indiana Pacers",
    "KCK": "Kansas City Kings",
    "LAC": "Los Angeles Clippers",
    "LAL": "Los Angeles Lakers",
    "MEM": "Memphis Grizzlies",
    "MIA": "Miami Heat",
    "MIL": "Milwaukee Bucks",
    "MIN": "Minnesota Timberwolves",
    "NJN": "New Jersey Nets",
    "NOK": "New Orleans/Oklahoma City Hornets",
    "NOP": "New Orleans Pelicans",
    "NOH": "New Orleans Hornets",
    "NOJ": "New Orleans Jazz",
    "NYK": "New York Knicks",
    "NYN": "New York Nets",
    "OKC": "Oklahoma City Thunder",
    "ORL": "Orlando Magic",
    "PHI": "Philadelphia 76ers",
    "PHO": "Phoenix Suns",
    "POR": "Portland Trail Blazers",
    "SAC": "Sacramento Kings",
    "SAS": "San Antonio Spurs",
    "SDC": "San Diego Clippers",
    "SEA": "Seattle SuperSonics",
    "TOR": "Toronto Raptors",
    "UTA": "Utah Jazz",
    "VAN": "Vancouver Grizzlies",
    "WSB": "Washington Bullets",
    "WAS": "Washington Wizards"
}

# %%
def get_all_links_all_games(big_df):
    length = len(big_df)
    link_list = []
    for i in range(length):
        df = big_df.iloc[[i]]
        link_list.append(get_boxscore_link(df))
    
    return link_list

# %%
def team_link(teamabv, year):
    return f'https://www.basketball-reference.com/teams/{teamabv}/{year}.html#all_roster'

# %%
def team_players(team_link):
    URL = team_link
    response = requests.get(URL)
    response.status_code
    soup = BeautifulSoup(response.text, features="html.parser")
    soup.prettify()
    tables = soup.find_all('table')
    table_html = str(tables[0])
    df = pd.read_html(io.StringIO(table_html))[0]
    players_list = df['Player'].tolist()
    players_list = list(map(lambda x: x.split('(')[0].strip(), players_list))
    return players_list

# %%
def player_link(name):
    
    firstname = name.split()[0]
    lastname = name.split()[1]
    firstname = "".join(char for char in firstname if char.isalpha()).lower()
    lastname = "".join(char for char in lastname if char.isalpha()).lower()
    lastinitial = lastname[0].lower()
    
    lastname5 = lastname[0:5]
    firstname2 = firstname[0:2]
    number = 1
    
    link = f'https://www.basketball-reference.com/players/{lastinitial}/{lastname5}{firstname2}0{number}.html'
    NotFound = True
    
    while NotFound:
        URL = link
        response = requests.get(URL)
        soup = BeautifulSoup(response.text, features="html.parser")
        h1_tag = soup.find('h1')
        player_name = h1_tag.text.strip()
        if player_name == name:
            print('Found it!')
            
            
            NotFound = False
        elif response.status_code != 200:
            print("Name Not Found....")
            NotFound = False
            positions = ['PG','SG','SF','PF','C']
        else:
            number += 1
            link = f'https://www.basketball-reference.com/players/{lastinitial}/{lastname5}{firstname2}0{number}.html'
            print(f'Didnt find it, trying again. This is {number} trying next.' )
        
    picturelink = f'https://www.basketball-reference.com/req/202106291/images/headshots/{lastname5}{firstname2}0{number}.jpg'
    linklist = []
    linklist.append(link)
    linklist.append(picturelink)
    return linklist

# %%
def get_positions_link(link, testing = False):
    response = requests.get(link)
    if response.status_code != 200:
        positions = ['PG','SG','SF','PF','C']
        return positions
    else:
        soup = BeautifulSoup(response.text, features="html.parser")
        inactive_section = soup.find_all('p')
        for i in range(10):
            try:
                if testing:
                    print(f'Trying {i}')
                
                positions = inactive_section[i]
                
                strong_tag = positions.find('strong', string=lambda t: t and "Position:" in t)
                position_text = strong_tag.next_sibling.strip()
                break
            except:
                pass
            
            
            
        positions = position_text.strip()
        only_positions = positions.split('\n')[0]
        
        if ',' in only_positions:
            only_positions = only_positions.split(',')
        else:
            if 'and' in only_positions:
                only_positions = only_positions.split('and')
            else:
                only_positions = [only_positions]
        if testing:
            print(f'This is only positions: {only_positions}')
            
            
        final_positions = []
        position_dict = {
            'Point Guard':"PG",
            'Shooting Guard' : "SG",
            'Small Forward' : "SF",
            'Power Forward' : "PF",
            'Center' : "C",
            'Forward' : "SF",
            'Guard' : 'PG'
        }
        for i in range(len(only_positions)):
            cleaned_string = only_positions[i].replace("and", "")
            if testing:
                print(f'This is cleaned_string: {cleaned_string}')
            cleaned_string = cleaned_string.strip()
            if testing:
                print(f'This is cleaned_string: {cleaned_string}')
            
            cleaned_string = position_dict[cleaned_string]
            
            final_positions.append(cleaned_string)
            
        
        return final_positions

# %%
def name_to_positions(name, testing = False):
    link = player_link(name)
    positions = get_positions_link(link[0], testing = testing)
    positionsandlink = []
    positionsandlink.append(positions)
    positionsandlink.append(link[1])
    return positionsandlink

# %%
def get_positions(team_abv,year):
    link = team_link(team_abv,year)
    list_players = team_players(link)
    
    
    
    names_list = []
    pos1_list = []
    pos2_list = []
    pos3_list = []
    pos4_list = []
    pos5_list = []
    picture_link = []
    for name in list_players:
        time.sleep(8)
        
        positionsAll = name_to_positions(name, False)
        positions = positionsAll[0]
        
        names_list.append(name)
        
        for i in range(5):
            if i == 0:
                try:
                    pos1_list.append(positions[i])
                except:
                    pos1_list.append(np.nan)
            if i == 1:
                try:
                    pos2_list.append(positions[i])
                except:
                    pos2_list.append(np.nan)
            if i == 2:
                try:
                    pos3_list.append(positions[i])
                except:
                    pos3_list.append(np.nan)
            if i == 3:
                try:
                    pos4_list.append(positions[i])
                except:
                    pos4_list.append(np.nan)
            if i == 4:
                try:
                    pos5_list.append(positions[i])
                except:
                    pos5_list.append(np.nan)
        
        picture_link.append(positionsAll[1])
        print(names_list)
        #print(pos1_list)
        #print(pos2_list)
        #print(pos3_list)
        #print(pos4_list)
        #print(pos5_list)
    
    
    df = pd.DataFrame(
        {
            'Players':names_list,
            'Pos1':pos1_list,
            'Pos2':pos2_list,
            'Pos3':pos3_list,
            'Pos4':pos4_list,
            'Pos5':pos5_list,
            'PictureLink':picture_link
            
        }
    )
    
    return df

# %%
def add_fantasy_averages(df):
    
    df = df.copy()  # Avoid modifying original dataframe
    df["_original_index"] = df.index  # Store original index
    
    df = df.sort_values(by=["Starters", "Date"])  # Sort by player and date

    # Calculate cumulative average per player
    df["AvgFantPoints"] = df.groupby("Starters")["FantasyPoints"].expanding().mean().reset_index(level=0, drop=True)

    df = df.sort_values(by="_original_index").drop(columns=["_original_index"])  # Restore original order

    return df

# %%
def add_fantasy_averages_new(df):
    
    df["AvgFantPoints"] = df.apply(lambda row: df[
    (df["Starters"] == row["Starters"]) &  # Same player
    (df["Date"] < row["Date"]) &  # Only past games
    (~df["DidNotPlay"])  # Only games where the player actually played
    ]["FantasyPoints"].mean(), axis=1)


    return df

# %%
def add_fantasy_averages_new_new(df):
    #df = df.sort_values(["Starters", "Date"])  # Ensure chronological order for each player

    avg_fantasy = []
    avg_fantasy_last10 = []
    avg_mp_time = []
    avg_mp_time_last10 = []
    avg_points = []
    avg_points_last10 = []
    avg_assists = []
    avg_assists_last10 = []
    avg_rebounds = []
    avg_rebounds_last10 = []
    avg_steals = []
    avg_steals_last10 = []
    avg_blocks = []
    avg_blocks_last10 = []
    avg_turnovers = []
    avg_turnovers_last10 = []
    avg_threepointers = []
    avg_threepointers_last10 = []
    
   

    # Convert MPTimeDelta to timedelta format
    df["MPTimeDelta"] = pd.to_timedelta(df["MPTimeDelta"])

    for idx, row in tqdm(df.iterrows()):
        past_games = df[
            (df["Starters"] == row["Starters"]) & 
            (df["Date"] < row["Date"]) & 
            (~df["DidNotPlay"])
        ].copy()  # ✅ Copy to avoid potential SettingWithCopyWarning

        # Convert MPTimeDelta to minutes as float
        past_games["MPMinutes"] = past_games["MPTimeDelta"].dt.total_seconds() / 60

        # Calculate averages
        avg_fantasy.append(past_games["FantasyPoints"].mean())
        avg_mp_time.append(past_games['MPMinutes'].mean())
        avg_points.append(past_games["PTS"].mean())
        avg_assists.append(past_games["AST"].mean())
        avg_rebounds.append(past_games["TRB"].mean())
        avg_steals.append(past_games["STL"].mean())
        avg_blocks.append(past_games["BLK"].mean())
        avg_turnovers.append(past_games["TOV"].mean())
        avg_threepointers.append(past_games["3P"].mean())

        last_10_games = past_games.tail(10).copy()  # ✅ Copy ensures "MPMinutes" exists

        avg_fantasy_last10.append(last_10_games["FantasyPoints"].mean())
        avg_mp_time_last10.append(last_10_games["MPMinutes"].mean() if not last_10_games.empty else None)
        avg_points_last10.append(last_10_games["PTS"].mean())
        avg_assists_last10.append(last_10_games["AST"].mean())
        avg_rebounds_last10.append(last_10_games["TRB"].mean())
        avg_steals_last10.append(last_10_games["STL"].mean())
        avg_blocks_last10.append(last_10_games["BLK"].mean())
        avg_turnovers_last10.append(last_10_games["TOV"].mean())
        avg_threepointers_last10.append(last_10_games["3P"].mean())
        
        
        
        
       

        
        

    # Assign new columns
    df["AvgFantPoints"] = avg_fantasy
    df["AvgFantPointsLast10"] = avg_fantasy_last10
    df["AvgMPTime"] = avg_mp_time
    df["AvgMPTimeLast10"] = avg_mp_time_last10
    df["AvgPoints"] = avg_points
    df["AvgPointsLast10"] = avg_points_last10
    df["AvgAssists"] = avg_assists
    df["AvgAssistsLast10"] = avg_assists_last10
    df["AvgRebounds"] = avg_rebounds
    df["AvgReboundsLast10"] = avg_rebounds_last10
    df["AvgSteals"] = avg_steals
    df["AvgStealsLast10"] = avg_steals_last10
    df["AvgBlocks"] = avg_blocks
    df["AvgBlocksLast10"] = avg_blocks_last10
    df["AvgTurnovers"] = avg_turnovers
    df["AvgTurnoversLast10"] = avg_turnovers_last10
    df["AvgThreePointers"] = avg_threepointers
    df["AvgThreePointersLast10"] = avg_threepointers_last10
    

    return df

# %%
def add_injury_counts(df):
    # Ensure correct data types
    
    
    # Create empty lists for new columns
    prev_inj_count = []
    opp_inj_count = []
    opp_prev_inj_count = []

    # Convert Date to datetime if not already
    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

    # Create a lookup table for previous injuries by team
    prev_injury_lookup = {}

    # Iterate over each row
    for idx, row in tqdm(df.iterrows()):
        team = row["TeamAbv"]
        opp_team = row["OpponentTeamAbv"]
        game_id = row["GameID"]

        # Get previous injury count for the team
        prev_value = prev_injury_lookup.get(team, None)
        prev_inj_count.append(prev_value)

        # Get opponent's injury count for the current game
        opp_injury = df[(df["GameID"] == game_id) & (df["TeamAbv"] == opp_team)]["InjTeamateCount"]
        opp_inj_count.append(opp_injury.mean() if not opp_injury.empty else None)

        # Get previous injury count for the opponent
        opp_prev_value = prev_injury_lookup.get(opp_team, None)
        opp_prev_inj_count.append(opp_prev_value)

        # Update lookup table with the current team's injury count
        prev_injury_lookup[team] = row["InjTeamateCount"]

    # Assign new columns
    df["PrevInjuredCount"] = prev_inj_count
    df["OpponentInjTeamateCount"] = opp_inj_count
    df["OpponentPrevInjuredCount"] = opp_prev_inj_count

    return df

# %%
def cut_dataframe(nba_data, ending_date, team_name):
    # Filter data based on date and team criteria
    cut_data = nba_data[
        (nba_data["Date"] < ending_date) &
        (nba_data["Date"] > nba_data["Date"].min()) &
        (nba_data["OpponentTeamAbv"] == team_name) &
        (nba_data["Top7InTeam"] == True)
    ]

    # Group by position and calculate mean fantasy points
    cut_data = cut_data.groupby("Pos1", as_index=False).agg(AvgFantPoints=("FantasyPoints", "mean"))
    
    # Add team and date columns
    cut_data["team"] = team_name
    cut_data["date"] = ending_date

    # Compute team-level statistics
    team_games = nba_data[
        (nba_data["Date"] < ending_date) &
        (nba_data["Date"] >= nba_data["Date"].min()) &
        (nba_data["OpponentTeamAbv"] == team_name)
    ].groupby("GameID", as_index=False).agg(
        Loss=("WonGame", lambda x: max(x)),  # If any player won, the team lost
        Win=("WonGame", lambda x: max(x == False)),  # If any player lost, the team won
        PointDiff=("GamePointDiff", lambda x: -max(x))  # Reverse point diff
    )

    # Calculate win percentage and total point differential
    win_percentage = team_games["Win"].sum() / len(team_games) if len(team_games) > 0 else 0
    point_diff = team_games["PointDiff"].sum() if len(team_games) > 0 else 0

    # Add win percentage and point differential
    cut_data["WinPercentage"] = win_percentage
    cut_data["PointDiff"] = point_diff

    # Add overall average row
    overall_avg = pd.DataFrame([{
        "Pos1": "ALL",
        "AvgFantPoints": cut_data["AvgFantPoints"].mean(),
        "team": team_name,
        "date": ending_date,
        "WinPercentage": win_percentage,
        "PointDiff": point_diff
    }])

    # Append overall average row
    cut_data = pd.concat([cut_data, overall_avg], ignore_index=True)

    return cut_data

# %%
def whole_team_dataframe(nba_data, team_name):
    start_date = pd.to_datetime("2024-10-25")
    end_date = nba_data["Date"].max()
    date_sequence = pd.date_range(start=start_date, end=end_date, freq="D")

    # Loop through dates and combine results into one dataframe
    full_team_df = pd.concat([cut_dataframe(nba_data, date, team_name) for date in date_sequence], ignore_index=True)

    return full_team_df

# %%
def generate_full_nba_dataframe(nba_data):
    nba_team_abbreviations = [
        "ATL", "BOS", "BRK", "CHO", "CHI", "CLE", "DAL", "DEN", "DET", "GSW",
        "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL", "MIN", "NOP", "NYK",
        "OKC", "ORL", "PHI", "PHO", "POR", "SAC", "SAS", "TOR", "UTA", "WAS"
    ]

    # Loop through each team abbreviation and combine results into one dataframe
    full_nba_df = pd.concat([whole_team_dataframe(nba_data, team) for team in nba_team_abbreviations], ignore_index=True)

    # Rank within each date & position
    full_nba_df["FantPointsAgainstRank"] = full_nba_df.groupby(["date", "Pos1"])["AvgFantPoints"].rank(method="min")

    return full_nba_df

# %%
def add_opponent_info(MainDF):
    
    teams = generate_full_nba_dataframe(MainDF)
    
    print(MainDF)
    print(teams)
    print("Checkpoint1")


    MainDF['Date'] = pd.to_datetime(MainDF['Date'], format = 'mixed')
    teams['date'] = pd.to_datetime(teams['date'])

    teams_noposition =  teams.drop_duplicates(subset=['date', 'team'])
    nba_data_merged = MainDF.merge(
        teams_noposition[['date', 'team', 'FantPointsAgainstRank', 'PointDiff','WinPercentage']],  
        left_on=['Date', 'OpponentTeamAbv'], 
        right_on=['date', 'team'], 
        how='left'
    ).drop(columns=['team','date'])

    print(nba_data_merged)
    print("Checkpoint2")
    positional_ranks = teams.pivot(index=['date', 'team'], columns='Pos1', values='FantPointsAgainstRank')
    positional_ranks = positional_ranks.reset_index()

    nba_data_merged = nba_data_merged.merge(
        positional_ranks, 
        left_on=['Date', 'OpponentTeamAbv'], 
        right_on=['date', 'team'], 
        how='left'
    ).drop(columns=['team','date'])

    nba_data_merged.rename(columns = {'PointDiff':'OpponentPointDiff','WinPercentage':'OpponentWinPercentage','ALL':'OppFantDefense: ALL','C':'OppFantDefense: C','PF_y':'OppFantDefense: PF','PG':'OppFantDefense: PG','SF':'OppFantDefense: SF','SG':'OppFantDefense: SG', 'PF_x':'PF'}, inplace = True)

    
    print(nba_data_merged)
    print("Checkpoint3")
    
    
    return(nba_data_merged)

# %%
def get_boxscore_link(df):
    
    if int(df['Month#'].iloc[0]) < 10:
        month = '0' + str(df['Month#'].iloc[0])
    else:
        month = df['Month#'].iloc[0]
    year = df['Year'].iloc[0]
    day = df['Day'].iloc[0]
    hometeam = df['HomeTeamAbv'].iloc[0]
    
    link = f'https://www.basketball-reference.com/boxscores/{year}{month}{day}0{hometeam}.html'
    print(link)
    return link

# %%
def player_scores_game(GameDF):
    
    global positions
    
    columns_to_replace = [
    'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 
    'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-'
    ]
    URL = get_boxscore_link(GameDF)
    
    response = requests.get(URL)
    soup = BeautifulSoup(response.text, features="html.parser")
    soup.prettify()
    tables = soup.find_all('table')
    
    
    try:
        inactive_section = soup.find('strong', string=lambda t: t and "Inactive:" in t)
        team_sections = inactive_section.find_next_siblings('span')
        team_inactives = {}  

        for team_section in team_sections:
            team_name = team_section.text.strip() 


            players = []
            sibling = team_section.find_next_sibling()
            while sibling and sibling.name == 'a':  
                players.append(sibling.text.strip())
                sibling = sibling.find_next_sibling()

            # Store the team and its players
            if players:
                team_inactives[team_name] = players
        rows = []
        for team, players in team_inactives.items():
            for player in players:
                row = {'Starters': player, 'Injured': True, 'TeamAbv': team}  
                rows.append(row)

        new_df = pd.DataFrame(rows)
        team_inactive_counts = {}
        team_inactive_counts = {team: len(players) for team, players in team_inactives.items()}
        
    except:
        new_df = pd.DataFrame()
        
    
    
    table_html1 = str(tables[0])
    df1 = pd.read_html(io.StringIO(table_html1))[0]
    df1.columns = df1.columns.droplevel(0)
    df1['Starting'] = [True if i < 5 else False for i in range(len(df1))]
    df1['Injured'] = False
    df1['TeamAbv'] = nba_team_abbreviations[GameDF['AwayTeam'].iloc[0]]
    name1 = df1['Starters'].iloc[0]
    
    df1_filtered = df1[~df1['Starters'].isin(['Team Totals', 'Reserves'])].copy()
    
    df1_filtered.loc[:, 'MP_sort'] = pd.to_numeric(df1_filtered['MP'], errors='coerce')
    top_non_startersdf1 = df1_filtered[df1_filtered['Starting'] == False].nlargest(2, 'MP_sort')
    
    df1['Top7InTeam'] = df1_filtered['Starting'] | df1_filtered.index.isin(top_non_startersdf1.index)
    
    
    
    
    GoodToGo = False
    i = 6
    
    while not GoodToGo:
        table_html2 = str(tables[i])
        df2 = pd.read_html(io.StringIO(table_html2))[0]
        #print(df2)
        #print("ABOVE IS THE SECOND DATAFRAME!")
        df2.columns = df2.columns.droplevel(0)
        df2['Starting'] = [True if i < 5 else False for i in range(len(df2))]
       
        df2['Injured'] = False
        df2['TeamAbv'] = nba_team_abbreviations[GameDF['HomeTeam'].iloc[0]]
        name2= df2['Starters'].iloc[0]
        #print(name2)
        #print(i)
        i = i + 1
        if name1 != name2:
            GoodToGo = True
        
    
    df2_filtered = df2[~df2['Starters'].isin(['Team Totals', 'Reserves'])].copy()
    
    df2_filtered.loc[:, 'MP_sort'] = pd.to_numeric(df2_filtered['MP'], errors='coerce')
    top_non_startersdf2 = df2_filtered[df2_filtered['Starting'] == False].nlargest(2, 'MP_sort')
    
    df2['Top7InTeam'] = df2_filtered['Starting'] | df2_filtered.index.isin(top_non_startersdf2.index)
    
    
    
    
#     for i in range(len(tables)):
#         print("                                    ")
#         print("                                    ")
#         print("                                    ")
#         print(i)
#         print("                                    ")
#         print("                                    ")
#         print("                                    ")
#         table_html0 = str(tables[i])
#         df0 = pd.read_html(io.StringIO(table_html0))[0]
#         print(df0)
    
    
    #Do a first run of didnotplay = injured, then do if did not play = false?
    # or do did not play be an or statement just the whole thing
    
    
    
    df_merged = pd.concat([df1, df2, new_df], ignore_index=True, sort=False)
    #df_merged.columns = df_merged.columns.droplevel(0)
    
    df_merged = df_merged[df_merged['Starters'] != 'Team Totals']
    df_merged = df_merged[df_merged['Starters'] != 'Reserves']

    
    df_merged['Date'] = GameDF['Date'].iloc[0]
    df_merged['Year'] = df_merged['Date'].dt.year
    df_merged['Day'] = df_merged['Date'].dt.day.astype(str).str.zfill(2)
    df_merged['Month#'] = df_merged['Date'].dt.month
    df_merged['MonthName'] = df_merged['Date'].dt.month_name().str.lower()
    df_merged['Day_of_week'] = df_merged['Date'].dt.day_name()
    df_merged['TeamName'] = df_merged['TeamAbv'].map(nba_team_names)
    df_merged['Home'] = df_merged['TeamName'].apply(lambda x: x == GameDF['HomeTeam'].iloc[0])
    df_merged['DidNotPlay'] = (df_merged['FG'] == df_merged['MP']) | df_merged['Injured']
    df_merged[df_merged['Injured']] = df_merged.fillna(0)
    
    
    for col_replace in columns_to_replace:
        df_merged.loc[df_merged['DidNotPlay'], col_replace] = 0
      
    
    df_merged['MPTimeDelta'] = df_merged['MP'].apply(
    lambda x: pd.to_timedelta("00:" + str(x)) if ':' in str(x) else pd.to_timedelta(0))
    df_merged['OpponentTeam'] = df_merged['Home'].apply(lambda x: GameDF['AwayTeam'].iloc[0] if x else GameDF['HomeTeam'].iloc[0])
    df_merged['OpponentTeamAbv'] = df_merged['Home'].apply(lambda x: GameDF['AwayTeamAbv'].iloc[0] if x else GameDF['HomeTeamAbv'].iloc[0])
    df_merged['WonGame'] = df_merged['Home'].apply(lambda x: GameDF['HomeWin'].iloc[0] if x else GameDF['AwayWin'].iloc[0])
    df_merged['GamePointDiff'] = df_merged['Home'].apply(lambda x: GameDF['HomePointDiff'].iloc[0] if x else GameDF['AwayPointDiff'].iloc[0])
    df_merged['Start(ET)'] = GameDF['Start (ET)'].iloc[0]
    df_merged['Overtime'] = GameDF['Overtime'].iloc[0]
    df_merged['Attend.'] = GameDF['Attend.'].iloc[0]
    df_merged['InSeasonTournament'] = GameDF['InSeasonTournament'].iloc[0]
    
    
    
    df_merged['Starting'] = df_merged['Starting'].apply(lambda x: False if x == 0 else x)
    df_merged['PTS'] = pd.to_numeric(df_merged['PTS'], errors='coerce')
    df_merged['TRB'] = pd.to_numeric(df_merged['TRB'], errors='coerce')
    df_merged['AST'] = pd.to_numeric(df_merged['AST'], errors='coerce')
    df_merged['STL'] = pd.to_numeric(df_merged['STL'], errors='coerce')
    df_merged['BLK'] = pd.to_numeric(df_merged['BLK'], errors='coerce')
    df_merged['TOV'] = pd.to_numeric(df_merged['TOV'], errors='coerce')
    df_merged['3P'] = pd.to_numeric(df_merged['3P'], errors='coerce')
    df_merged['tens'] = ((df_merged['PTS'] >= 10) * 1) + ((df_merged['TRB'] >= 10) * 1) + ((df_merged['AST'] >= 10) * 1)+ ((df_merged['STL'] >= 10) * 1)+ ((df_merged['BLK'] >= 10) * 1)
    df_merged['FantasyPoints'] = (df_merged['PTS'] * .5) + (df_merged['TRB'] * 1) + (df_merged['AST'] * 1) + (df_merged['STL'] * 2) + (df_merged['BLK'] * 2) + (df_merged['TOV'] * -1) + (df_merged['3P'] * .5) + ((df_merged['PTS'] >= 40).astype(int) * 2) + ((df_merged['PTS'] >= 50).astype(int) * 2) + ((df_merged['tens'] >= 2).astype(int) * 1) + ((df_merged['tens'] >= 3).astype(int) * 2)
    df_merged['GameID'] = GameDF['GameID'].iloc[0]
    try:
        df_merged['InjTeamateCount'] = df_merged['TeamAbv'].map(team_inactive_counts)
    except:
        df_merged['InjTeamateCount'] = 0
    df_merged['Top7InTeam'] = df_merged['Top7InTeam'].apply(lambda x: False if x == 0 else x)
    
    df_merged = df_merged[['Date','Starters','TeamName','WonGame','Injured','DidNotPlay','FantasyPoints','MPTimeDelta','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','GmSc','+/-','TeamAbv','Year','Day','Month#','MonthName','Day_of_week','Home','GamePointDiff','Start(ET)','Overtime','Attend.','InSeasonTournament','GameID','OpponentTeam','OpponentTeamAbv','InjTeamateCount', 'Starting','Top7InTeam']]
    #df_merged = df_merged.rename(columns = {
    #    'Starters'
    #    
    #})
    
    
    return df_merged

#stats = player_scores_game(smalldfdf)

# %%
def get_game_dates(year, month):  
    session = requests.Session()
    #print(year, month)
    URL = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html'
    #print(URL)
    response = session.get(URL)
    #print(response.status_code)
    soup = BeautifulSoup(response.text, features="html.parser")
    soup.prettify()
    tables = soup.find_all('table')
    #print(len(tables))
    table_html = str(tables[0])
    df = pd.read_html(io.StringIO(table_html))[0]
    df = df[~(df == 'Playoffs').all(axis=1)]
    df['PTS'] = pd.to_numeric(df['PTS'], errors='coerce').astype('Int64')
    df['PTS.1'] = pd.to_numeric(df['PTS.1'], errors='coerce').astype('Int64')
    df['Attend.'] = pd.to_numeric(df['Attend.'], errors='coerce').astype('Int64')
    
    #print(year,month)
    #print(df)
#     print(df['Date'])
#     print("BEFORE BEFORE BEFORE BEFORE ERROR") 
    df['Date'] = pd.to_datetime(df['Date'])
    #print("AFTER AFTER AFTER AFTER AFTER ERROR")
    df['Year'] = df['Date'].dt.year
    df['Day'] = df['Date'].dt.day.astype(str).str.zfill(2)
    df['Month#'] = df['Date'].dt.month
    df['MonthName'] = df['Date'].dt.month_name().str.lower()
    df['GameFinished'] = df['Date'] < (pd.Timestamp('today') - pd.Timedelta(days=1))
    
    if year > 2000:
        
        df = df.rename(columns = {
            'Visitor/Neutral':'AwayTeam',
            'PTS':'AwayPTS',
            'PTS.1':'HomePTS',
            'Home/Neutral' : 'HomeTeam',
            'Unnamed: 7' : 'Overtime',
            'Notes':'InSeasonTournament'
        })
        
        df = df.drop(['Unnamed: 6', 'LOG','Arena'], axis = 1)
    
    else:
        df = df.rename(columns = {
            'Visitor/Neutral':'AwayTeam',
            'PTS':'AwayPTS',
            'PTS.1':'HomePTS',
            'Home/Neutral' : 'HomeTeam',
            'Unnamed: 6' : 'Overtime',
            'Notes':'InSeasonTournament'
        })
        
        df = df.drop(['Unnamed: 5', 'LOG','Arena'], axis = 1)

    df['Overtime'] = df['Overtime'].apply(lambda x: True if x == 'OT' else False)
    df['HomeTeamAbv'] = df['HomeTeam'].map(nba_team_abbreviations)
    df['AwayTeamAbv'] = df['AwayTeam'].map(nba_team_abbreviations)
    df['HomeWin'] = df['HomePTS'] > df['AwayPTS']
    df['AwayWin'] = df['AwayPTS'] > df['HomePTS']
    df['HomePointDiff'] = df['HomePTS'] - df['AwayPTS']
    df['AwayPointDiff'] = df['AwayPTS'] - df['HomePTS']
    df['GameID'] = df['Year'].astype(str) + df['Day'].astype(str) + df['Month#'].astype(str) + df['HomeTeamAbv']

    df['InSeasonTournament'] = df['InSeasonTournament'].apply(lambda x: True if x == 'In-Season Tournament' else False)

    
    return df

# %%
messed_up = get_game_dates(2001,'november')
# Out:
# 2001 november
#                   Date Start (ET)     Visitor/Neutral  PTS  \
# 0     Wed, Nov 1, 2000      7:00p     Detroit Pistons   83
# 1     Wed, Nov 1, 2000      7:00p     Toronto Raptors   98
# 2     Wed, Nov 1, 2000      7:30p  Washington Wizards   95
# 3     Wed, Nov 1, 2000      7:30p    Sacramento Kings  100
# 4     Wed, Nov 1, 2000      8:00p       Orlando Magic   79
# ..                 ...        ...                 ...  ...
# 204  Thu, Nov 30, 2000      8:00p      Boston Celtics   97
# 205  Thu, Nov 30, 2000      9:00p     Houston Rockets  109
# 206  Thu, Nov 30, 2000     10:00p    Dallas Mavericks   84
# 207  Thu, Nov 30, 2000     10:00p  Los Angeles Lakers   88
# 208  Thu, Nov 30, 2000     10:30p      Indiana Pacers   95
#
#                Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.   LOG  \
# 0            Boston Celtics    103  Box Score        NaN    17725  2:21
# 1        Philadelphia 76ers    104  Box Score        NaN    19817   NaN
# 2         Charlotte Hornets     77  Box Score        NaN    16043   NaN
# 3       Cleveland Cavaliers    102  Box Score        2OT    17695   NaN
# 4                Miami Heat    105  Box Score        NaN    16500   NaN
# ..                      ...    ...        ...        ...      ...   ...
# 204         Milwaukee Bucks    108  Box Score        NaN    13247  2:04
# 205          Denver Nuggets    105  Box Score         OT    13684   NaN
# 206  Portland Trail Blazers     95  Box Score        NaN    19980   NaN
# 207     Seattle SuperSonics    121  Box Score        NaN    17072   NaN
# 208   Golden State Warriors     99  Box Score        NaN    13149   NaN
#
#                           Arena  Notes
# 0                   FleetCenter    NaN
# 1            First Union Center    NaN
# 2            Charlotte Coliseum    NaN
# 3                    Gund Arena    NaN
# 4        AmericanAirlines Arena    NaN
# ..                          ...    ...
# 204              Bradley Center    NaN
# 205                Pepsi Center    NaN
# 206           Rose Garden Arena    NaN
# 207  KeyArena at Seattle Center    NaN
# 208        The Arena in Oakland    NaN
#
# [209 rows x 12 columns]

# %%
normal = get_game_dates(2000,'november')
# Out:
# 2000 november
#                   Date        Visitor/Neutral  PTS          Home/Neutral  \
# 0     Tue, Nov 2, 1999          Orlando Magic   86     Charlotte Hornets
# 1     Tue, Nov 2, 1999  Golden State Warriors   96      Dallas Mavericks
# 2     Tue, Nov 2, 1999           Phoenix Suns  102        Denver Nuggets
# 3     Tue, Nov 2, 1999        Milwaukee Bucks   98       Houston Rockets
# 4     Tue, Nov 2, 1999    Seattle SuperSonics  104  Los Angeles Clippers
# ..                 ...                    ...  ...                   ...
# 204  Tue, Nov 30, 1999       Sacramento Kings  111         Orlando Magic
# 205  Tue, Nov 30, 1999        New York Knicks   70    Philadelphia 76ers
# 206  Tue, Nov 30, 1999        Detroit Pistons   87     San Antonio Spurs
# 207  Tue, Nov 30, 1999     Los Angeles Lakers  101   Seattle SuperSonics
# 208  Tue, Nov 30, 1999          Atlanta Hawks  107       Toronto Raptors
#
#      PTS.1 Unnamed: 5 Unnamed: 6  Attend.  LOG                       Arena  \
# 0      100  Box Score        NaN    17461  NaN          Charlotte Coliseum
# 1      108  Box Score        NaN    12848  NaN               Reunion Arena
# 2      107  Box Score         OT    19099  NaN                Pepsi Center
# 3       93  Box Score        NaN    14491  NaN               Compaq Center
# 4       92  Box Score        NaN    17847  NaN              STAPLES Center
# ..     ...        ...        ...      ...  ...                         ...
# 204    102  Box Score        NaN    14439  NaN        TD Waterhouse Centre
# 205     74  Box Score        NaN    17420  NaN          First Union Center
# 206    106  Box Score        NaN    18328  NaN                   Alamodome
# 207     77  Box Score        NaN    17072  NaN  KeyArena at Seattle Center
# 208     89  Box Score        NaN    16862  NaN           Air Canada Centre
#
#     Notes
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 204   NaN
# 205   NaN
# 206   NaN
# 207   NaN
# 208   NaN
#
# [209 rows x 11 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Overtime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 normal = get_game_dates(2000,'november')
#
# Cell In[31], line 40, in get_game_dates(year, month)
#      31 df = df.rename(columns = {
#      32     'Visitor/Neutral':'AwayTeam',
#      33     'PTS':'AwayPTS',
#    (...)
#      37     'Notes':'InSeasonTournament'
#      38 })
#      39 df = df.drop(['Unnamed: 6', 'LOG','Arena'], axis = 1)
# ---> 40 df['Overtime'] = df['Overtime'].apply(lambda x: True if x == 'OT' else False)
#      41 df['HomeTeamAbv'] = df['HomeTeam'].map(nba_team_abbreviations)
#      42 df['AwayTeamAbv'] = df['AwayTeam'].map(nba_team_abbreviations)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Overtime'

# %%
def get_game_dates_months(year):  
    session = requests.Session()
    
    URL = f'https://www.basketball-reference.com/leagues/NBA_{year}_games.html'
    response = session.get(URL)
    response.status_code
    soup = BeautifulSoup(response.text, features="html.parser")

    filter_div = soup.find('div', {"class": "filter"})


    month_links = filter_div.find_all('a')


    months = [link.text.lower().replace(' ', '-') for link in month_links]
    
    return months

# %%
get_game_dates(2019, 'march')
# Out:
#           Date Start (ET)                AwayTeam  AwayPTS  \
# 0   2019-03-01      7:30p           Chicago Bulls      168
# 1   2019-03-01      7:30p       Charlotte Hornets      123
# 2   2019-03-01      8:00p      Washington Wizards       96
# 3   2019-03-01      8:00p  Portland Trail Blazers      117
# 4   2019-03-01      9:00p    New Orleans Pelicans      130
# ..         ...        ...                     ...      ...
# 219 2019-03-31      6:00p      Los Angeles Lakers      130
# 220 2019-03-31      7:00p        Sacramento Kings      113
# 221 2019-03-31      8:00p      Washington Wizards       95
# 222 2019-03-31      8:30p       Charlotte Hornets       90
# 223 2019-03-31     10:30p       Memphis Grizzlies       96
#
#                   HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 0            Atlanta Hawks      161     False    15267               False
# 1            Brooklyn Nets      112     False    15578               False
# 2           Boston Celtics      107     False    18624               False
# 3          Toronto Raptors      119     False    19800               False
# 4             Phoenix Suns      116     False    14123               False
# ..                     ...      ...       ...      ...                 ...
# 219   New Orleans Pelicans      102     False    18562               False
# 220      San Antonio Spurs      106     False    18407               False
# 221         Denver Nuggets       90     False    17356               False
# 222  Golden State Warriors      137     False    19596               False
# 223   Los Angeles Clippers      113     False    16740               False
#
#      Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv  \
# 0    2019  ...      3      march         True          ATL         CHI
# 1    2019  ...      3      march         True          BRK         CHO
# 2    2019  ...      3      march         True          BOS         WAS
# 3    2019  ...      3      march         True          TOR         POR
# 4    2019  ...      3      march         True          PHO         NOP
# ..    ...  ...    ...        ...          ...          ...         ...
# 219  2019  ...      3      march         True          NOP         LAL
# 220  2019  ...      3      march         True          SAS         SAC
# 221  2019  ...      3      march         True          DEN         WAS
# 222  2019  ...      3      march         True          GSW         CHO
# 223  2019  ...      3      march         True          LAC         MEM
#
#     HomeWin  AwayWin  HomePointDiff  AwayPointDiff      GameID
# 0     False     True             -7              7  2019013ATL
# 1     False     True            -11             11  2019013BRK
# 2      True    False             11            -11  2019013BOS
# 3      True    False              2             -2  2019013TOR
# 4     False     True            -14             14  2019013PHO
# ..      ...      ...            ...            ...         ...
# 219   False     True            -28             28  2019313NOP
# 220   False     True             -7              7  2019313SAS
# 221   False     True             -5              5  2019313DEN
# 222    True    False             47            -47  2019313GSW
# 223    True    False             17            -17  2019313LAC
#
# [224 rows x 21 columns]

# %%
get_game_dates_months(2019)
# Out:
# ['october',
#  'november',
#  'december',
#  'january',
#  'february',
#  'march',
#  'april',
#  'may',
#  'june']

# %%
def all_games_season(year):
    months = get_game_dates_months(year)
    total_df = pd.DataFrame()
    all_dataframes = []
    for month in months:
        time.sleep(5)
        df = get_game_dates(year, month)
        all_dataframes.append(df)
    
    total_df = pd.concat(all_dataframes)
    
    return total_df

# %%
def final_df(year,existing_df,numaddrows, add_all):
    
    all_games_df = all_games_season(year)
    try:
        
        all_games_df = all_games_df[~all_games_df['GameID'].isin(existing_df['GameID'])]
    except:
        pass
    
    all_games_df = all_games_df[all_games_df['GameFinished'] == True]
    total_df = existing_df
    
    if add_all:
        for i in range(len(all_games_df)):
            game_df = player_scores_game(all_games_df.iloc[[i]])
            total_df = pd.concat([total_df, game_df], ignore_index=True, sort=False)
            time.sleep(4.15)
            print(f'Done with game #{i}')
            print(all_games_df.iloc[[i]])
    else:
        for i in range(numaddrows):
            game_df = player_scores_game(all_games_df.iloc[[i]])
            total_df = pd.concat([total_df, game_df], ignore_index=True, sort=False)
            time.sleep(4.15)
            print(f'Done with game #{i}')
            print(all_games_df.iloc[[i]])

    
    return total_df


#stats_2025 = final_df(2025)

# %%
def update_full_data_new(rows_to_add = 10, add_all = False, datayear = 2025):
    try: 
        existing_dataframe = pd.read_csv(f"../data/full_nba_data{datayear}.csv")
    except:
        existing_dataframe = pd.DataFrame()

    
        
    new_df = final_df(datayear, existing_dataframe, rows_to_add, add_all)
    new_df['Date'] = pd.to_datetime(new_df['Date'], format = 'mixed')

    new_df = new_df[['Date','Starters','TeamName','WonGame','Injured','DidNotPlay','FantasyPoints','MPTimeDelta','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','GmSc','+/-','TeamAbv','Year','Day','Month#','MonthName','Day_of_week','Home','GamePointDiff','Start(ET)','Overtime','Attend.','InSeasonTournament','GameID','OpponentTeam','OpponentTeamAbv','InjTeamateCount', 'Starting','Top7InTeam']]
    
    new_df.to_csv(f'../data/full_nba_data{datayear}.csv')
    return new_df

# %%
new_df_2 = update_full_data_new(datayear = 2007, rows_to_add = 1)
new_df_2
# Out:
# https://www.basketball-reference.com/boxscores/200611050SEA.html
# Done with game #0
#          Date Start (ET)            AwayTeam  AwayPTS             HomeTeam  \
# 41 2006-11-05      9:00p  Los Angeles Lakers      101  Seattle SuperSonics
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 41      117     False    17072               False  2006  ...     11
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 41   november         True          SEA         LAL    True    False
#
#     HomePointDiff  AwayPointDiff       GameID
# 41             16            -16  20060511SEA
#
# [1 rows x 21 columns]
#            Date           Starters             TeamName  WonGame  Injured  \
# 0    2006-10-31       Kirk Hinrich        Chicago Bulls     True    False
# 1    2006-10-31        Ben Wallace        Chicago Bulls     True    False
# 2    2006-10-31          Luol Deng        Chicago Bulls     True    False
# 3    2006-10-31         Ben Gordon        Chicago Bulls     True    False
# 4    2006-10-31         P.J. Brown        Chicago Bulls     True    False
# ...         ...                ...                  ...      ...      ...
# 1263 2006-11-05      Nick Collison  Seattle SuperSonics     True    False
# 1264 2006-11-05      Danny Fortson  Seattle SuperSonics     True    False
# 1265 2006-11-05      Mouhamed Sene  Seattle SuperSonics     True    False
# 1266 2006-11-05  MickaÃ«l Gelabale  Seattle SuperSonics     True    False
# 1267 2006-11-05         Mike Wilks  Seattle SuperSonics     True    False
#
#       DidNotPlay  FantasyPoints      MPTimeDelta     MP  FG  ... Start(ET)  \
# 0          False           25.5  0 days 00:34:38  34:38  10  ...     8:00p
# 1          False           16.5  0 days 00:28:29  28:29   2  ...     8:00p
# 2          False            8.0  0 days 00:24:07  24:07   4  ...     8:00p
# 3          False            6.0  0 days 00:22:56  22:56   1  ...     8:00p
# 4          False            8.0  0 days 00:18:23  18:23   1  ...     8:00p
# ...          ...            ...              ...    ...  ..  ...       ...
# 1263       False            4.0  0 days 00:14:49  14:49   1  ...     9:00p
# 1264       False            0.0  0 days 00:09:25   9:25   0  ...     9:00p
# 1265       False            1.0  0 days 00:00:53   0:53   0  ...     9:00p
# 1266       False            0.0  0 days 00:00:43   0:43   0  ...     9:00p
# 1267       False            0.0  0 days 00:00:43   0:43   0  ...     9:00p
#
#      Overtime  Attend. InSeasonTournament       GameID        OpponentTeam  \
# 0       False    20229              False  20063110MIA          Miami Heat
# 1       False    20229              False  20063110MIA          Miami Heat
# 2       False    20229              False  20063110MIA          Miami Heat
# 3       False    20229              False  20063110MIA          Miami Heat
# 4       False    20229              False  20063110MIA          Miami Heat
# ...       ...      ...                ...          ...                 ...
# 1263    False    17072              False  20060511SEA  Los Angeles Lakers
# 1264    False    17072              False  20060511SEA  Los Angeles Lakers
# 1265    False    17072              False  20060511SEA  Los Angeles Lakers
# 1266    False    17072              False  20060511SEA  Los Angeles Lakers
# 1267    False    17072              False  20060511SEA  Los Angeles Lakers
#
#      OpponentTeamAbv InjTeamateCount Starting Top7InTeam
# 0                MIA             3.0     True       True
# 1                MIA             3.0     True       True
# 2                MIA             3.0     True       True
# 3                MIA             3.0     True       True
# 4                MIA             3.0     True       True
# ...              ...             ...      ...        ...
# 1263             LAL             0.0    False      False
# 1264             LAL             0.0    False      False
# 1265             LAL             0.0    False      False
# 1266             LAL             0.0    False      False
# 1267             LAL             0.0    False      False
#
# [1268 rows x 47 columns]

# %%
new_df_2[new_df_2['GameID'] == '20060511SEA']
# Out:
#            Date              Starters             TeamName  WonGame  Injured  \
# 1244 2006-11-05           Kobe Bryant   Los Angeles Lakers    False    False
# 1245 2006-11-05            Lamar Odom   Los Angeles Lakers    False    False
# 1246 2006-11-05          Smush Parker   Los Angeles Lakers    False    False
# 1247 2006-11-05           Luke Walton   Los Angeles Lakers    False    False
# 1248 2006-11-05          Andrew Bynum   Los Angeles Lakers    False    False
# 1249 2006-11-05  Vladimir RadmanoviÄ   Los Angeles Lakers    False    False
# 1250 2006-11-05         Jordan Farmar   Los Angeles Lakers    False    False
# 1251 2006-11-05          Ronny Turiaf   Los Angeles Lakers    False    False
# 1252 2006-11-05            Brian Cook   Los Angeles Lakers    False    False
# 1253 2006-11-05         Maurice Evans   Los Angeles Lakers    False    False
# 1254 2006-11-05       Sasha VujaÄiÄ   Los Angeles Lakers    False    False
# 1255 2006-11-05     Shammond Williams   Los Angeles Lakers    False    False
# 1256 2006-11-05         Rashard Lewis  Seattle SuperSonics     True    False
# 1257 2006-11-05          Luke Ridnour  Seattle SuperSonics     True    False
# 1258 2006-11-05             Ray Allen  Seattle SuperSonics     True    False
# 1259 2006-11-05          Chris Wilcox  Seattle SuperSonics     True    False
# 1260 2006-11-05           Johan Petro  Seattle SuperSonics     True    False
# 1261 2006-11-05        Damien Wilkins  Seattle SuperSonics     True    False
# 1262 2006-11-05           Earl Watson  Seattle SuperSonics     True    False
# 1263 2006-11-05         Nick Collison  Seattle SuperSonics     True    False
# 1264 2006-11-05         Danny Fortson  Seattle SuperSonics     True    False
# 1265 2006-11-05         Mouhamed Sene  Seattle SuperSonics     True    False
# 1266 2006-11-05     MickaÃ«l Gelabale  Seattle SuperSonics     True    False
# 1267 2006-11-05            Mike Wilks  Seattle SuperSonics     True    False
#
#       DidNotPlay  FantasyPoints      MPTimeDelta     MP  FG  ... Start(ET)  \
# 1244       False           19.5  0 days 00:39:03  39:03   4  ...     9:00p
# 1245       False           13.5  0 days 00:34:54  34:54   3  ...     9:00p
# 1246       False            4.0  0 days 00:26:15  26:15   2  ...     9:00p
# 1247       False           19.5  0 days 00:25:49  25:49   4  ...     9:00p
# 1248       False            8.5  0 days 00:18:56  18:56   5  ...     9:00p
# 1249       False           15.0  0 days 00:23:27  23:27   4  ...     9:00p
# 1250       False            9.5  0 days 00:18:10  18:10   5  ...     9:00p
# 1251       False            4.5  0 days 00:15:03  15:03   2  ...     9:00p
# 1252       False           15.5  0 days 00:14:01  14:01   4  ...     9:00p
# 1253       False            1.0  0 days 00:11:39  11:39   0  ...     9:00p
# 1254       False            5.0  0 days 00:09:32   9:32   2  ...     9:00p
# 1255       False            0.0  0 days 00:03:11   3:11   0  ...     9:00p
# 1256       False           29.5  0 days 00:39:32  39:32   8  ...     9:00p
# 1257       False           21.0  0 days 00:36:53  36:53   9  ...     9:00p
# 1258       False           27.5  0 days 00:35:59  35:59  10  ...     9:00p
# 1259       False           20.0  0 days 00:35:03  35:03   4  ...     9:00p
# 1260       False           10.0  0 days 00:24:16  24:16   3  ...     9:00p
# 1261       False            6.0  0 days 00:22:29  22:29   2  ...     9:00p
# 1262       False           21.5  0 days 00:19:15  19:15   4  ...     9:00p
# 1263       False            4.0  0 days 00:14:49  14:49   1  ...     9:00p
# 1264       False            0.0  0 days 00:09:25   9:25   0  ...     9:00p
# 1265       False            1.0  0 days 00:00:53   0:53   0  ...     9:00p
# 1266       False            0.0  0 days 00:00:43   0:43   0  ...     9:00p
# 1267       False            0.0  0 days 00:00:43   0:43   0  ...     9:00p
#
#      Overtime  Attend. InSeasonTournament       GameID         OpponentTeam  \
# 1244    False    17072              False  20060511SEA  Seattle SuperSonics
# 1245    False    17072              False  20060511SEA  Seattle SuperSonics
# 1246    False    17072              False  20060511SEA  Seattle SuperSonics
# 1247    False    17072              False  20060511SEA  Seattle SuperSonics
# 1248    False    17072              False  20060511SEA  Seattle SuperSonics
# 1249    False    17072              False  20060511SEA  Seattle SuperSonics
# 1250    False    17072              False  20060511SEA  Seattle SuperSonics
# 1251    False    17072              False  20060511SEA  Seattle SuperSonics
# 1252    False    17072              False  20060511SEA  Seattle SuperSonics
# 1253    False    17072              False  20060511SEA  Seattle SuperSonics
# 1254    False    17072              False  20060511SEA  Seattle SuperSonics
# 1255    False    17072              False  20060511SEA  Seattle SuperSonics
# 1256    False    17072              False  20060511SEA   Los Angeles Lakers
# 1257    False    17072              False  20060511SEA   Los Angeles Lakers
# 1258    False    17072              False  20060511SEA   Los Angeles Lakers
# 1259    False    17072              False  20060511SEA   Los Angeles Lakers
# 1260    False    17072              False  20060511SEA   Los Angeles Lakers
# 1261    False    17072              False  20060511SEA   Los Angeles Lakers
# 1262    False    17072              False  20060511SEA   Los Angeles Lakers
# 1263    False    17072              False  20060511SEA   Los Angeles Lakers
# 1264    False    17072              False  20060511SEA   Los Angeles Lakers
# 1265    False    17072              False  20060511SEA   Los Angeles Lakers
# 1266    False    17072              False  20060511SEA   Los Angeles Lakers
# 1267    False    17072              False  20060511SEA   Los Angeles Lakers
#
#      OpponentTeamAbv InjTeamateCount Starting Top7InTeam
# 1244             SEA             0.0     True       True
# 1245             SEA             0.0     True       True
# 1246             SEA             0.0     True       True
# 1247             SEA             0.0     True       True
# 1248             SEA             0.0     True       True
# 1249             SEA             0.0    False       True
# 1250             SEA             0.0    False       True
# 1251             SEA             0.0    False      False
# 1252             SEA             0.0    False      False
# 1253             SEA             0.0    False      False
# 1254             SEA             0.0    False      False
# 1255             SEA             0.0    False      False
# 1256             LAL             0.0     True       True
# 1257             LAL             0.0     True       True
# 1258             LAL             0.0     True       True
# 1259             LAL             0.0     True       True
# 1260             LAL             0.0     True       True
# 1261             LAL             0.0    False       True
# 1262             LAL             0.0    False       True
# 1263             LAL             0.0    False      False
# 1264             LAL             0.0    False      False
# 1265             LAL             0.0    False      False
# 1266             LAL             0.0    False      False
# 1267             LAL             0.0    False      False
#
# [24 rows x 47 columns]

# %%
def get_player_names(nba_data):
    unique_names = nba_data['Starters'].unique()
    return list(unique_names)

get_player_names(new_df_2)

# %%
# for i in range(35):
#     new_df_2 = update_full_data_new(datayear = 2014, rows_to_add = 14, add_all = False)
#     print(f"RESET DONE WITH LOOP #{i+1}")
#     print("                            ")
#     print("//%/%?%?%?%/%?%?%?%?/%?///%%")
#     print("                            ")
#     print("//%/%?%?%?%/%?%?%?%?/%?///%%")
#     print("                            ")
#     print("//%/%?%?%?%/%?%?%?%?/%?///%%")
#     print("                            ")
#     print("//%/%?%?%?%/%?%?%?%?/%?///%%")
#     print("                            ")
#     print("//%/%?%?%?%/%?%?%?%?/%?///%%")

# %%
for j in [2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995]:
    
    
    
    for i in range(100):
        try:      
            new_df_2 = update_full_data_new(datayear = j, rows_to_add = 14, add_all = False)
        except:
            break

    
    new_df_2 = update_full_data_new(datayear = j, rows_to_add = 17, add_all = True)
# Out:
# https://www.basketball-reference.com/boxscores/200702210MIN.html
# Done with game #0
#           Date Start (ET)           AwayTeam  AwayPTS                HomeTeam  \
# 120 2007-02-21      8:00p  Charlotte Bobcats      100  Minnesota Timberwolves
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 120       95     False    16576               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 120   february         True          MIN         CHA   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 120             -5              5  2007212MIN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702210HOU.html
# Done with game #1
#           Date Start (ET)    AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 121 2007-02-21      9:00p  Miami Heat      102  Houston Rockets      112
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 121     False    18324               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 121         True          HOU         MIA    True    False             10
#
#      AwayPointDiff      GameID
# 121            -10  2007212HOU
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702210PHO.html
# Done with game #2
#           Date Start (ET)        AwayTeam  AwayPTS      HomeTeam  HomePTS  \
# 122 2007-02-21      9:00p  Boston Celtics      108  Phoenix Suns      118
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 122     False    18422               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 122         True          PHO         BOS    True    False             10
#
#      AwayPointDiff      GameID
# 122            -10  2007212PHO
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702210GSW.html
# Done with game #3
#           Date Start (ET)           AwayTeam  AwayPTS               HomeTeam  \
# 123 2007-02-21     10:30p  Memphis Grizzlies      115  Golden State Warriors
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 123      118      True    16967               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 123   february         True          GSW         MEM    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 123              3             -3  2007212GSW
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702210LAL.html
# Done with game #4
#           Date Start (ET)                AwayTeam  AwayPTS  \
# 124 2007-02-21     10:30p  Portland Trail Blazers      112
#
#                HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  Year  \
# 124  Los Angeles Lakers      108     False    18997               False  2007
#
#      ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  \
# 124  ...      2   february         True          LAL         POR   False
#
#      AwayWin  HomePointDiff  AwayPointDiff      GameID
# 124     True             -4              4  2007212LAL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702220CLE.html
# Done with game #5
#           Date Start (ET)       AwayTeam  AwayPTS             HomeTeam  \
# 125 2007-02-22      7:00p  Chicago Bulls       84  Cleveland Cavaliers
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 125       78     False    20562               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 125   february         True          CLE         CHI   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 125             -6              6  2007222CLE
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702220WAS.html
# Done with game #6
#           Date Start (ET)          AwayTeam  AwayPTS            HomeTeam  \
# 126 2007-02-22      7:00p  Sacramento Kings      106  Washington Wizards
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 126      109     False    15508               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 126   february         True          WAS         SAC    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 126              3             -3  2007222WAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702220DAL.html
# Done with game #7
#           Date Start (ET)    AwayTeam  AwayPTS          HomeTeam  HomePTS  \
# 127 2007-02-22      9:30p  Miami Heat      100  Dallas Mavericks      112
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 127     False    20448               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 127         True          DAL         MIA    True    False             12
#
#      AwayPointDiff      GameID
# 127            -12  2007222DAL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230CHA.html
# Done with game #8
#           Date Start (ET)            AwayTeam  AwayPTS           HomeTeam  \
# 128 2007-02-23      7:00p  Philadelphia 76ers       87  Charlotte Bobcats
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 128      102     False    15781               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 128   february         True          CHA         PHI    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 128             15            -15  2007232CHA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230ORL.html
# Done with game #9
#           Date Start (ET)         AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 129 2007-02-23      7:00p  Detroit Pistons       94  Orlando Magic       89
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 129     False    17451               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 129         True          ORL         DET   False     True             -5
#
#      AwayPointDiff      GameID
# 129              5  2007232ORL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230TOR.html
# Done with game #10
#           Date Start (ET)        AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 130 2007-02-23      7:00p  Indiana Pacers       88  Toronto Raptors      110
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 130     False    19481               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 130         True          TOR         IND    True    False             22
#
#      AwayPointDiff      GameID
# 130            -22  2007232TOR
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230ATL.html
# Done with game #11
#           Date Start (ET)         AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 131 2007-02-23      7:30p  Houston Rockets       99  Atlanta Hawks      105
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 131     False    16041               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 131         True          ATL         HOU    True    False              6
#
#      AwayPointDiff      GameID
# 131             -6  2007232ATL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230NJN.html
# Done with game #12
#           Date Start (ET)          AwayTeam  AwayPTS         HomeTeam  \
# 132 2007-02-23      7:30p  Sacramento Kings       96  New Jersey Nets
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 132      109     False    18902               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 132   february         True          NJN         SAC    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 132             13            -13  2007232NJN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230NYK.html
# Done with game #13
#           Date Start (ET)         AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 133 2007-02-23      7:30p  Milwaukee Bucks       93  New York Knicks       95
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 133     False    19763               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 133         True          NYK         MIL    True    False              2
#
#      AwayPointDiff      GameID
# 133             -2  2007232NYK
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230CHI.html
# Done with game #0
#           Date Start (ET)            AwayTeam  AwayPTS       HomeTeam  \
# 134 2007-02-23      8:00p  Washington Wizards       90  Chicago Bulls
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 134      105     False    22618               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 134   february         True          CHI         WAS    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 134             15            -15  2007232CHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230MIN.html
# Done with game #1
#           Date Start (ET)      AwayTeam  AwayPTS                HomeTeam  \
# 135 2007-02-23      8:00p  Phoenix Suns      116  Minnesota Timberwolves
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 135      104     False    20196               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 135   february         True          MIN         PHO   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 135            -12             12  2007232MIN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230NOK.html
# Done with game #2
#           Date Start (ET)             AwayTeam  AwayPTS  \
# 136 2007-02-23      8:00p  Seattle SuperSonics       97
#
#                               HomeTeam  HomePTS  Overtime  Attend.  \
# 136  New Orleans/Oklahoma City Hornets       98     False    17961
#
#      InSeasonTournament  Year  ... Month#  MonthName GameFinished  \
# 136               False  2007  ...      2   february         True
#
#      HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  AwayPointDiff  \
# 136          NOK         SEA    True    False              1             -1
#
#          GameID
# 136  2007232NOK
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230POR.html
# Done with game #3
#           Date Start (ET)           AwayTeam  AwayPTS                HomeTeam  \
# 137 2007-02-23     10:00p  Memphis Grizzlies      103  Portland Trail Blazers
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 137      102     False    14875               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 137   february         True          POR         MEM   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 137             -1              1  2007232POR
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230DEN.html
# Done with game #4
#           Date Start (ET)   AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 138 2007-02-23     10:30p  Utah Jazz      114  Denver Nuggets      104
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 138     False    19565               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 138         True          DEN         UTA   False     True            -10
#
#      AwayPointDiff      GameID
# 138             10  2007232DEN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702230LAL.html
# Done with game #5
#           Date Start (ET)        AwayTeam  AwayPTS            HomeTeam  \
# 139 2007-02-23     10:30p  Boston Celtics       96  Los Angeles Lakers
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 139      122     False    18997               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 139   february         True          LAL         BOS    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 139             26            -26  2007232LAL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702240LAC.html
# Done with game #6
#           Date Start (ET)               AwayTeam  AwayPTS  \
# 140 2007-02-24      3:30p  Golden State Warriors       90
#
#                  HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 140  Los Angeles Clippers      103     False    19060               False
#
#      Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv  \
# 140  2007  ...      2   february         True          LAC         GSW
#
#     HomeWin  AwayWin  HomePointDiff  AwayPointDiff      GameID
# 140    True    False             13            -13  2007242LAC
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702240CHA.html
# Done with game #7
#           Date Start (ET)         AwayTeam  AwayPTS           HomeTeam  \
# 141 2007-02-24      7:00p  Toronto Raptors       93  Charlotte Bobcats
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 141       76     False    17091               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 141   february         True          CHA         TOR   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 141            -17             17  2007242CHA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702240SAS.html
# Done with game #8
#           Date Start (ET)             AwayTeam  AwayPTS           HomeTeam  \
# 142 2007-02-24      8:00p  Seattle SuperSonics       71  San Antonio Spurs
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 142      102     False    18797               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 142   february         True          SAS         SEA    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 142             31            -31  2007242SAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702240MIL.html
# Done with game #9
#           Date Start (ET)            AwayTeam  AwayPTS         HomeTeam  \
# 143 2007-02-24      8:30p  Philadelphia 76ers       90  Milwaukee Bucks
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 143      109     False    16978               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 143   february         True          MIL         PHI    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 143             19            -19  2007242MIL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702240DAL.html
# Done with game #10
#           Date Start (ET)        AwayTeam  AwayPTS          HomeTeam  HomePTS  \
# 144 2007-02-24      9:00p  Denver Nuggets       95  Dallas Mavericks      115
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 144     False    20455               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 144         True          DAL         DEN    True    False             20
#
#      AwayPointDiff      GameID
# 144            -20  2007242DAL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702240UTA.html
# Done with game #11
#           Date Start (ET)        AwayTeam  AwayPTS   HomeTeam  HomePTS  \
# 145 2007-02-24      9:00p  Boston Celtics       87  Utah Jazz      105
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 145     False    19911               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 145         True          UTA         BOS    True    False             18
#
#      AwayPointDiff      GameID
# 145            -18  2007242UTA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250DET.html
# Done with game #12
#           Date Start (ET)       AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 146 2007-02-25      1:00p  Chicago Bulls       93  Detroit Pistons       95
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 146     False    22076               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 146         True          DET         CHI    True    False              2
#
#      AwayPointDiff      GameID
# 146             -2  2007252DET
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250ORL.html
# Done with game #13
#           Date Start (ET)         AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 147 2007-02-25      2:00p  Houston Rockets       97  Orlando Magic       93
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 147     False    17451               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 147         True          ORL         HOU   False     True             -4
#
#      AwayPointDiff      GameID
# 147              4  2007252ORL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250MIA.html
# Done with game #0
#           Date Start (ET)             AwayTeam  AwayPTS    HomeTeam  HomePTS  \
# 148 2007-02-25      3:30p  Cleveland Cavaliers       81  Miami Heat       86
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 148     False    20255               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 148         True          MIA         CLE    True    False              5
#
#      AwayPointDiff      GameID
# 148             -5  2007252MIA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250MIN.html
# Done with game #1
#           Date Start (ET)            AwayTeam  AwayPTS  \
# 149 2007-02-25      3:30p  Washington Wizards       94
#
#                    HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 149  Minnesota Timberwolves       98     False    15347               False
#
#      Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv  \
# 149  2007  ...      2   february         True          MIN         WAS
#
#     HomeWin  AwayWin  HomePointDiff  AwayPointDiff      GameID
# 149    True    False              4             -4  2007252MIN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250ATL.html
# Done with game #2
#           Date Start (ET)      AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 150 2007-02-25      6:00p  Phoenix Suns      115  Atlanta Hawks      106
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 150     False    18022               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 150         True          ATL         PHO   False     True             -9
#
#      AwayPointDiff      GameID
# 150              9  2007252ATL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250GSW.html
# Done with game #3
#           Date Start (ET)            AwayTeam  AwayPTS               HomeTeam  \
# 151 2007-02-25      6:00p  Los Angeles Lakers      102  Golden State Warriors
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 151       85     False    20107               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 151   february         True          GSW         LAL   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 151            -17             17  2007252GSW
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250NJN.html
# Done with game #4
#           Date Start (ET)         AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 152 2007-02-25      6:00p  New York Knicks       92  New Jersey Nets      101
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 152     False    20032               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 152         True          NJN         NYK    True    False              9
#
#      AwayPointDiff      GameID
# 152             -9  2007252NJN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702250IND.html
# Done with game #5
#           Date Start (ET)          AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 153 2007-02-25      8:00p  Sacramento Kings      110  Indiana Pacers       93
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 153     False    12258               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 153         True          IND         SAC   False     True            -17
#
#      AwayPointDiff      GameID
# 153             17  2007252IND
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260PHI.html
# Done with game #6
#           Date Start (ET)          AwayTeam  AwayPTS            HomeTeam  \
# 154 2007-02-26      7:00p  Sacramento Kings       82  Philadelphia 76ers
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 154       89     False    11034               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 154   february         True          PHI         SAC    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 154              7             -7  2007262PHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260NYK.html
# Done with game #7
#           Date Start (ET)    AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 155 2007-02-26      7:30p  Miami Heat       93  New York Knicks       99
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 155     False    19763               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 155         True          NYK         MIA    True    False              6
#
#      AwayPointDiff      GameID
# 155             -6  2007262NYK
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260MEM.html
# Done with game #8
#           Date Start (ET)        AwayTeam  AwayPTS           HomeTeam  \
# 156 2007-02-26      8:00p  Denver Nuggets      111  Memphis Grizzlies
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 156      107     False    14736               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 156   february         True          MEM         DEN   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 156             -4              4  2007262MEM
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260SAS.html
# Done with game #9
#           Date Start (ET)         AwayTeam  AwayPTS           HomeTeam  \
# 157 2007-02-26      8:00p  Toronto Raptors       91  San Antonio Spurs
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 157      107     False    18563               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 157   february         True          SAS         TOR    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 157             16            -16  2007262SAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260CHI.html
# Done with game #10
#           Date Start (ET)       AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 158 2007-02-26      8:30p  Orlando Magic       94  Chicago Bulls       87
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 158     False    22031               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 158         True          CHI         ORL   False     True             -7
#
#      AwayPointDiff      GameID
# 158              7  2007262CHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260DAL.html
# Done with game #11
#           Date Start (ET)       AwayTeam  AwayPTS          HomeTeam  HomePTS  \
# 159 2007-02-26      8:30p  Atlanta Hawks       87  Dallas Mavericks      110
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 159     False    20245               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 159         True          DAL         ATL    True    False             23
#
#      AwayPointDiff      GameID
# 159            -23  2007262DAL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260HOU.html
# Done with game #12
#           Date Start (ET)        AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 160 2007-02-26      8:30p  Boston Celtics       77  Houston Rockets       72
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 160     False    14037               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 160         True          HOU         BOS   False     True             -5
#
#      AwayPointDiff      GameID
# 160              5  2007262HOU
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260UTA.html
# Done with game #13
#           Date Start (ET)            AwayTeam  AwayPTS   HomeTeam  HomePTS  \
# 161 2007-02-26      9:00p  Los Angeles Lakers      102  Utah Jazz       94
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 161     False    19911               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 161         True          UTA         LAL   False     True             -8
#
#      AwayPointDiff      GameID
# 161              8  2007262UTA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260SEA.html
# Done with game #0
#           Date Start (ET)                AwayTeam  AwayPTS  \
# 162 2007-02-26     10:00p  Portland Trail Blazers       73
#
#                 HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 162  Seattle SuperSonics       97     False    16538               False
#
#      Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv  \
# 162  2007  ...      2   february         True          SEA         POR
#
#     HomeWin  AwayWin  HomePointDiff  AwayPointDiff      GameID
# 162    True    False             24            -24  2007262SEA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702260LAC.html
# Done with game #1
#           Date Start (ET)           AwayTeam  AwayPTS              HomeTeam  \
# 163 2007-02-26     10:30p  Charlotte Bobcats       93  Los Angeles Clippers
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 163      100     False    18442               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 163   february         True          LAC         CHA    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 163              7             -7  2007262LAC
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702270CLE.html
# Done with game #2
#           Date Start (ET)                           AwayTeam  AwayPTS  \
# 164 2007-02-27      7:00p  New Orleans/Oklahoma City Hornets       89
#
#                 HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 164  Cleveland Cavaliers       97     False    19619               False
#
#      Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv  \
# 164  2007  ...      2   february         True          CLE         NOK
#
#     HomeWin  AwayWin  HomePointDiff  AwayPointDiff      GameID
# 164    True    False              8             -8  2007272CLE
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702270IND.html
# Done with game #3
#           Date Start (ET)      AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 165 2007-02-27      7:00p  Phoenix Suns      103  Indiana Pacers       92
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 165     False    13742               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 165         True          IND         PHO   False     True            -11
#
#      AwayPointDiff      GameID
# 165             11  2007272IND
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702270NJN.html
# Done with game #4
#           Date Start (ET)            AwayTeam  AwayPTS         HomeTeam  \
# 166 2007-02-27      7:30p  Washington Wizards      101  New Jersey Nets
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 166      113     False    15102               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 166   february         True          NJN         WAS    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 166             12            -12  2007272NJN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702270MIL.html
# Done with game #5
#           Date Start (ET)               AwayTeam  AwayPTS         HomeTeam  \
# 167 2007-02-27      8:00p  Golden State Warriors      101  Milwaukee Bucks
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 167      122     False    13409               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 167   february         True          MIL         GSW    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 167             21            -21  2007272MIL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702270MIN.html
# Done with game #6
#           Date Start (ET)          AwayTeam  AwayPTS                HomeTeam  \
# 168 2007-02-27      8:00p  Dallas Mavericks       91  Minnesota Timberwolves
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 168       65     False    13326               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 168   february         True          MIN         DAL   False     True
#
#      HomePointDiff  AwayPointDiff      GameID
# 168            -26             26  2007272MIN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280PHI.html
# Done with game #7
#           Date Start (ET)      AwayTeam  AwayPTS            HomeTeam  HomePTS  \
# 169 2007-02-28      7:00p  Phoenix Suns       94  Philadelphia 76ers       99
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 169     False    15914               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 169         True          PHI         PHO    True    False              5
#
#      AwayPointDiff      GameID
# 169             -5  2007282PHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280WAS.html
# Done with game #8
#           Date Start (ET)    AwayTeam  AwayPTS            HomeTeam  HomePTS  \
# 170 2007-02-28      7:00p  Miami Heat       92  Washington Wizards       83
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 170     False    20173               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 170         True          WAS         MIA   False     True             -9
#
#      AwayPointDiff      GameID
# 170              9  2007282WAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280BOS.html
# Done with game #9
#           Date Start (ET)         AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 171 2007-02-28      7:30p  New York Knicks       94  Boston Celtics      102
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 171     False    17003               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 171         True          BOS         NYK    True    False              8
#
#      AwayPointDiff      GameID
# 171             -8  2007282BOS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280MEM.html
# Done with game #10
#           Date Start (ET)   AwayTeam  AwayPTS           HomeTeam  HomePTS  \
# 172 2007-02-28      8:00p  Utah Jazz      104  Memphis Grizzlies       88
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 172     False    15117               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 172         True          MEM         UTA   False     True            -16
#
#      AwayPointDiff      GameID
# 172             16  2007282MEM
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280NOK.html
# Done with game #11
#           Date Start (ET)       AwayTeam  AwayPTS  \
# 173 2007-02-28      8:00p  Atlanta Hawks      100
#
#                               HomeTeam  HomePTS  Overtime  Attend.  \
# 173  New Orleans/Oklahoma City Hornets      107     False    17402
#
#      InSeasonTournament  Year  ... Month#  MonthName GameFinished  \
# 173               False  2007  ...      2   february         True
#
#      HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  AwayPointDiff  \
# 173          NOK         ATL    True    False              7             -7
#
#          GameID
# 173  2007282NOK
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280CHI.html
# Done with game #12
#           Date Start (ET)               AwayTeam  AwayPTS       HomeTeam  \
# 174 2007-02-28      8:30p  Golden State Warriors       83  Chicago Bulls
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 174      113     False    21814               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 174   february         True          CHI         GSW    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 174             30            -30  2007282CHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280HOU.html
# Done with game #13
#           Date Start (ET)         AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 175 2007-02-28      8:30p  Toronto Raptors      106  Houston Rockets       90
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 175     False    14071               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 175         True          HOU         TOR   False     True            -16
#
#      AwayPointDiff      GameID
# 175             16  2007282HOU
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280DEN.html
# Done with game #0
#           Date Start (ET)       AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 176 2007-02-28      9:00p  Orlando Magic      101  Denver Nuggets      111
#
#      Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 176     False    15371               False  2007  ...      2   february
#
#     GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 176         True          DEN         ORL    True    False             10
#
#      AwayPointDiff      GameID
# 176            -10  2007282DEN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280SAC.html
# Done with game #1
#           Date Start (ET)           AwayTeam  AwayPTS          HomeTeam  \
# 177 2007-02-28     10:00p  Charlotte Bobcats      120  Sacramento Kings
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 177      135     False    17317               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 177   february         True          SAC         CHA    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 177             15            -15  2007282SAC
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200702280LAC.html
# Done with game #2
#           Date Start (ET)             AwayTeam  AwayPTS              HomeTeam  \
# 178 2007-02-28     10:30p  Seattle SuperSonics       91  Los Angeles Clippers
#
#      HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 178       96     False    19317               False  2007  ...      2
#
#      MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 178   february         True          LAC         SEA    True    False
#
#      HomePointDiff  AwayPointDiff      GameID
# 178              5             -5  2007282LAC
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703010DAL.html
# Done with game #3
#         Date Start (ET)             AwayTeam  AwayPTS          HomeTeam  \
# 0 2007-03-01      8:00p  Cleveland Cavaliers       92  Dallas Mavericks
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 0       95     False    20428               False  2007  ...      3
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 0      march         True          DAL         CLE    True    False
#
#    HomePointDiff  AwayPointDiff      GameID
# 0              3             -3  2007013DAL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703010POR.html
# Done with game #4
#         Date Start (ET)           AwayTeam  AwayPTS                HomeTeam  \
# 1 2007-03-01     10:00p  Charlotte Bobcats       90  Portland Trail Blazers
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 1      127     False    15063               False  2007  ...      3
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 1      march         True          POR         CHA    True    False
#
#    HomePointDiff  AwayPointDiff      GameID
# 1             37            -37  2007013POR
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703010SEA.html
# Done with game #5
#         Date Start (ET)              AwayTeam  AwayPTS             HomeTeam  \
# 2 2007-03-01     10:30p  Los Angeles Clippers       75  Seattle SuperSonics
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 2       77     False    14601               False  2007  ...      3
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 2      march         True          SEA         LAC    True    False
#
#    HomePointDiff  AwayPointDiff      GameID
# 2              2             -2  2007013SEA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020PHI.html
# Done with game #6
#         Date Start (ET)           AwayTeam  AwayPTS            HomeTeam  \
# 3 2007-03-02      7:00p  Memphis Grizzlies      112  Philadelphia 76ers
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 3      117      True    16314               False  2007  ...      3
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 3      march         True          PHI         MEM    True    False
#
#    HomePointDiff  AwayPointDiff      GameID
# 3              5             -5  2007023PHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020TOR.html
# Done with game #7
#         Date Start (ET)         AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 4 2007-03-02      7:00p  Milwaukee Bucks       94  Toronto Raptors       81
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 4     False    18816               False  2007  ...      3      march
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 4         True          TOR         MIL   False     True            -13
#
#    AwayPointDiff      GameID
# 4             13  2007023TOR
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020WAS.html
# Done with game #8
#         Date Start (ET)       AwayTeam  AwayPTS            HomeTeam  HomePTS  \
# 5 2007-03-02      7:00p  Atlanta Hawks       92  Washington Wizards       93
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 5     False    20173               False  2007  ...      3      march
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 5         True          WAS         ATL    True    False              1
#
#    AwayPointDiff      GameID
# 5             -1  2007023WAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020NYK.html
# Done with game #9
#         Date Start (ET)               AwayTeam  AwayPTS         HomeTeam  \
# 6 2007-03-02      7:30p  Golden State Warriors       97  New York Knicks
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 6      106     False    19763               False  2007  ...      3
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 6      march         True          NYK         GSW    True    False
#
#    HomePointDiff  AwayPointDiff      GameID
# 6              9             -9  2007023NYK
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020MIA.html
# Done with game #10
#         Date Start (ET)         AwayTeam  AwayPTS    HomeTeam  HomePTS  \
# 7 2007-03-02      8:00p  Detroit Pistons       82  Miami Heat       85
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 7     False    20279               False  2007  ...      3      march
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 7         True          MIA         DET    True    False              3
#
#    AwayPointDiff      GameID
# 7             -3  2007023MIA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020MIN.html
# Done with game #11
#         Date Start (ET)   AwayTeam  AwayPTS                HomeTeam  HomePTS  \
# 8 2007-03-02      8:00p  Utah Jazz      109  Minnesota Timberwolves       83
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 8     False    14759               False  2007  ...      3      march
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 8         True          MIN         UTA   False     True            -26
#
#    AwayPointDiff      GameID
# 8             26  2007023MIN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020SAS.html
# Done with game #12
#         Date Start (ET)       AwayTeam  AwayPTS           HomeTeam  HomePTS  \
# 9 2007-03-02      8:00p  Orlando Magic       74  San Antonio Spurs       98
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 9     False    18797               False  2007  ...      3      march
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 9         True          SAS         ORL    True    False             24
#
#    AwayPointDiff      GameID
# 9            -24  2007023SAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020CHI.html
# Done with game #13
#          Date Start (ET)                           AwayTeam  AwayPTS  \
# 10 2007-03-02      8:30p  New Orleans/Oklahoma City Hornets       93
#
#          HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  Year  ...  \
# 10  Chicago Bulls      104     False    22056               False  2007  ...
#
#    Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 10      3      march         True          CHI         NOK    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 10             11            -11  2007023CHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020PHO.html
# Done with game #0
#          Date Start (ET)        AwayTeam  AwayPTS      HomeTeam  HomePTS  \
# 11 2007-03-02      9:00p  Indiana Pacers       90  Phoenix Suns      115
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 11     False    18422               False  2007  ...      3      march
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 11         True          PHO         IND    True    False             25
#
#     AwayPointDiff      GameID
# 11            -25  2007023PHO
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020DEN.html
# Done with game #1
#          Date Start (ET)         AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 12 2007-03-02     10:30p  Houston Rockets      108  Denver Nuggets       97
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 12     False    18938               False  2007  ...      3      march
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 12         True          DEN         HOU   False     True            -11
#
#     AwayPointDiff      GameID
# 12             11  2007023DEN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703020LAL.html
# Done with game #2
#          Date Start (ET)          AwayTeam  AwayPTS            HomeTeam  \
# 13 2007-03-02     10:30p  Sacramento Kings      116  Los Angeles Lakers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 13      108     False    18997               False  2007  ...      3
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 13      march         True          LAL         SAC   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 13             -8              8  2007023LAL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703030NJN.html
# Done with game #3
#          Date Start (ET)        AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 14 2007-03-03      1:00p  Boston Celtics       96  New Jersey Nets       88
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 14      True    15975               False  2007  ...      3      march
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 14         True          NJN         BOS   False     True             -8
#
#     AwayPointDiff      GameID
# 14              8  2007033NJN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200703030ATL.html
# Done with game #4
#          Date Start (ET)         AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 15 2007-03-03      7:00p  New York Knicks      104  Atlanta Hawks      100
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# ...
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 7     False    16324               False  2002  ...     10    october
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 7         True          NJN         ATL    True    False             11
#
#    AwayPointDiff       GameID
# 7            -11  20023010NJN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300MIA.html
# Done with game #6
#         Date Start (ET)       AwayTeam  AwayPTS    HomeTeam  HomePTS  \
# 8 2002-10-30      7:30p  Orlando Magic      100  Miami Heat       86
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 8     False    16500               False  2002  ...     10    october
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 8         True          MIA         ORL   False     True            -14
#
#    AwayPointDiff       GameID
# 8             14  20023010MIA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300MIN.html
# Done with game #7
#         Date Start (ET)        AwayTeam  AwayPTS                HomeTeam  \
# 9 2002-10-30      8:00p  Denver Nuggets       77  Minnesota Timberwolves
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 9       83     False    16113               False  2002  ...     10
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 9    october         True          MIN         DEN    True    False
#
#    HomePointDiff  AwayPointDiff       GameID
# 9              6             -6  20023010MIN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300MEM.html
# Done with game #8
#          Date Start (ET)          AwayTeam  AwayPTS           HomeTeam  \
# 10 2002-10-30      8:00p  Dallas Mavericks      119  Memphis Grizzlies
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 10      108     False    16638               False  2002  ...     10
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 10    october         True          MEM         DAL   False     True
#
#     HomePointDiff  AwayPointDiff       GameID
# 10            -11             11  20023010MEM
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300DET.html
# Done with game #9
#          Date Start (ET)         AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 11 2002-10-30      8:00p  New York Knicks       77  Detroit Pistons       86
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 11     False    22076               False  2002  ...     10    october
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 11         True          DET         NYK    True    False              9
#
#     AwayPointDiff       GameID
# 11             -9  20023010DET
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300NOH.html
# Done with game #10
#          Date Start (ET)   AwayTeam  AwayPTS             HomeTeam  HomePTS  \
# 12 2002-10-30      8:30p  Utah Jazz       75  New Orleans Hornets      100
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 12     False    17668               False  2002  ...     10    october
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 12         True          NOH         UTA    True    False             25
#
#     AwayPointDiff       GameID
# 12            -25  20023010NOH
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300POR.html
# Done with game #11
#          Date Start (ET)            AwayTeam  AwayPTS                HomeTeam  \
# 13 2002-10-30      9:30p  Los Angeles Lakers       90  Portland Trail Blazers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 13      102     False    20225               False  2002  ...     10
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 13    october         True          POR         LAL    True    False
#
#     HomePointDiff  AwayPointDiff       GameID
# 13             12            -12  20023010POR
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300SEA.html
# Done with game #12
#          Date Start (ET)      AwayTeam  AwayPTS             HomeTeam  HomePTS  \
# 14 2002-10-30     10:00p  Phoenix Suns       73  Seattle SuperSonics       86
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 14     False    14002               False  2002  ...     10    october
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 14         True          SEA         PHO    True    False             13
#
#     AwayPointDiff       GameID
# 14            -13  20023010SEA
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300LAC.html
# Done with game #13
#          Date Start (ET)             AwayTeam  AwayPTS              HomeTeam  \
# 15 2002-10-30     10:30p  Cleveland Cavaliers       98  Los Angeles Clippers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 15       96     False    16822               False  2002  ...     10
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 15    october         True          LAC         CLE   False     True
#
#     HomePointDiff  AwayPointDiff       GameID
# 15             -2              2  20023010LAC
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210300GSW.html
# Done with game #0
#          Date Start (ET)           AwayTeam  AwayPTS               HomeTeam  \
# 16 2002-10-30     10:30p  San Antonio Spurs       98  Golden State Warriors
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 16      106     False    13261               False  2002  ...     10
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 16    october         True          GSW         SAS    True    False
#
#     HomePointDiff  AwayPointDiff       GameID
# 16              8             -8  20023010GSW
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210310ATL.html
# Done with game #1
#          Date Start (ET)   AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 17 2002-10-31      7:30p  Utah Jazz       98  Atlanta Hawks      105
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 17     False    14155               False  2002  ...     10    october
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 17         True          ATL         UTA    True    False              7
#
#     AwayPointDiff       GameID
# 17             -7  20023110ATL
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210310WAS.html
# Done with game #2
#          Date Start (ET)        AwayTeam  AwayPTS            HomeTeam  \
# 18 2002-10-31      7:30p  Boston Celtics       69  Washington Wizards
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 18      114     False    20173               False  2002  ...     10
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 18    october         True          WAS         BOS    True    False
#
#     HomePointDiff  AwayPointDiff       GameID
# 18             45            -45  20023110WAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200210310SAC.html
# Done with game #3
#          Date Start (ET)                AwayTeam  AwayPTS          HomeTeam  \
# 19 2002-10-31     10:00p  Portland Trail Blazers       72  Sacramento Kings
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 19      100     False    17317               False  2002  ...     10
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 19    october         True          SAC         POR    True    False
#
#     HomePointDiff  AwayPointDiff       GameID
# 19             28            -28  20023110SAC
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010NJN.html
# Done with game #4
#         Date Start (ET)        AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 0 2002-11-01      7:30p  Indiana Pacers       91  New Jersey Nets      102
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 0     False    11156               False  2002  ...     11   november
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 0         True          NJN         IND    True    False             11
#
#    AwayPointDiff       GameID
# 0            -11  20020111NJN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010DET.html
# Done with game #5
#         Date Start (ET)           AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 1 2002-11-01      8:00p  Memphis Grizzlies       86  Detroit Pistons      109
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 1     False    18113               False  2002  ...     11   november
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 1         True          DET         MEM    True    False             23
#
#    AwayPointDiff       GameID
# 1            -23  20020111DET
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010MIN.html
# Done with game #6
#         Date Start (ET)       AwayTeam  AwayPTS                HomeTeam  \
# 2 2002-11-01      8:00p  Orlando Magic      105  Minnesota Timberwolves
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 2      111     False    14117               False  2002  ...     11
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 2   november         True          MIN         ORL    True    False
#
#    HomePointDiff  AwayPointDiff       GameID
# 2              6             -6  20020111MIN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010PHI.html
# Done with game #7
#         Date Start (ET)         AwayTeam  AwayPTS            HomeTeam  \
# 3 2002-11-01      8:00p  New York Knicks       86  Philadelphia 76ers
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 3       98     False    18298               False  2002  ...     11
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 3   november         True          PHI         NYK    True    False
#
#    HomePointDiff  AwayPointDiff       GameID
# 3             12            -12  20020111PHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010CHI.html
# Done with game #8
#         Date Start (ET)             AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 4 2002-11-01      8:30p  New Orleans Hornets       79  Chicago Bulls       84
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 4     False    21246               False  2002  ...     11   november
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 4         True          CHI         NOH    True    False              5
#
#    AwayPointDiff       GameID
# 4             -5  20020111CHI
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010SAS.html
# Done with game #9
#         Date Start (ET)         AwayTeam  AwayPTS           HomeTeam  HomePTS  \
# 5 2002-11-01      8:30p  Toronto Raptors       72  San Antonio Spurs       91
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 5     False    18787               False  2002  ...     11   november
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 5         True          SAS         TOR    True    False             19
#
#    AwayPointDiff       GameID
# 5            -19  20020111SAS
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010DEN.html
# Done with game #10
#         Date Start (ET)         AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 6 2002-11-01      9:00p  Houston Rockets       83  Denver Nuggets       74
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 6     False    18030               False  2002  ...     11   november
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 6         True          DEN         HOU   False     True             -9
#
#    AwayPointDiff       GameID
# 6              9  20020111DEN
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010PHO.html
# Done with game #11
#         Date Start (ET)             AwayTeam  AwayPTS      HomeTeam  HomePTS  \
# 7 2002-11-01      9:00p  Cleveland Cavaliers       74  Phoenix Suns       78
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 7     False    16133               False  2002  ...     11   november
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 7         True          PHO         CLE    True    False              4
#
#    AwayPointDiff       GameID
# 7             -4  20020111PHO
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010GSW.html
# Done with game #12
#         Date Start (ET)             AwayTeam  AwayPTS               HomeTeam  \
# 8 2002-11-01     10:30p  Seattle SuperSonics      106  Golden State Warriors
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 8       93     False    12121               False  2002  ...     11
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 8   november         True          GSW         SEA   False     True
#
#    HomePointDiff  AwayPointDiff       GameID
# 8            -13             13  20020111GSW
#
# [1 rows x 21 columns]
# https://www.basketball-reference.com/boxscores/200211010LAC.html
# Done with game #13
#         Date Start (ET)            AwayTeam  AwayPTS              HomeTeam  \
# 9 2002-11-01     10:30p  Los Angeles Lakers      108  Los Angeles Clippers
#
#    HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 9       93     False    20474               False  2002  ...     11
#
#    MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 9   november         True          LAC         LAL   False     True
#
#    HomePointDiff  AwayPointDiff       GameID
# 9            -15             15  20020111LAC
#
# [1 rows x 21 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 12
#       8     except:
#       9         break
# ---> 12 new_df_2 = update_full_data_new(datayear = j, rows_to_add = 17, add_all = True)
#
# Cell In[25], line 9, in update_full_data_new(rows_to_add, add_all, datayear)
#       4 except:
#       5     existing_dataframe = pd.DataFrame()
# ----> 9 new_df = final_df(datayear, existing_dataframe, rows_to_add, add_all)
#      10 new_df['Date'] = pd.to_datetime(new_df['Date'], format = 'mixed')
#      12 new_df = new_df[['Date','Starters','TeamName','WonGame','Injured','DidNotPlay','FantasyPoints','MPTimeDelta','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','GmSc','+/-','TeamAbv','Year','Day','Month#','MonthName','Day_of_week','Home','GamePointDiff','Start(ET)','Overtime','Attend.','InSeasonTournament','GameID','OpponentTeam','OpponentTeamAbv','InjTeamateCount', 'Starting','Top7InTeam']]
#
# Cell In[43], line 3, in final_df(year, existing_df, numaddrows, add_all)
#       1 def final_df(year,existing_df,numaddrows, add_all):
# ----> 3     all_games_df = all_games_season(year)
#       4     try:
#       6         all_games_df = all_games_df[~all_games_df['GameID'].isin(existing_df['GameID'])]
#
# Cell In[42], line 6, in all_games_season(year)
#       4 all_dataframes = []
#       5 for month in months:
# ----> 6     time.sleep(5)
#       7     df = get_game_dates(year, month)
#       8     all_dataframes.append(df)
#
# KeyboardInterrupt:

# %%
#testing = add_fantasy_averages_new_new(existing_dataframe)

# %%
#testing
