# %%
import requests
from bs4 import BeautifulSoup
from IPython.core.display import HTML
import pandas as pd
import io
import numpy as np
import time
from fuzzywuzzy import fuzz, process
from unidecode import unidecode

# %% [markdown]
# ## img itemscope="image" src="https://www.basketball-reference.com/req/202106291/images/headshots/jokicni01.jpg" alt="Photo of Nikola Jokić"

# %% [markdown]
# ## Add picture Link and add a non starting most minutes tag that starters also get, for fantasy defense rating.

# %%
positions = pd.read_csv("../data/playerpositions.csv")
player_names_positions = positions['Players'].tolist()
players_pic_link = pd.read_csv("../data/positions2.csv")
player_pic_link_names = players_pic_link['Players'].tolist()
players_pic_link
# Out:
#      Unnamed: 0.1              Players Pos1 Pos2 Pos3 Pos4 Pos5  \
# 0               0  Jonas ValanÄiÅ«nas    C  NaN  NaN  NaN  NaN
# 1               1   Carlton Carrington   PG  NaN  NaN  NaN  NaN
# 2               2      Bilal Coulibaly   SF  NaN  NaN  NaN  NaN
# 3               3            Alex Sarr    C   PF  NaN  NaN  NaN
# 4               4        Corey Kispert   SF  NaN  NaN  NaN  NaN
# ..            ...                  ...  ...  ...  ...  ...  ...
# 521           521          Kobe Bufkin   SG  NaN  NaN  NaN  NaN
# 522           522      Dominick Barlow   PF   SF  NaN  NaN  NaN
# 523           523       Mouhamed Gueye   PF  NaN  NaN  NaN  NaN
# 524           524      Daeqwon Plowden   SG  NaN  NaN  NaN  NaN
# 525           525          Cody Zeller    C  NaN  NaN  NaN  NaN
#
#                                            PictureLink  Unnamed: 0
# 0    https://www.basketball-reference.com/req/20210...         NaN
# 1    https://www.basketball-reference.com/req/20210...         NaN
# 2    https://www.basketball-reference.com/req/20210...         NaN
# 3    https://www.basketball-reference.com/req/20210...         NaN
# 4    https://www.basketball-reference.com/req/20210...         NaN
# ..                                                 ...         ...
# 521  https://www.basketball-reference.com/req/20210...       380.0
# 522  https://www.basketball-reference.com/req/20210...       381.0
# 523  https://www.basketball-reference.com/req/20210...       382.0
# 524  https://www.basketball-reference.com/req/20210...       383.0
# 525  https://www.basketball-reference.com/req/20210...       384.0
#
# [526 rows x 9 columns]

# %%
nba_team_abbreviations = {
    "Atlanta Hawks": "ATL",
    "Boston Celtics": "BOS",
    "Brooklyn Nets": "BRK",
    "Charlotte Hornets": "CHO", ####
    "Chicago Bulls": "CHI",
    "Cleveland Cavaliers": "CLE",
    "Dallas Mavericks": "DAL",
    "Denver Nuggets": "DEN",
    "Detroit Pistons": "DET",
    "Golden State Warriors": "GSW",
    "Houston Rockets": "HOU",
    "Indiana Pacers": "IND",
    "Los Angeles Clippers": "LAC",
    "Los Angeles Lakers": "LAL",
    "Memphis Grizzlies": "MEM",
    "Miami Heat": "MIA",
    "Milwaukee Bucks": "MIL",
    "Minnesota Timberwolves": "MIN",
    "New Orleans Pelicans": "NOP",
    "New York Knicks": "NYK",
    "Oklahoma City Thunder": "OKC",
    "Orlando Magic": "ORL",
    "Philadelphia 76ers": "PHI",
    "Phoenix Suns": "PHO",
    "Portland Trail Blazers": "POR",
    "Sacramento Kings": "SAC",
    "San Antonio Spurs": "SAS",
    "Toronto Raptors": "TOR",
    "Utah Jazz": "UTA",
    "Washington Wizards": "WAS"
    }


nba_team_names = {
    "ATL": "Atlanta Hawks",
    "BOS": "Boston Celtics",
    "BRK": "Brooklyn Nets",
    "CHO": "Charlotte Hornets",
    "CHI": "Chicago Bulls",
    "CLE": "Cleveland Cavaliers",
    "DAL": "Dallas Mavericks",
    "DEN": "Denver Nuggets",
    "DET": "Detroit Pistons",
    "GSW": "Golden State Warriors",
    "HOU": "Houston Rockets",
    "IND": "Indiana Pacers",
    "LAC": "Los Angeles Clippers",
    "LAL": "Los Angeles Lakers",
    "MEM": "Memphis Grizzlies",
    "MIA": "Miami Heat",
    "MIL": "Milwaukee Bucks",
    "MIN": "Minnesota Timberwolves",
    "NOP": "New Orleans Pelicans",
    "NYK": "New York Knicks",
    "OKC": "Oklahoma City Thunder",
    "ORL": "Orlando Magic",
    "PHI": "Philadelphia 76ers",
    "PHO": "Phoenix Suns",
    "POR": "Portland Trail Blazers",
    "SAC": "Sacramento Kings",
    "SAS": "San Antonio Spurs",
    "TOR": "Toronto Raptors",
    "UTA": "Utah Jazz",
    "WAS": "Washington Wizards"
}

# %%
def get_game_dates(year, month):  
    session = requests.Session()
    
    URL = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html'
    response = session.get(URL)
    response.status_code
    soup = BeautifulSoup(response.text, features="html.parser")
    soup.prettify()
    tables = soup.find_all('table')
    table_html = str(tables[0])
    df = pd.read_html(io.StringIO(table_html))[0]
    df['Date'] = pd.to_datetime(df['Date'])
    df['Year'] = df['Date'].dt.year
    df['Day'] = df['Date'].dt.day.astype(str).str.zfill(2)
    df['Month#'] = df['Date'].dt.month
    df['MonthName'] = df['Date'].dt.month_name().str.lower()
    df['GameFinished'] = df['Date'] < (pd.Timestamp('today') - pd.Timedelta(days=1))
    
    df = df.rename(columns = {
        'Visitor/Neutral':'AwayTeam',
        'PTS':'AwayPTS',
        'PTS.1':'HomePTS',
        'Home/Neutral' : 'HomeTeam',
        'Unnamed: 7' : 'Overtime',
        'Notes':'InSeasonTournament'
    })
    df = df.drop(['Unnamed: 6', 'LOG','Arena'], axis = 1)
    df['Overtime'] = df['Overtime'].apply(lambda x: True if x == 'OT' else False)
    df['HomeTeamAbv'] = df['HomeTeam'].map(nba_team_abbreviations)
    df['AwayTeamAbv'] = df['AwayTeam'].map(nba_team_abbreviations)
    df['HomeWin'] = df['HomePTS'] > df['AwayPTS']
    df['AwayWin'] = df['AwayPTS'] > df['HomePTS']
    df['HomePointDiff'] = df['HomePTS'] - df['AwayPTS']
    df['AwayPointDiff'] = df['AwayPTS'] - df['HomePTS']
    df['GameID'] = df['Year'].astype(str) + df['Day'].astype(str) + df['Month#'].astype(str) + df['HomeTeamAbv']

    df['InSeasonTournament'] = df['InSeasonTournament'].apply(lambda x: True if x == 'In-Season Tournament' else False)

    return df

# %%
get_game_dates(2025, 'november')
# Out:
#           Date Start (ET)               AwayTeam  AwayPTS  \
# 0   2024-11-01      7:00p         Boston Celtics      124
# 1   2024-11-01      7:00p          Orlando Magic      109
# 2   2024-11-01      7:00p        New York Knicks      128
# 3   2024-11-01      7:30p       Sacramento Kings      123
# 4   2024-11-01      7:30p          Chicago Bulls      112
# ..         ...        ...                    ...      ...
# 217 2024-11-30      6:00p          Atlanta Hawks      107
# 218 2024-11-30      7:00p     Philadelphia 76ers      111
# 219 2024-11-30      8:00p     Washington Wizards      114
# 220 2024-11-30      9:00p  Golden State Warriors      105
# 221 2024-11-30      9:30p       Dallas Mavericks      106
#
#                 HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 0      Charlotte Hornets      109     False    18557               False
# 1    Cleveland Cavaliers      120     False    19432               False
# 2        Detroit Pistons       98     False    17022               False
# 3          Atlanta Hawks      115     False    15156               False
# 4          Brooklyn Nets      120     False    17977               False
# ..                   ...      ...       ...      ...                 ...
# 217    Charlotte Hornets      104     False    17969               False
# 218      Detroit Pistons       96     False    22062               False
# 219      Milwaukee Bucks      124     False    17341               False
# 220         Phoenix Suns      113     False    17071               False
# 221            Utah Jazz       94     False    18175               False
#
#      Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv  \
# 0    2024  ...     11   november         True          CHO         BOS
# 1    2024  ...     11   november         True          CLE         ORL
# 2    2024  ...     11   november         True          DET         NYK
# 3    2024  ...     11   november         True          ATL         SAC
# 4    2024  ...     11   november         True          BRK         CHI
# ..    ...  ...    ...        ...          ...          ...         ...
# 217  2024  ...     11   november         True          CHO         ATL
# 218  2024  ...     11   november         True          DET         PHI
# 219  2024  ...     11   november         True          MIL         WAS
# 220  2024  ...     11   november         True          PHO         GSW
# 221  2024  ...     11   november         True          UTA         DAL
#
#     HomeWin  AwayWin  HomePointDiff  AwayPointDiff       GameID
# 0     False     True            -15             15  20240111CHO
# 1      True    False             11            -11  20240111CLE
# 2     False     True            -30             30  20240111DET
# 3     False     True             -8              8  20240111ATL
# 4      True    False              8             -8  20240111BRK
# ..      ...      ...            ...            ...          ...
# 217   False     True             -3              3  20243011CHO
# 218   False     True            -15             15  20243011DET
# 219    True    False             10            -10  20243011MIL
# 220    True    False              8             -8  20243011PHO
# 221   False     True            -12             12  20243011UTA
#
# [222 rows x 21 columns]

# %%
def all_games_season(year):
    months = ['october', 'november', 'december', 'january', 'february', 'march', 'april']
    total_df = pd.DataFrame()
    all_dataframes = []
    for month in months:
        
        df = get_game_dates(year, month)
        all_dataframes.append(df)
    
    total_df = pd.concat(all_dataframes)
    
    return total_df

# %%
dfdf = all_games_season(2025)
dfdf
# Out:
#           Date Start (ET)                AwayTeam  AwayPTS  \
# 0   2024-10-22      7:30p         New York Knicks    109.0
# 1   2024-10-22     10:00p  Minnesota Timberwolves    103.0
# 2   2024-10-23      7:00p          Indiana Pacers    115.0
# 3   2024-10-23      7:30p           Brooklyn Nets    116.0
# 4   2024-10-23      7:30p           Orlando Magic    116.0
# ..         ...        ...                     ...      ...
# 100 2025-04-13      3:30p               Utah Jazz      NaN
# 101 2025-04-13      3:30p   Oklahoma City Thunder      NaN
# 102 2025-04-13      3:30p      Los Angeles Lakers      NaN
# 103 2025-04-13      3:30p            Phoenix Suns      NaN
# 104 2025-04-13      3:30p         Toronto Raptors      NaN
#
#                    HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 0            Boston Celtics    132.0     False  19156.0               False
# 1        Los Angeles Lakers    110.0     False  18997.0               False
# 2           Detroit Pistons    109.0     False  20062.0               False
# 3             Atlanta Hawks    120.0     False  17548.0               False
# 4                Miami Heat     97.0     False  19630.0               False
# ..                      ...      ...       ...      ...                 ...
# 100  Minnesota Timberwolves      NaN     False      NaN               False
# 101    New Orleans Pelicans      NaN     False      NaN               False
# 102  Portland Trail Blazers      NaN     False      NaN               False
# 103        Sacramento Kings      NaN     False      NaN               False
# 104       San Antonio Spurs      NaN     False      NaN               False
#
#      Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv  \
# 0    2024  ...     10    october         True          BOS         NYK
# 1    2024  ...     10    october         True          LAL         MIN
# 2    2024  ...     10    october         True          DET         IND
# 3    2024  ...     10    october         True          ATL         BRK
# 4    2024  ...     10    october         True          MIA         ORL
# ..    ...  ...    ...        ...          ...          ...         ...
# 100  2025  ...      4      april        False          MIN         UTA
# 101  2025  ...      4      april        False          NOP         OKC
# 102  2025  ...      4      april        False          POR         LAL
# 103  2025  ...      4      april        False          SAC         PHO
# 104  2025  ...      4      april        False          SAS         TOR
#
#     HomeWin  AwayWin  HomePointDiff  AwayPointDiff       GameID
# 0      True    False           23.0          -23.0  20242210BOS
# 1      True    False            7.0           -7.0  20242210LAL
# 2     False     True           -6.0            6.0  20242310DET
# 3      True    False            4.0           -4.0  20242310ATL
# 4     False     True          -19.0           19.0  20242310MIA
# ..      ...      ...            ...            ...          ...
# 100   False    False            NaN            NaN   2025134MIN
# 101   False    False            NaN            NaN   2025134NOP
# 102   False    False            NaN            NaN   2025134POR
# 103   False    False            NaN            NaN   2025134SAC
# 104   False    False            NaN            NaN   2025134SAS
#
# [1231 rows x 21 columns]

# %%
def get_boxscore_link(df):
    
    if int(df['Month#'].iloc[0]) < 10:
        month = '0' + str(df['Month#'].iloc[0])
    else:
        month = df['Month#'].iloc[0]
    year = df['Year'].iloc[0]
    day = df['Day'].iloc[0]
    hometeam = df['HomeTeamAbv'].iloc[0]
    
    link = f'https://www.basketball-reference.com/boxscores/{year}{month}{day}0{hometeam}.html'
    
    return link

# %%
def get_all_links_all_games(big_df):
    length = len(big_df)
    link_list = []
    for i in range(length):
        df = big_df.iloc[[i]]
        link_list.append(get_boxscore_link(df))
    
    return link_list

# %%
links = get_all_links_all_games(dfdf)

# %%
smalldfdf = dfdf.iloc[[0]]

# %%
def player_scores_game(GameDF):
    
    global positions
    
    columns_to_replace = [
    'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 
    'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-'
    ]
    URL = get_boxscore_link(GameDF)
    
    response = requests.get(URL)
    soup = BeautifulSoup(response.text, features="html.parser")
    soup.prettify()
    tables = soup.find_all('table')
    
    
    inactive_section = soup.find('strong', string=lambda t: t and "Inactive:" in t)
    team_sections = inactive_section.find_next_siblings('span')
    team_inactives = {}  

    for team_section in team_sections:
        team_name = team_section.text.strip() 

        
        players = []
        sibling = team_section.find_next_sibling()
        while sibling and sibling.name == 'a':  
            players.append(sibling.text.strip())
            sibling = sibling.find_next_sibling()

        # Store the team and its players
        if players:
            team_inactives[team_name] = players
    rows = []
    for team, players in team_inactives.items():
        for player in players:
            row = {'Starters': player, 'Injured': True, 'TeamAbv': team}  
            rows.append(row)
    
    new_df = pd.DataFrame(rows)
    team_inactive_counts = {}
    team_inactive_counts = {team: len(players) for team, players in team_inactives.items()} 
    
    
    table_html1 = str(tables[0])
    df1 = pd.read_html(io.StringIO(table_html1))[0]
    df1.columns = df1.columns.droplevel(0)
    df1['Starting'] = [True if i < 5 else False for i in range(len(df1))]
    df1['Injured'] = False
    df1['TeamAbv'] = nba_team_abbreviations[GameDF['AwayTeam'].iloc[0]]
    name1 = df1['Starters'].iloc[0]
    
    df1_filtered = df1[~df1['Starters'].isin(['Team Totals', 'Reserves'])].copy()
    
    df1_filtered.loc[:, 'MP_sort'] = pd.to_numeric(df1_filtered['MP'], errors='coerce')
    top_non_startersdf1 = df1_filtered[df1_filtered['Starting'] == False].nlargest(2, 'MP_sort')
    
    df1['Top7InTeam'] = df1_filtered['Starting'] | df1_filtered.index.isin(top_non_startersdf1.index)
    
    
    
    
    GoodToGo = False
    i = 6
    
    while not GoodToGo:
        table_html2 = str(tables[i])
        df2 = pd.read_html(io.StringIO(table_html2))[0]
        #print(df2)
        #print("ABOVE IS THE SECOND DATAFRAME!")
        df2.columns = df2.columns.droplevel(0)
        df2['Starting'] = [True if i < 5 else False for i in range(len(df2))]
       
        df2['Injured'] = False
        df2['TeamAbv'] = nba_team_abbreviations[GameDF['HomeTeam'].iloc[0]]
        name2= df2['Starters'].iloc[0]
        #print(name2)
        #print(i)
        i = i + 1
        if name1 != name2:
            GoodToGo = True
        
    
    df2_filtered = df2[~df2['Starters'].isin(['Team Totals', 'Reserves'])].copy()
    
    df2_filtered.loc[:, 'MP_sort'] = pd.to_numeric(df2_filtered['MP'], errors='coerce')
    top_non_startersdf2 = df2_filtered[df2_filtered['Starting'] == False].nlargest(2, 'MP_sort')
    
    df2['Top7InTeam'] = df2_filtered['Starting'] | df2_filtered.index.isin(top_non_startersdf2.index)
    
    
    
    
#     for i in range(len(tables)):
#         print("                                    ")
#         print("                                    ")
#         print("                                    ")
#         print(i)
#         print("                                    ")
#         print("                                    ")
#         print("                                    ")
#         table_html0 = str(tables[i])
#         df0 = pd.read_html(io.StringIO(table_html0))[0]
#         print(df0)
    
    
    #Do a first run of didnotplay = injured, then do if did not play = false?
    # or do did not play be an or statement just the whole thing
    
    
    
    df_merged = pd.concat([df1, df2, new_df], ignore_index=True, sort=False)
    #df_merged.columns = df_merged.columns.droplevel(0)
    
    df_merged = df_merged[df_merged['Starters'] != 'Team Totals']
    df_merged = df_merged[df_merged['Starters'] != 'Reserves']

    
    df_merged['Date'] = GameDF['Date'].iloc[0]
    df_merged['Year'] = df_merged['Date'].dt.year
    df_merged['Day'] = df_merged['Date'].dt.day.astype(str).str.zfill(2)
    df_merged['Month#'] = df_merged['Date'].dt.month
    df_merged['MonthName'] = df_merged['Date'].dt.month_name().str.lower()
    df_merged['Day_of_week'] = df_merged['Date'].dt.day_name()
    df_merged['TeamName'] = df_merged['TeamAbv'].map(nba_team_names)
    df_merged['Home'] = df_merged['TeamName'].apply(lambda x: x == GameDF['HomeTeam'].iloc[0])
    df_merged['DidNotPlay'] = (df_merged['FG'] == df_merged['MP']) | df_merged['Injured']
    df_merged[df_merged['Injured']] = df_merged.fillna(0)
    
    
    for col_replace in columns_to_replace:
        df_merged.loc[df_merged['DidNotPlay'], col_replace] = 0
      
    
    df_merged['MPTimeDelta'] = df_merged['MP'].apply(
    lambda x: pd.to_timedelta("00:" + str(x)) if ':' in str(x) else pd.to_timedelta(0))
    df_merged['OpponentTeam'] = df_merged['Home'].apply(lambda x: GameDF['AwayTeam'].iloc[0] if x else GameDF['HomeTeam'].iloc[0])
    df_merged['OpponentTeamAbv'] = df_merged['Home'].apply(lambda x: GameDF['AwayTeamAbv'].iloc[0] if x else GameDF['HomeTeamAbv'].iloc[0])
    df_merged['WonGame'] = df_merged['Home'].apply(lambda x: GameDF['HomeWin'].iloc[0] if x else GameDF['AwayWin'].iloc[0])
    df_merged['GamePointDiff'] = df_merged['Home'].apply(lambda x: GameDF['HomePointDiff'].iloc[0] if x else GameDF['AwayPointDiff'].iloc[0])
    df_merged['Start(ET)'] = GameDF['Start (ET)'].iloc[0]
    df_merged['Overtime'] = GameDF['Overtime'].iloc[0]
    df_merged['Attend.'] = GameDF['Attend.'].iloc[0]
    df_merged['InSeasonTournament'] = GameDF['InSeasonTournament'].iloc[0]
    
    df_merged['Pos1'] = df_merged['Starters'].apply(
    lambda x: positions.loc[positions['Players'] == x, 'Pos1'].iloc[0] if not positions.loc[positions['Players'] == x].empty else positions.loc[positions['Players'] == process.extractOne(x, player_names_positions)[0], 'Pos1'].iloc[0])
    
    df_merged['Pos2'] = df_merged['Starters'].apply(
    lambda x: positions.loc[positions['Players'] == x, 'Pos2'].iloc[0] if not positions.loc[positions['Players'] == x].empty else positions.loc[positions['Players'] == process.extractOne(x, player_names_positions)[0], 'Pos2'].iloc[0])
    
    df_merged['Pos3'] = df_merged['Starters'].apply(
    lambda x: positions.loc[positions['Players'] == x, 'Pos3'].iloc[0] if not positions.loc[positions['Players'] == x].empty else positions.loc[positions['Players'] == process.extractOne(x, player_names_positions)[0], 'Pos3'].iloc[0])
    
    df_merged['Pos4'] = df_merged['Starters'].apply(
    lambda x: positions.loc[positions['Players'] == x, 'Pos4'].iloc[0] if not positions.loc[positions['Players'] == x].empty else positions.loc[positions['Players'] == process.extractOne(x, player_names_positions)[0], 'Pos4'].iloc[0])
    
    df_merged['Pos5'] = df_merged['Starters'].apply(
    lambda x: positions.loc[positions['Players'] == x, 'Pos5'].iloc[0] if not positions.loc[positions['Players'] == x].empty else positions.loc[positions['Players'] == process.extractOne(x, player_names_positions)[0], 'Pos5'].iloc[0])
    
    df_merged['correct_positions'] = df_merged['Starters'].apply(
    lambda x: positions['Players'].eq(x).any() or process.extractOne(x, player_names_positions, score_cutoff=75) is not None)
    
    df_merged['PhotoLink'] = df_merged['Starters'].apply(
    lambda x: players_pic_link.loc[players_pic_link['Players'] == x, 'PictureLink'].iloc[0] 
    if not players_pic_link.loc[players_pic_link['Players'] == x].empty 
    else None
    )
    
    df_merged['Starting'] = df_merged['Starting'].apply(lambda x: False if x == 0 else x)
    df_merged['PTS'] = pd.to_numeric(df_merged['PTS'], errors='coerce')
    df_merged['TRB'] = pd.to_numeric(df_merged['TRB'], errors='coerce')
    df_merged['AST'] = pd.to_numeric(df_merged['AST'], errors='coerce')
    df_merged['STL'] = pd.to_numeric(df_merged['STL'], errors='coerce')
    df_merged['BLK'] = pd.to_numeric(df_merged['BLK'], errors='coerce')
    df_merged['TOV'] = pd.to_numeric(df_merged['TOV'], errors='coerce')
    df_merged['3P'] = pd.to_numeric(df_merged['3P'], errors='coerce')
    df_merged['tens'] = ((df_merged['PTS'] >= 10) * 1) + ((df_merged['TRB'] >= 10) * 1) + ((df_merged['AST'] >= 10) * 1)+ ((df_merged['STL'] >= 10) * 1)+ ((df_merged['BLK'] >= 10) * 1)
    df_merged['FantasyPoints'] = (df_merged['PTS'] * .5) + (df_merged['TRB'] * 1) + (df_merged['AST'] * 1) + (df_merged['STL'] * 2) + (df_merged['BLK'] * 2) + (df_merged['TOV'] * -1) + (df_merged['3P'] * .5) + ((df_merged['PTS'] >= 40).astype(int) * 2) + ((df_merged['PTS'] >= 50).astype(int) * 2) + ((df_merged['tens'] >= 2).astype(int) * 1) + ((df_merged['tens'] >= 3).astype(int) * 2)
    df_merged['GameID'] = GameDF['GameID'].iloc[0]
    df_merged['InjTeamateCount'] = df_merged['TeamAbv'].map(team_inactive_counts)
    df_merged['Top7InTeam'] = df_merged['Top7InTeam'].apply(lambda x: False if x == 0 else x)
    
    df_merged = df_merged[['Date','Starters','TeamName','WonGame','Injured','DidNotPlay','FantasyPoints','MPTimeDelta','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','GmSc','+/-','TeamAbv','Year','Day','Month#','MonthName','Day_of_week','Home','GamePointDiff','Start(ET)','Overtime','Attend.','InSeasonTournament','Pos1','Pos2','Pos3','Pos4','Pos5','correct_positions','GameID','OpponentTeam','OpponentTeamAbv','InjTeamateCount', 'Starting','Top7InTeam','PhotoLink']]
    #df_merged = df_merged.rename(columns = {
    #    'Starters'
    #    
    #})
    
    
    return df_merged

stats = player_scores_game(smalldfdf)

# %%
# Index([, 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'GmSc', '+/-', '', 'Injured', 'TeamAbv', , 'Year', 'Day',
#        'Month#', 'MonthName', 'Day_of_week', 'TeamName', 'Home', 'DidNotPlay',
#        'WonGame', 'GamePointDiff', 'Start(ET)', 'Overtime', 'Attend.',
#        'InSeasonTournament', 'Pos1', 'Pos2', 'Pos3', 'Pos4', 'Pos5'],
#       dtype='object')

# %%
stats
# Out:
#          Date              Starters         TeamName  WonGame  Injured  \
# 0  2024-10-22         Mikal Bridges  New York Knicks    False    False
# 1  2024-10-22            OG Anunoby  New York Knicks    False    False
# 2  2024-10-22         Jalen Brunson  New York Knicks    False    False
# 3  2024-10-22             Josh Hart  New York Knicks    False    False
# 4  2024-10-22    Karl-Anthony Towns  New York Knicks    False    False
# 6  2024-10-22         Miles McBride  New York Knicks    False    False
# 7  2024-10-22          Jericho Sims  New York Knicks    False    False
# 8  2024-10-22         Cameron Payne  New York Knicks    False    False
# 9  2024-10-22         Pacome Dadiet  New York Knicks    False    False
# 10 2024-10-22        Ariel Hukporti  New York Knicks    False    False
# 11 2024-10-22           Tyler Kolek  New York Knicks    False    False
# 12 2024-10-22          Jacob Toppin  New York Knicks    False    False
# 14 2024-10-22          Jrue Holiday   Boston Celtics     True    False
# 15 2024-10-22          Jayson Tatum   Boston Celtics     True    False
# 16 2024-10-22          Jaylen Brown   Boston Celtics     True    False
# 17 2024-10-22         Derrick White   Boston Celtics     True    False
# 18 2024-10-22            Al Horford   Boston Celtics     True    False
# 20 2024-10-22      Payton Pritchard   Boston Celtics     True    False
# 21 2024-10-22            Sam Hauser   Boston Celtics     True    False
# 22 2024-10-22           Luke Kornet   Boston Celtics     True    False
# 23 2024-10-22    Xavier Tillman Sr.   Boston Celtics     True    False
# 24 2024-10-22          Jordan Walsh   Boston Celtics     True    False
# 25 2024-10-22         Neemias Queta   Boston Celtics     True    False
# 26 2024-10-22     Baylor Scheierman   Boston Celtics     True    False
# 27 2024-10-22        Jaden Springer   Boston Celtics     True    False
# 29 2024-10-22      Precious Achiuwa  New York Knicks    False     True
# 30 2024-10-22    Kevin McCullar Jr.  New York Knicks    False     True
# 31 2024-10-22     Mitchell Robinson  New York Knicks    False     True
# 32 2024-10-22            JD Davison   Boston Celtics     True     True
# 33 2024-10-22         Drew Peterson   Boston Celtics     True     True
# 34 2024-10-22  Kristaps PorziÅÄ£is   Boston Celtics     True     True
# 35 2024-10-22          Anton Watson   Boston Celtics     True     True
#
#     DidNotPlay  FantasyPoints     MPTimeDelta     MP  FG  ... Pos4 Pos5  \
# 0        False           10.0 0 days 00:34:37  34:37   7  ...  NaN  NaN
# 1        False           12.0 0 days 00:34:10  34:10   1  ...  NaN  NaN
# 2        False           10.5 0 days 00:24:30  24:30   9  ...  NaN  NaN
# 3        False           12.0 0 days 00:24:30  24:30   4  ...  NaN  NaN
# 4        False           16.5 0 days 00:23:37  23:37   5  ...  NaN  NaN
# 6        False           14.0 0 days 00:25:51  25:51   8  ...  NaN  NaN
# 7        False           15.0 0 days 00:24:23  24:23   2  ...  NaN  NaN
# 8        False           14.0 0 days 00:20:43  20:43   5  ...  NaN  NaN
# 9        False            3.0 0 days 00:13:23  13:23   1  ...  NaN  NaN
# 10       False            6.0 0 days 00:06:05   6:05   0  ...  NaN  NaN
# 11       False            0.0 0 days 00:05:24   5:24   1  ...  NaN  NaN
# 12       False            0.0 0 days 00:02:47   2:47   0  ...  NaN  NaN
# 14       False           21.0 0 days 00:30:31  30:31   7  ...  NaN  NaN
# 15       False           40.5 0 days 00:30:18  30:18  14  ...  NaN  NaN
# 16       False           23.0 0 days 00:29:54  29:54   7  ...  NaN  NaN
# 17       False           24.0 0 days 00:26:38  26:38   8  ...  NaN  NaN
# 18       False           19.0 0 days 00:26:05  26:05   4  ...  NaN  NaN
# 20       False            9.0 0 days 00:24:58  24:58   1  ...  NaN  NaN
# 21       False           12.0 0 days 00:24:10  24:10   4  ...  NaN  NaN
# 22       False           10.0 0 days 00:19:19  19:19   2  ...  NaN  NaN
# 23       False           10.0 0 days 00:17:42  17:42   1  ...  NaN  NaN
# 24       False            1.0 0 days 00:06:05   6:05   0  ...  NaN  NaN
# 25       False            0.0 0 days 00:04:20   4:20   0  ...  NaN  NaN
# 26        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 27        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 29        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 30        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 31        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 32        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 33        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 34        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 35        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
#
#     correct_positions       GameID     OpponentTeam OpponentTeamAbv  \
# 0                True  20242210BOS   Boston Celtics             BOS
# 1                True  20242210BOS   Boston Celtics             BOS
# 2                True  20242210BOS   Boston Celtics             BOS
# 3                True  20242210BOS   Boston Celtics             BOS
# 4                True  20242210BOS   Boston Celtics             BOS
# 6                True  20242210BOS   Boston Celtics             BOS
# 7                True  20242210BOS   Boston Celtics             BOS
# 8                True  20242210BOS   Boston Celtics             BOS
# 9                True  20242210BOS   Boston Celtics             BOS
# 10               True  20242210BOS   Boston Celtics             BOS
# 11               True  20242210BOS   Boston Celtics             BOS
# 12               True  20242210BOS   Boston Celtics             BOS
# 14               True  20242210BOS  New York Knicks             NYK
# 15               True  20242210BOS  New York Knicks             NYK
# 16               True  20242210BOS  New York Knicks             NYK
# 17               True  20242210BOS  New York Knicks             NYK
# 18               True  20242210BOS  New York Knicks             NYK
# 20               True  20242210BOS  New York Knicks             NYK
# 21               True  20242210BOS  New York Knicks             NYK
# 22               True  20242210BOS  New York Knicks             NYK
# 23               True  20242210BOS  New York Knicks             NYK
# 24               True  20242210BOS  New York Knicks             NYK
# 25               True  20242210BOS  New York Knicks             NYK
# 26               True  20242210BOS  New York Knicks             NYK
# 27               True  20242210BOS  New York Knicks             NYK
# 29               True  20242210BOS   Boston Celtics             BOS
# 30               True  20242210BOS   Boston Celtics             BOS
# 31               True  20242210BOS   Boston Celtics             BOS
# 32               True  20242210BOS  New York Knicks             NYK
# 33               True  20242210BOS  New York Knicks             NYK
# 34               True  20242210BOS  New York Knicks             NYK
# 35               True  20242210BOS  New York Knicks             NYK
#
#    InjTeamateCount Starting Top7InTeam  \
# 0                3     True       True
# 1                3     True       True
# 2                3     True       True
# 3                3     True       True
# 4                3     True       True
# 6                3    False       True
# 7                3    False       True
# 8                3    False      False
# 9                3    False      False
# 10               3    False      False
# 11               3    False      False
# 12               3    False      False
# 14               4     True       True
# 15               4     True       True
# 16               4     True       True
# 17               4     True       True
# 18               4     True       True
# 20               4    False       True
# 21               4    False       True
# 22               4    False      False
# 23               4    False      False
# 24               4    False      False
# 25               4    False      False
# 26               4    False      False
# 27               4    False      False
# 29               3    False      False
# 30               3    False      False
# 31               3    False      False
# 32               4    False      False
# 33               4    False      False
# 34               4    False      False
# 35               4    False      False
#
#                                             PhotoLink
# 0   https://www.basketball-reference.com/req/20210...
# 1   https://www.basketball-reference.com/req/20210...
# 2   https://www.basketball-reference.com/req/20210...
# 3   https://www.basketball-reference.com/req/20210...
# 4   https://www.basketball-reference.com/req/20210...
# 6   https://www.basketball-reference.com/req/20210...
# 7   https://www.basketball-reference.com/req/20210...
# 8   https://www.basketball-reference.com/req/20210...
# 9   https://www.basketball-reference.com/req/20210...
# 10  https://www.basketball-reference.com/req/20210...
# 11  https://www.basketball-reference.com/req/20210...
# 12  https://www.basketball-reference.com/req/20210...
# 14  https://www.basketball-reference.com/req/20210...
# 15  https://www.basketball-reference.com/req/20210...
# 16  https://www.basketball-reference.com/req/20210...
# 17  https://www.basketball-reference.com/req/20210...
# 18  https://www.basketball-reference.com/req/20210...
# 20  https://www.basketball-reference.com/req/20210...
# 21  https://www.basketball-reference.com/req/20210...
# 22  https://www.basketball-reference.com/req/20210...
# 23  https://www.basketball-reference.com/req/20210...
# 24  https://www.basketball-reference.com/req/20210...
# 25  https://www.basketball-reference.com/req/20210...
# 26  https://www.basketball-reference.com/req/20210...
# 27  https://www.basketball-reference.com/req/20210...
# 29  https://www.basketball-reference.com/req/20210...
# 30  https://www.basketball-reference.com/req/20210...
# 31  https://www.basketball-reference.com/req/20210...
# 32  https://www.basketball-reference.com/req/20210...
# 33  https://www.basketball-reference.com/req/20210...
# 34  https://www.basketball-reference.com/req/20210...
# 35  https://www.basketball-reference.com/req/20210...
#
# [32 rows x 54 columns]

# %%
first_2025 = dfdf[dfdf['Year'] == 2025].iloc[[0]]
first_2025
# Out:
#         Date Start (ET)       AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 0 2025-01-01      7:00p  Orlando Magic     96.0  Detroit Pistons    105.0
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 0     False  19399.0               False  2025  ...      1    january
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 0         True          DET         ORL    True    False            9.0
#
#    AwayPointDiff      GameID
# 0           -9.0  2025011DET
#
# [1 rows x 21 columns]

# %%
#20242210BOS

# %%
testingdfdf = dfdf[dfdf['GameID'] == '2025011DET']

# %%
player_scores_game(testingdfdf)
# Out:
#          Date                  Starters         TeamName  WonGame  Injured  \
# 0  2025-01-01  Kentavious Caldwell-Pope    Orlando Magic    False    False
# 1  2025-01-01        Wendell Carter Jr.    Orlando Magic    False    False
# 2  2025-01-01               Jalen Suggs    Orlando Magic    False    False
# 3  2025-01-01          Tristan Da Silva    Orlando Magic    False    False
# 4  2025-01-01              Goga Bitadze    Orlando Magic    False    False
# 6  2025-01-01             Caleb Houstan    Orlando Magic    False    False
# 7  2025-01-01               Gary Harris    Orlando Magic    False    False
# 8  2025-01-01               Jett Howard    Orlando Magic    False    False
# 9  2025-01-01            Jonathan Isaac    Orlando Magic    False    False
# 10 2025-01-01              Cole Anthony    Orlando Magic    False    False
# 11 2025-01-01               Cory Joseph    Orlando Magic    False    False
# 13 2025-01-01             Tobias Harris  Detroit Pistons     True    False
# 14 2025-01-01           Cade Cunningham  Detroit Pistons     True    False
# 15 2025-01-01          Tim Hardaway Jr.  Detroit Pistons     True    False
# 16 2025-01-01                Jaden Ivey  Detroit Pistons     True    False
# 17 2025-01-01               Jalen Duren  Detroit Pistons     True    False
# 19 2025-01-01            Ausar Thompson  Detroit Pistons     True    False
# 20 2025-01-01             Malik Beasley  Detroit Pistons     True    False
# 21 2025-01-01            Isaiah Stewart  Detroit Pistons     True    False
# 22 2025-01-01               Ron Holland  Detroit Pistons     True    False
# 23 2025-01-01             Marcus Sasser  Detroit Pistons     True    False
# 24 2025-01-01         Wendell Moore Jr.  Detroit Pistons     True    False
# 25 2025-01-01                 Paul Reed  Detroit Pistons     True    False
# 27 2025-01-01            Paolo Banchero    Orlando Magic    False     True
# 28 2025-01-01             Anthony Black    Orlando Magic    False     True
# 29 2025-01-01               Mac McClung    Orlando Magic    False     True
# 30 2025-01-01            Trevelin Queen    Orlando Magic    False     True
# 31 2025-01-01              Franz Wagner    Orlando Magic    False     True
# 32 2025-01-01             Moritz Wagner    Orlando Magic    False     True
# 33 2025-01-01         Simone Fontecchio  Detroit Pistons     True     True
# 34 2025-01-01            Daniss Jenkins  Detroit Pistons     True     True
# 35 2025-01-01             Bobi Klintman  Detroit Pistons     True     True
# 36 2025-01-01               Cole Swider  Detroit Pistons     True     True
# 37 2025-01-01          Alondes Williams  Detroit Pistons     True     True
#
#     DidNotPlay  FantasyPoints     MPTimeDelta     MP FG  ... Pos4 Pos5  \
# 0        False           20.5 0 days 00:34:23  34:23  8  ...  NaN  NaN
# 1        False           21.5 0 days 00:34:04  34:04  7  ...  NaN  NaN
# 2        False           28.5 0 days 00:33:49  33:49  9  ...  NaN  NaN
# 3        False           10.0 0 days 00:22:42  22:42  0  ...  NaN  NaN
# 4        False           13.0 0 days 00:22:39  22:39  3  ...  NaN  NaN
# 6        False            9.0 0 days 00:27:18  27:18  1  ...  NaN  NaN
# 7        False            9.0 0 days 00:15:19  15:19  2  ...  NaN  NaN
# 8        False            5.5 0 days 00:15:12  15:12  3  ...  NaN  NaN
# 9        False            7.0 0 days 00:15:02  15:02  1  ...  NaN  NaN
# 10       False           10.0 0 days 00:13:18  13:18  3  ...  NaN  NaN
# 11       False            3.0 0 days 00:06:14   6:14  0  ...  NaN  NaN
# 13       False           20.5 0 days 00:34:52  34:52  7  ...  NaN  NaN
# 14       False           25.5 0 days 00:34:20  34:20  7  ...  NaN  NaN
# 15       False           10.0 0 days 00:32:30  32:30  4  ...  NaN  NaN
# 16       False           15.5 0 days 00:26:45  26:45  8  ...  NaN  NaN
# 17       False           23.0 0 days 00:26:44  26:44  9  ...  NaN  NaN
# 19       False           14.0 0 days 00:24:46  24:46  3  ...  NaN  NaN
# 20       False            4.0 0 days 00:22:04  22:04  0  ...  NaN  NaN
# 21       False           17.0 0 days 00:21:16  21:16  2  ...  NaN  NaN
# 22       False            1.0 0 days 00:10:09  10:09  1  ...  NaN  NaN
# 23       False            0.0 0 days 00:06:34   6:34  0  ...  NaN  NaN
# 24        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 25        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 27        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 28        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 29        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 30        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 31        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 32        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 33        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 34        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 35        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 36        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
# 37        True            0.0 0 days 00:00:00      0  0  ...  NaN  NaN
#
#     correct_positions      GameID     OpponentTeam OpponentTeamAbv  \
# 0                True  2025011DET  Detroit Pistons             DET
# 1                True  2025011DET  Detroit Pistons             DET
# 2                True  2025011DET  Detroit Pistons             DET
# 3                True  2025011DET  Detroit Pistons             DET
# 4                True  2025011DET  Detroit Pistons             DET
# 6                True  2025011DET  Detroit Pistons             DET
# 7                True  2025011DET  Detroit Pistons             DET
# 8                True  2025011DET  Detroit Pistons             DET
# 9                True  2025011DET  Detroit Pistons             DET
# 10               True  2025011DET  Detroit Pistons             DET
# 11               True  2025011DET  Detroit Pistons             DET
# 13               True  2025011DET    Orlando Magic             ORL
# 14               True  2025011DET    Orlando Magic             ORL
# 15               True  2025011DET    Orlando Magic             ORL
# 16               True  2025011DET    Orlando Magic             ORL
# 17               True  2025011DET    Orlando Magic             ORL
# 19               True  2025011DET    Orlando Magic             ORL
# 20               True  2025011DET    Orlando Magic             ORL
# 21               True  2025011DET    Orlando Magic             ORL
# 22               True  2025011DET    Orlando Magic             ORL
# 23               True  2025011DET    Orlando Magic             ORL
# 24               True  2025011DET    Orlando Magic             ORL
# 25               True  2025011DET    Orlando Magic             ORL
# 27               True  2025011DET  Detroit Pistons             DET
# 28               True  2025011DET  Detroit Pistons             DET
# 29               True  2025011DET  Detroit Pistons             DET
# 30               True  2025011DET  Detroit Pistons             DET
# 31               True  2025011DET  Detroit Pistons             DET
# 32               True  2025011DET  Detroit Pistons             DET
# 33               True  2025011DET    Orlando Magic             ORL
# 34               True  2025011DET    Orlando Magic             ORL
# 35               True  2025011DET    Orlando Magic             ORL
# 36               True  2025011DET    Orlando Magic             ORL
# 37               True  2025011DET    Orlando Magic             ORL
#
#    InjTeamateCount Starting Top7InTeam  \
# 0                6     True       True
# 1                6     True       True
# 2                6     True       True
# 3                6     True       True
# 4                6     True       True
# 6                6    False       True
# 7                6    False       True
# 8                6    False      False
# 9                6    False      False
# 10               6    False      False
# 11               6    False      False
# 13               5     True       True
# 14               5     True       True
# 15               5     True       True
# 16               5     True       True
# 17               5     True       True
# 19               5    False       True
# 20               5    False       True
# 21               5    False      False
# 22               5    False      False
# 23               5    False      False
# 24               5    False      False
# 25               5    False      False
# 27               6    False      False
# 28               6    False      False
# 29               6    False      False
# 30               6    False      False
# 31               6    False      False
# 32               6    False      False
# 33               5    False      False
# 34               5    False      False
# 35               5    False      False
# 36               5    False      False
# 37               5    False      False
#
#                                             PhotoLink
# 0   https://www.basketball-reference.com/req/20210...
# 1   https://www.basketball-reference.com/req/20210...
# 2   https://www.basketball-reference.com/req/20210...
# 3   https://www.basketball-reference.com/req/20210...
# 4   https://www.basketball-reference.com/req/20210...
# 6   https://www.basketball-reference.com/req/20210...
# 7   https://www.basketball-reference.com/req/20210...
# 8   https://www.basketball-reference.com/req/20210...
# 9   https://www.basketball-reference.com/req/20210...
# 10  https://www.basketball-reference.com/req/20210...
# 11  https://www.basketball-reference.com/req/20210...
# 13  https://www.basketball-reference.com/req/20210...
# 14  https://www.basketball-reference.com/req/20210...
# 15  https://www.basketball-reference.com/req/20210...
# 16  https://www.basketball-reference.com/req/20210...
# 17  https://www.basketball-reference.com/req/20210...
# 19  https://www.basketball-reference.com/req/20210...
# 20  https://www.basketball-reference.com/req/20210...
# 21  https://www.basketball-reference.com/req/20210...
# 22  https://www.basketball-reference.com/req/20210...
# 23  https://www.basketball-reference.com/req/20210...
# 24  https://www.basketball-reference.com/req/20210...
# 25  https://www.basketball-reference.com/req/20210...
# 27  https://www.basketball-reference.com/req/20210...
# 28  https://www.basketball-reference.com/req/20210...
# 29  https://www.basketball-reference.com/req/20210...
# 30  https://www.basketball-reference.com/req/20210...
# 31  https://www.basketball-reference.com/req/20210...
# 32  https://www.basketball-reference.com/req/20210...
# 33  https://www.basketball-reference.com/req/20210...
# 34  https://www.basketball-reference.com/req/20210...
# 35  https://www.basketball-reference.com/req/20210...
# 36                                               None
# 37                                               None
#
# [34 rows x 54 columns]

# %%
get_boxscore_link(first_2025)
# Out:
# 'https://www.basketball-reference.com/boxscores/202501010DET.html'

# %%
stats
# Out:
#          Date              Starters         TeamName  WonGame  Injured  \
# 0  2024-10-22         Mikal Bridges  New York Knicks    False    False
# 1  2024-10-22            OG Anunoby  New York Knicks    False    False
# 2  2024-10-22         Jalen Brunson  New York Knicks    False    False
# 3  2024-10-22             Josh Hart  New York Knicks    False    False
# 4  2024-10-22    Karl-Anthony Towns  New York Knicks    False    False
# 6  2024-10-22         Miles McBride  New York Knicks    False    False
# 7  2024-10-22          Jericho Sims  New York Knicks    False    False
# 8  2024-10-22         Cameron Payne  New York Knicks    False    False
# 9  2024-10-22         Pacome Dadiet  New York Knicks    False    False
# 10 2024-10-22        Ariel Hukporti  New York Knicks    False    False
# 11 2024-10-22           Tyler Kolek  New York Knicks    False    False
# 12 2024-10-22          Jacob Toppin  New York Knicks    False    False
# 14 2024-10-22          Jrue Holiday   Boston Celtics     True    False
# 15 2024-10-22          Jayson Tatum   Boston Celtics     True    False
# 16 2024-10-22          Jaylen Brown   Boston Celtics     True    False
# 17 2024-10-22         Derrick White   Boston Celtics     True    False
# 18 2024-10-22            Al Horford   Boston Celtics     True    False
# 20 2024-10-22      Payton Pritchard   Boston Celtics     True    False
# 21 2024-10-22            Sam Hauser   Boston Celtics     True    False
# 22 2024-10-22           Luke Kornet   Boston Celtics     True    False
# 23 2024-10-22    Xavier Tillman Sr.   Boston Celtics     True    False
# 24 2024-10-22          Jordan Walsh   Boston Celtics     True    False
# 25 2024-10-22         Neemias Queta   Boston Celtics     True    False
# 26 2024-10-22     Baylor Scheierman   Boston Celtics     True    False
# 27 2024-10-22        Jaden Springer   Boston Celtics     True    False
# 29 2024-10-22      Precious Achiuwa  New York Knicks    False     True
# 30 2024-10-22    Kevin McCullar Jr.  New York Knicks    False     True
# 31 2024-10-22     Mitchell Robinson  New York Knicks    False     True
# 32 2024-10-22            JD Davison   Boston Celtics     True     True
# 33 2024-10-22         Drew Peterson   Boston Celtics     True     True
# 34 2024-10-22  Kristaps PorziÅÄ£is   Boston Celtics     True     True
# 35 2024-10-22          Anton Watson   Boston Celtics     True     True
#
#     DidNotPlay  FantasyPoints     MPTimeDelta     MP  FG  ... Pos4 Pos5  \
# 0        False           10.0 0 days 00:34:37  34:37   7  ...  NaN  NaN
# 1        False           12.0 0 days 00:34:10  34:10   1  ...  NaN  NaN
# 2        False           10.5 0 days 00:24:30  24:30   9  ...  NaN  NaN
# 3        False           12.0 0 days 00:24:30  24:30   4  ...  NaN  NaN
# 4        False           16.5 0 days 00:23:37  23:37   5  ...  NaN  NaN
# 6        False           14.0 0 days 00:25:51  25:51   8  ...  NaN  NaN
# 7        False           15.0 0 days 00:24:23  24:23   2  ...  NaN  NaN
# 8        False           14.0 0 days 00:20:43  20:43   5  ...  NaN  NaN
# 9        False            3.0 0 days 00:13:23  13:23   1  ...  NaN  NaN
# 10       False            6.0 0 days 00:06:05   6:05   0  ...  NaN  NaN
# 11       False            0.0 0 days 00:05:24   5:24   1  ...  NaN  NaN
# 12       False            0.0 0 days 00:02:47   2:47   0  ...  NaN  NaN
# 14       False           21.0 0 days 00:30:31  30:31   7  ...  NaN  NaN
# 15       False           40.5 0 days 00:30:18  30:18  14  ...  NaN  NaN
# 16       False           23.0 0 days 00:29:54  29:54   7  ...  NaN  NaN
# 17       False           24.0 0 days 00:26:38  26:38   8  ...  NaN  NaN
# 18       False           19.0 0 days 00:26:05  26:05   4  ...  NaN  NaN
# 20       False            9.0 0 days 00:24:58  24:58   1  ...  NaN  NaN
# 21       False           12.0 0 days 00:24:10  24:10   4  ...  NaN  NaN
# 22       False           10.0 0 days 00:19:19  19:19   2  ...  NaN  NaN
# 23       False           10.0 0 days 00:17:42  17:42   1  ...  NaN  NaN
# 24       False            1.0 0 days 00:06:05   6:05   0  ...  NaN  NaN
# 25       False            0.0 0 days 00:04:20   4:20   0  ...  NaN  NaN
# 26        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 27        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 29        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 30        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 31        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 32        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 33        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 34        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
# 35        True            0.0 0 days 00:00:00      0   0  ...  NaN  NaN
#
#     correct_positions       GameID     OpponentTeam OpponentTeamAbv  \
# 0                True  20242210BOS   Boston Celtics             BOS
# 1                True  20242210BOS   Boston Celtics             BOS
# 2                True  20242210BOS   Boston Celtics             BOS
# 3                True  20242210BOS   Boston Celtics             BOS
# 4                True  20242210BOS   Boston Celtics             BOS
# 6                True  20242210BOS   Boston Celtics             BOS
# 7                True  20242210BOS   Boston Celtics             BOS
# 8                True  20242210BOS   Boston Celtics             BOS
# 9                True  20242210BOS   Boston Celtics             BOS
# 10               True  20242210BOS   Boston Celtics             BOS
# 11               True  20242210BOS   Boston Celtics             BOS
# 12               True  20242210BOS   Boston Celtics             BOS
# 14               True  20242210BOS  New York Knicks             NYK
# 15               True  20242210BOS  New York Knicks             NYK
# 16               True  20242210BOS  New York Knicks             NYK
# 17               True  20242210BOS  New York Knicks             NYK
# 18               True  20242210BOS  New York Knicks             NYK
# 20               True  20242210BOS  New York Knicks             NYK
# 21               True  20242210BOS  New York Knicks             NYK
# 22               True  20242210BOS  New York Knicks             NYK
# 23               True  20242210BOS  New York Knicks             NYK
# 24               True  20242210BOS  New York Knicks             NYK
# 25               True  20242210BOS  New York Knicks             NYK
# 26               True  20242210BOS  New York Knicks             NYK
# 27               True  20242210BOS  New York Knicks             NYK
# 29               True  20242210BOS   Boston Celtics             BOS
# 30               True  20242210BOS   Boston Celtics             BOS
# 31               True  20242210BOS   Boston Celtics             BOS
# 32               True  20242210BOS  New York Knicks             NYK
# 33               True  20242210BOS  New York Knicks             NYK
# 34               True  20242210BOS  New York Knicks             NYK
# 35               True  20242210BOS  New York Knicks             NYK
#
#    InjTeamateCount Starting Top7InTeam  \
# 0                3     True       True
# 1                3     True       True
# 2                3     True       True
# 3                3     True       True
# 4                3     True       True
# 6                3    False       True
# 7                3    False       True
# 8                3    False      False
# 9                3    False      False
# 10               3    False      False
# 11               3    False      False
# 12               3    False      False
# 14               4     True       True
# 15               4     True       True
# 16               4     True       True
# 17               4     True       True
# 18               4     True       True
# 20               4    False       True
# 21               4    False       True
# 22               4    False      False
# 23               4    False      False
# 24               4    False      False
# 25               4    False      False
# 26               4    False      False
# 27               4    False      False
# 29               3    False      False
# 30               3    False      False
# 31               3    False      False
# 32               4    False      False
# 33               4    False      False
# 34               4    False      False
# 35               4    False      False
#
#                                             PhotoLink
# 0   https://www.basketball-reference.com/req/20210...
# 1   https://www.basketball-reference.com/req/20210...
# 2   https://www.basketball-reference.com/req/20210...
# 3   https://www.basketball-reference.com/req/20210...
# 4   https://www.basketball-reference.com/req/20210...
# 6   https://www.basketball-reference.com/req/20210...
# 7   https://www.basketball-reference.com/req/20210...
# 8   https://www.basketball-reference.com/req/20210...
# 9   https://www.basketball-reference.com/req/20210...
# 10  https://www.basketball-reference.com/req/20210...
# 11  https://www.basketball-reference.com/req/20210...
# 12  https://www.basketball-reference.com/req/20210...
# 14  https://www.basketball-reference.com/req/20210...
# 15  https://www.basketball-reference.com/req/20210...
# 16  https://www.basketball-reference.com/req/20210...
# 17  https://www.basketball-reference.com/req/20210...
# 18  https://www.basketball-reference.com/req/20210...
# 20  https://www.basketball-reference.com/req/20210...
# 21  https://www.basketball-reference.com/req/20210...
# 22  https://www.basketball-reference.com/req/20210...
# 23  https://www.basketball-reference.com/req/20210...
# 24  https://www.basketball-reference.com/req/20210...
# 25  https://www.basketball-reference.com/req/20210...
# 26  https://www.basketball-reference.com/req/20210...
# 27  https://www.basketball-reference.com/req/20210...
# 29  https://www.basketball-reference.com/req/20210...
# 30  https://www.basketball-reference.com/req/20210...
# 31  https://www.basketball-reference.com/req/20210...
# 32  https://www.basketball-reference.com/req/20210...
# 33  https://www.basketball-reference.com/req/20210...
# 34  https://www.basketball-reference.com/req/20210...
# 35  https://www.basketball-reference.com/req/20210...
#
# [32 rows x 54 columns]

# %%
smalldfdf
# Out:
#         Date Start (ET)         AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 0 2024-10-22      7:30p  New York Knicks    109.0  Boston Celtics    132.0
#
#    Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 0     False  19156.0               False  2024  ...     10    october
#
#   GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 0         True          BOS         NYK    True    False           23.0
#
#    AwayPointDiff       GameID
# 0          -23.0  20242210BOS
#
# [1 rows x 21 columns]

# %%
def final_df(year,existing_df,numaddrows, add_all):
    
    all_games_df = all_games_season(year)
    all_games_df = all_games_df[~all_games_df['GameID'].isin(existing_df['GameID'])]
    all_games_df = all_games_df[all_games_df['GameFinished'] == True]
    total_df = existing_df
    
    if add_all:
        for i in range(len(all_games_df)):
            game_df = player_scores_game(all_games_df.iloc[[i]])
            total_df = pd.concat([total_df, game_df], ignore_index=True, sort=False)
            time.sleep(10)
            print(f'Done with game #{i}')
            print(all_games_df.iloc[[i]])
    else:
        for i in range(numaddrows):
            game_df = player_scores_game(all_games_df.iloc[[i]])
            total_df = pd.concat([total_df, game_df], ignore_index=True, sort=False)
            time.sleep(10)
            print(f'Done with game #{i}')
            print(all_games_df.iloc[[i]])

    
    return total_df


#stats_2025 = final_df(2025)

# %% [markdown]
# ## To get positions, go through names (through teams or whatever) and do
# ## https://www.basketball-reference.com/players/w/wembavi01.html
# ## where the slash after players is the last name initial
# ## and then it is first 5 of last name (less if last name is smaller), and first 2 of first, then a number.
# ## try 01 first, and check if name on page matches title. if not add to number and try
# ## if error, don't put position.
#
# ## https://www.basketball-reference.com/teams/ATL/2025.html#all_roster
# ## this is format for each team roster in a table
#
# ## https://www.basketball-reference.com/players/j/jamesle01.html
# ## format for player name section

# %%
def team_link(teamabv, year):
    return f'https://www.basketball-reference.com/teams/{teamabv}/{year}.html#all_roster'

# %%
def team_players(team_link):
    URL = team_link
    response = requests.get(URL)
    response.status_code
    soup = BeautifulSoup(response.text, features="html.parser")
    soup.prettify()
    tables = soup.find_all('table')
    table_html = str(tables[0])
    df = pd.read_html(io.StringIO(table_html))[0]
    players_list = df['Player'].tolist()
    players_list = list(map(lambda x: x.split('(')[0].strip(), players_list))
    return players_list

# %%
suns = team_players(team_link('PHO',2025))
suns
# Out:
# ['Tyus Jones',
#  'Mason Plumlee',
#  'Ryan Dunn',
#  'Devin Booker',
#  "Royce O'Neale",
#  'Grayson Allen',
#  'Kevin Durant',
#  'Oso Ighodaro',
#  'Monte Morris',
#  'Bradley Beal',
#  'Bol Bol',
#  'Damion Lee',
#  'Nick Richards',
#  'Collin Gillespie',
#  'TyTy Washington Jr.',
#  'Jalen Bridges',
#  'Vasilije MiciÄ\x87',
#  'Cody Martin']

# %%
#Get rid of dashes and apostraphese and stuff like that, no jr. stuff counted for last name.


def player_link(name):
    
    firstname = name.split()[0]
    lastname = name.split()[1]
    firstname = "".join(char for char in firstname if char.isalpha()).lower()
    lastname = "".join(char for char in lastname if char.isalpha()).lower()
    lastinitial = lastname[0].lower()
    
    lastname5 = lastname[0:5]
    firstname2 = firstname[0:2]
    number = 1
    
    link = f'https://www.basketball-reference.com/players/{lastinitial}/{lastname5}{firstname2}0{number}.html'
    NotFound = True
    
    while NotFound:
        URL = link
        response = requests.get(URL)
        soup = BeautifulSoup(response.text, features="html.parser")
        h1_tag = soup.find('h1')
        player_name = h1_tag.text.strip()
        if player_name == name:
            print('Found it!')
            
            
            NotFound = False
        elif response.status_code != 200:
            print("Name Not Found....")
            NotFound = False
            positions = ['PG','SG','SF','PF','C']
        else:
            number += 1
            link = f'https://www.basketball-reference.com/players/{lastinitial}/{lastname5}{firstname2}0{number}.html'
            print(f'Didnt find it, trying again. This is {number} trying next.' )
        
    picturelink = f'https://www.basketball-reference.com/req/202106291/images/headshots/{lastname5}{firstname2}0{number}.jpg'
    linklist = []
    linklist.append(link)
    linklist.append(picturelink)
    return linklist

# %%
link = player_link("Devin Booker")
link
# Out:
# Found it!
# ['https://www.basketball-reference.com/players/b/bookede01.html',
#  'https://www.basketball-reference.com/req/202106291/images/headshots/bookede01.jpg']

# %%
def get_positions_link(link, testing = False):
    response = requests.get(link)
    if response.status_code != 200:
        positions = ['PG','SG','SF','PF','C']
        return positions
    else:
        soup = BeautifulSoup(response.text, features="html.parser")
        inactive_section = soup.find_all('p')
        for i in range(10):
            try:
                if testing:
                    print(f'Trying {i}')
                
                positions = inactive_section[i]
                
                strong_tag = positions.find('strong', string=lambda t: t and "Position:" in t)
                position_text = strong_tag.next_sibling.strip()
                break
            except:
                pass
            
            
            
        positions = position_text.strip()
        only_positions = positions.split('\n')[0]
        
        if ',' in only_positions:
            only_positions = only_positions.split(',')
        else:
            if 'and' in only_positions:
                only_positions = only_positions.split('and')
            else:
                only_positions = [only_positions]
        if testing:
            print(f'This is only positions: {only_positions}')
            
            
        final_positions = []
        position_dict = {
            'Point Guard':"PG",
            'Shooting Guard' : "SG",
            'Small Forward' : "SF",
            'Power Forward' : "PF",
            'Center' : "C",
            'Forward' : "SF",
            'Guard' : 'PG'
        }
        for i in range(len(only_positions)):
            cleaned_string = only_positions[i].replace("and", "")
            if testing:
                print(f'This is cleaned_string: {cleaned_string}')
            cleaned_string = cleaned_string.strip()
            if testing:
                print(f'This is cleaned_string: {cleaned_string}')
            
            cleaned_string = position_dict[cleaned_string]
            
            final_positions.append(cleaned_string)
            
        
        return final_positions

# %%
get_positions_link('https://www.basketball-reference.com/players/j/fefsef01.html')
# Out:
# ['PG', 'SG', 'SF', 'PF', 'C']

# %%
def name_to_positions(name, testing = False):
    link = player_link(name)
    positions = get_positions_link(link[0], testing = testing)
    positionsandlink = []
    positionsandlink.append(positions)
    positionsandlink.append(link[1])
    return positionsandlink

# %%
name_to_positions('Mikal Bridges')
# Out:
# Found it!
# [['SF', 'SG'],
#  'https://www.basketball-reference.com/req/202106291/images/headshots/bridgmi01.jpg']

# %%
team_players(team_link('PHO',2025))
# Out:
# ['Tyus Jones',
#  'Mason Plumlee',
#  'Ryan Dunn',
#  'Devin Booker',
#  "Royce O'Neale",
#  'Grayson Allen',
#  'Kevin Durant',
#  'Oso Ighodaro',
#  'Monte Morris',
#  'Bradley Beal',
#  'Bol Bol',
#  'Damion Lee',
#  'Nick Richards',
#  'Collin Gillespie',
#  'TyTy Washington Jr.',
#  'Jalen Bridges',
#  'Vasilije MiciÄ\x87',
#  'Cody Martin']

# %%
def get_positions(team_abv,year):
    link = team_link(team_abv,year)
    list_players = team_players(link)
    
    
    
    names_list = []
    pos1_list = []
    pos2_list = []
    pos3_list = []
    pos4_list = []
    pos5_list = []
    picture_link = []
    for name in list_players:
        time.sleep(8)
        
        positionsAll = name_to_positions(name, False)
        positions = positionsAll[0]
        
        names_list.append(name)
        
        for i in range(5):
            if i == 0:
                try:
                    pos1_list.append(positions[i])
                except:
                    pos1_list.append(np.nan)
            if i == 1:
                try:
                    pos2_list.append(positions[i])
                except:
                    pos2_list.append(np.nan)
            if i == 2:
                try:
                    pos3_list.append(positions[i])
                except:
                    pos3_list.append(np.nan)
            if i == 3:
                try:
                    pos4_list.append(positions[i])
                except:
                    pos4_list.append(np.nan)
            if i == 4:
                try:
                    pos5_list.append(positions[i])
                except:
                    pos5_list.append(np.nan)
        
        picture_link.append(positionsAll[1])
        print(names_list)
        #print(pos1_list)
        #print(pos2_list)
        #print(pos3_list)
        #print(pos4_list)
        #print(pos5_list)
    
    
    df = pd.DataFrame(
        {
            'Players':names_list,
            'Pos1':pos1_list,
            'Pos2':pos2_list,
            'Pos3':pos3_list,
            'Pos4':pos4_list,
            'Pos5':pos5_list,
            'PictureLink':picture_link
            
        }
    )
    
    return df

# %%
nba_teams = list(nba_team_names.keys())
nba_teams
# Out:
# ['ATL',
#  'BOS',
#  'BRK',
#  'CHO',
#  'CHI',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NOP',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHO',
#  'POR',
#  'SAC',
#  'SAS',
#  'TOR',
#  'UTA',
#  'WAS']

# %%
remaining_teams = ['PHI','PHO','POR','SAC','SAS','TOR','UTA','WAS']

# %%
# all_player_pos2 = pd.read_csv("../data/positions2.csv")


# for abr in remaining_teams:
#     df = get_positions(abr,2025)
#     all_player_pos2 =  pd.concat([df, all_player_pos2], ignore_index=True, sort=False)
#     all_player_pos2.to_csv('../data/positions2.csv')
    
# all_player_pos2

# %%
cool
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 cool
#
# NameError: name 'cool' is not defined

# %%
final_dataframe = pd.read_csv("../data/full_nba_data_2.csv")
final_dataframe["Date"] = pd.to_datetime(final_dataframe["Date"], format="mixed")
final_dataframe

# %%
def add_fantasy_averages(df):
    
    df = df.copy()  # Avoid modifying original dataframe
    df["_original_index"] = df.index  # Store original index
    
    df = df.sort_values(by=["Starters", "Date"])  # Sort by player and date

    # Calculate cumulative average per player
    df["AvgFantPoints"] = df.groupby("Starters")["FantasyPoints"].expanding().mean().reset_index(level=0, drop=True)

    df = df.sort_values(by="_original_index").drop(columns=["_original_index"])  # Restore original order

    return df

# %%
def add_fantasy_averages_new(df):
    
    df["AvgFantPoints"] = df.apply(lambda row: df[
    (df["Starters"] == row["Starters"]) &  # Same player
    (df["Date"] < row["Date"]) &  # Only past games
    (~df["DidNotPlay"])  # Only games where the player actually played
    ]["FantasyPoints"].mean(), axis=1)


    return df

# %%
def add_fantasy_averages_new_new(df):
    #df = df.sort_values(["Starters", "Date"])  # Ensure chronological order for each player

    avg_fantasy = []
    avg_fantasy_last10 = []
    avg_points = []
    avg_points_last10 = []
    avg_assists = []
    avg_assists_last10 = []
    avg_rebounds = []
    avg_rebounds_last10 = []
    avg_steals = []
    avg_steals_last10 = []
    avg_blocks = []
    avg_blocks_last10 = []
    avg_turnovers = []
    avg_turnovers_last10 = []
    avg_threepointers = []
    avg_threepointers_last10 = []
    
    avg_mp_time = []
    avg_mp_time_last10 = []

    # Convert MPTimeDelta to timedelta format
    df["MPTimeDelta"] = pd.to_timedelta(df["MPTimeDelta"])

    for idx, row in df.iterrows():
        past_games = df[
            (df["Starters"] == row["Starters"]) & 
            (df["Date"] < row["Date"]) & 
            (~df["DidNotPlay"])
        ].copy()  # ✅ Copy to avoid potential SettingWithCopyWarning

        # Convert MPTimeDelta to minutes as float
        past_games["MPMinutes"] = past_games["MPTimeDelta"].dt.total_seconds() / 60

        # Calculate averages
        avg_fantasy.append(past_games["FantasyPoints"].mean())
        avg_points.append(past_games["PTS"].mean())
        avg_assists.append(past_games["AST"].mean())
        avg_rebounds.append(past_games["TRB"].mean())
        avg_steals.append(past_games["STL"].mean())
        avg_blocks.append(past_games["BLK"].mean())
        avg_turnovers.append(past_games["TOV"].mean())
        avg_threepointers.append(past_games["3P"].mean())

        last_10_games = past_games.tail(10).copy()  # ✅ Copy ensures "MPMinutes" exists

        avg_fantasy_last10.append(last_10_games["FantasyPoints"].mean())
        avg_points_last10.append(last_10_games["PTS"].mean())
        avg_assists_last10.append(last_10_games["AST"].mean())
        avg_rebounds_last10.append(last_10_games["TRB"].mean())
        avg_steals_last10.append(last_10_games["STL"].mean())
        avg_blocks_last10.append(last_10_games["BLK"].mean())
        avg_turnovers_last10.append(last_10_games["TOV"].mean())
        avg_threepointers_last10.append(last_10_games["3P"].mean())
        
        
        
        
        avg_mp_time.append(past_games["MPMinutes"].mean())

        # Ensure 'MPMinutes' exists in last_10_games before computing mean
        avg_mp_time_last10.append(last_10_games["MPMinutes"].mean() if not last_10_games.empty else None)

    # Assign new columns
    df["AvgPoints"] = avg_points
    df["AvgPointsLast10"] = avg_points_last10
    df["AvgAssists"] = avg_assists
    df["AvgAssistsLast10"] = avg_assists_last10
    df["AvgRebounds"] = avg_rebounds
    df["AvgReboundsLast10"] = avg_rebounds_last10
    df["AvgSteals"] = avg_steals
    df["AvgStealsLast10"] = avg_steals_last10
    df["AvgBlocks"] = avg_blocks
    df["AvgBlocksLast10"] = avg_blocks_last10
    df["AvgTurnovers"] = avg_turnovers
    df["AvgTurnoversLast10"] = avg_turnovers_last10
    df["AvgThreePointers"] = avg_threepointers
    df["AvgThreePointersLast10"] = avg_threepointers_last10
    

    return df

# %%
def add_injury_counts(df):
    # Ensure correct data types
    
    
    # Create empty lists for new columns
    prev_inj_count = []
    opp_inj_count = []
    opp_prev_inj_count = []

    # Convert Date to datetime if not already
    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

    # Create a lookup table for previous injuries by team
    prev_injury_lookup = {}

    # Iterate over each row
    for idx, row in df.iterrows():
        team = row["TeamAbv"]
        opp_team = row["OpponentTeamAbv"]
        game_id = row["GameID"]

        # Get previous injury count for the team
        prev_value = prev_injury_lookup.get(team, None)
        prev_inj_count.append(prev_value)

        # Get opponent's injury count for the current game
        opp_injury = df[(df["GameID"] == game_id) & (df["TeamAbv"] == opp_team)]["InjTeamateCount"]
        opp_inj_count.append(opp_injury.mean() if not opp_injury.empty else None)

        # Get previous injury count for the opponent
        opp_prev_value = prev_injury_lookup.get(opp_team, None)
        opp_prev_inj_count.append(opp_prev_value)

        # Update lookup table with the current team's injury count
        prev_injury_lookup[team] = row["InjTeamateCount"]

    # Assign new columns
    df["PrevInjuredCount"] = prev_inj_count
    df["OpponentInjTeamateCount"] = opp_inj_count
    df["OpponentPrevInjuredCount"] = opp_prev_inj_count

    return df

# %%
testing_opp_df = add_injury_counts(new_df_2)

# %%
testing_opp_df[1490:1505]#["GameID"]

# %%
new_df_2.head(10)

# %%
new_df_2.columns

# %%
testingdataframe[testingdataframe['Starters'] == 'LeBron James']

# %%
def cut_dataframe(nba_data, ending_date, team_name):
    # Filter data based on date and team criteria
    cut_data = nba_data[
        (nba_data["Date"] < ending_date) &
        (nba_data["Date"] > nba_data["Date"].min()) &
        (nba_data["OpponentTeamAbv"] == team_name) &
        (nba_data["Top7InTeam"] == True)
    ]

    # Group by position and calculate mean fantasy points
    cut_data = cut_data.groupby("Pos1", as_index=False).agg(AvgFantPoints=("FantasyPoints", "mean"))
    
    # Add team and date columns
    cut_data["team"] = team_name
    cut_data["date"] = ending_date

    # Compute team-level statistics
    team_games = nba_data[
        (nba_data["Date"] < ending_date) &
        (nba_data["Date"] >= nba_data["Date"].min()) &
        (nba_data["OpponentTeamAbv"] == team_name)
    ].groupby("GameID", as_index=False).agg(
        Loss=("WonGame", lambda x: max(x)),  # If any player won, the team lost
        Win=("WonGame", lambda x: max(x == False)),  # If any player lost, the team won
        PointDiff=("GamePointDiff", lambda x: -max(x))  # Reverse point diff
    )

    # Calculate win percentage and total point differential
    win_percentage = team_games["Win"].sum() / len(team_games) if len(team_games) > 0 else 0
    point_diff = team_games["PointDiff"].sum() if len(team_games) > 0 else 0

    # Add win percentage and point differential
    cut_data["WinPercentage"] = win_percentage
    cut_data["PointDiff"] = point_diff

    # Add overall average row
    overall_avg = pd.DataFrame([{
        "Pos1": "ALL",
        "AvgFantPoints": cut_data["AvgFantPoints"].mean(),
        "team": team_name,
        "date": ending_date,
        "WinPercentage": win_percentage,
        "PointDiff": point_diff
    }])

    # Append overall average row
    cut_data = pd.concat([cut_data, overall_avg], ignore_index=True)

    return cut_data

# %%
testing = cut_dataframe(final_dataframe,pd.to_datetime("2025-01-06"),"WAS")

testing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 testing = cut_dataframe(final_dataframe,pd.to_datetime("2025-01-06"),"WAS")
#       3 testing
#
# NameError: name 'final_dataframe' is not defined

# %%
def whole_team_dataframe(nba_data, team_name):
    start_date = pd.to_datetime("2024-10-25")
    end_date = nba_data["Date"].max()
    date_sequence = pd.date_range(start=start_date, end=end_date, freq="D")

    # Loop through dates and combine results into one dataframe
    full_team_df = pd.concat([cut_dataframe(nba_data, date, team_name) for date in date_sequence], ignore_index=True)

    return full_team_df

# %%
def generate_full_nba_dataframe(nba_data):
    nba_team_abbreviations = [
        "ATL", "BOS", "BRK", "CHO", "CHI", "CLE", "DAL", "DEN", "DET", "GSW",
        "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL", "MIN", "NOP", "NYK",
        "OKC", "ORL", "PHI", "PHO", "POR", "SAC", "SAS", "TOR", "UTA", "WAS"
    ]

    # Loop through each team abbreviation and combine results into one dataframe
    full_nba_df = pd.concat([whole_team_dataframe(nba_data, team) for team in nba_team_abbreviations], ignore_index=True)

    # Rank within each date & position
    full_nba_df["FantPointsAgainstRank"] = full_nba_df.groupby(["date", "Pos1"])["AvgFantPoints"].rank(method="min")

    return full_nba_df

# %%
teams = generate_full_nba_dataframe(final_dataframe)

# %%
teams

# %%
final_dataframe['Date'] = pd.to_datetime(final_dataframe['Date'])
teams['date'] = pd.to_datetime(teams['date'])

# %%
teams_unique = teams.drop_duplicates()
teams_unique

# %%
nba_data_merged = final_dataframe.merge(
    teams[['date', 'team', 'FantPointsAgainstRank', 'PointDiff','WinPercentage']],  
    left_on=['Date', 'OpponentTeamAbv'], 
    right_on=['date', 'team'], 
    how='left'
).drop(columns=['team','date'])
nba_data_merged

# %%
positional_ranks = teams.pivot(index=['date', 'team'], columns='Pos1', values='FantPointsAgainstRank')
positional_ranks = positional_ranks.reset_index()
positional_ranks

# %%
def add_opponent_info(MainDF):
    
    teams = generate_full_nba_dataframe(MainDF)
    
    print(MainDF)
    print(teams)
    print("Checkpoint1")


    MainDF['Date'] = pd.to_datetime(MainDF['Date'], format = 'mixed')
    teams['date'] = pd.to_datetime(teams['date'])

    teams_noposition =  teams.drop_duplicates(subset=['date', 'team'])
    nba_data_merged = MainDF.merge(
        teams_noposition[['date', 'team', 'FantPointsAgainstRank', 'PointDiff','WinPercentage']],  
        left_on=['Date', 'OpponentTeamAbv'], 
        right_on=['date', 'team'], 
        how='left'
    ).drop(columns=['team','date'])

    print(nba_data_merged)
    print("Checkpoint2")
    positional_ranks = teams.pivot(index=['date', 'team'], columns='Pos1', values='FantPointsAgainstRank')
    positional_ranks = positional_ranks.reset_index()

    nba_data_merged = nba_data_merged.merge(
        positional_ranks, 
        left_on=['Date', 'OpponentTeamAbv'], 
        right_on=['date', 'team'], 
        how='left'
    ).drop(columns=['team','date'])

    nba_data_merged.rename(columns = {'PointDiff':'OpponentPointDiff','WinPercentage':'OpponentWinPercentage','ALL':'OppFantDefense: ALL','C':'OppFantDefense: C','PF_y':'OppFantDefense: PF','PG':'OppFantDefense: PG','SF':'OppFantDefense: SF','SG':'OppFantDefense: SG', 'PF_x':'PF'}, inplace = True)

    
    print(nba_data_merged)
    print("Checkpoint3")
    
    
    return(nba_data_merged)

# %%
def update_full_data(rows_to_add = 10, add_all = False):
    existing_dataframe = pd.read_csv("../data/full_nba_data.csv")
    existing_dataframe = existing_dataframe[['Date','Starters','TeamName','WonGame','Injured','DidNotPlay','FantasyPoints','MPTimeDelta','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','GmSc','+/-','TeamAbv','Year','Day','Month#','MonthName','Day_of_week','Home','GamePointDiff','Start(ET)','Overtime','Attend.','InSeasonTournament','Pos1','Pos2','Pos3','Pos4','Pos5','correct_positions','GameID','OpponentTeam','OpponentTeamAbv','InjTeamateCount','Starting']]
    existing_dataframe

    new_df = final_df(2025, existing_dataframe, rows_to_add, add_all)
    new_df.to_csv('../data/full_nba_data.csv')
    return new_df

# %%
existing_dataframe = stats
existing_dataframe
existing_dataframe.to_csv('../data/full_nba_data_2.csv')

# %%
def update_full_data_new(rows_to_add = 10, add_all = False):
    existing_dataframe = pd.read_csv("../data/full_nba_data.csv")

    existing_dataframe = existing_dataframe[['Date','Starters','TeamName','WonGame','Injured','DidNotPlay','FantasyPoints','MPTimeDelta','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','GmSc','+/-','TeamAbv','Year','Day','Month#','MonthName','Day_of_week','Home','GamePointDiff','Start(ET)','Overtime','Attend.','InSeasonTournament','Pos1','Pos2','Pos3','Pos4','Pos5','correct_positions','GameID','OpponentTeam','OpponentTeamAbv','InjTeamateCount', 'Starting','Top7InTeam','PhotoLink']]
    existing_dataframe

    new_df = final_df(2025, existing_dataframe, rows_to_add, add_all)
    new_df['Date'] = pd.to_datetime(new_df['Date'], format = 'mixed')
    new_df = add_opponent_info(new_df)
    new_df = add_fantasy_averages_new_new(new_df)
    new_df = add_injury_counts(new_df)
    new_df.to_csv('../data/full_nba_data.csv')
    return new_df

# %%
existing_dataframe['MPTimeDelta'].dtypes

# %%
new_df_2 = update_full_data_new(add_all = True)
new_df_2
# Out:
# Done with game #0
#          Date Start (ET)          AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 42 2025-02-06      7:30p  Dallas Mavericks    127.0  Boston Celtics    120.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 42     False  19156.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 42         True          BOS         DAL   False     True           -7.0
#
#     AwayPointDiff      GameID
# 42            7.0  2025062BOS
#
# [1 rows x 21 columns]
# Done with game #1
#          Date Start (ET)         AwayTeam  AwayPTS                HomeTeam  \
# 43 2025-02-06      8:00p  Houston Rockets    114.0  Minnesota Timberwolves
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 43    127.0     False  18978.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 43   february         True          MIN         HOU    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 43           13.0          -13.0  2025062MIN
#
# [1 rows x 21 columns]
# Done with game #2
#          Date Start (ET)       AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 44 2025-02-06      9:00p  Orlando Magic     90.0  Denver Nuggets    112.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 44     False  19616.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 44         True          DEN         ORL    True    False           22.0
#
#     AwayPointDiff      GameID
# 44          -22.0  2025062DEN
#
# [1 rows x 21 columns]
# Done with game #3
#          Date Start (ET)               AwayTeam  AwayPTS            HomeTeam  \
# 45 2025-02-06     10:00p  Golden State Warriors    112.0  Los Angeles Lakers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 45    120.0     False  18997.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 45   february         True          LAL         GSW    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 45            8.0           -8.0  2025062LAL
#
# [1 rows x 21 columns]
# Done with game #4
#          Date Start (ET)          AwayTeam  AwayPTS                HomeTeam  \
# 46 2025-02-06     10:00p  Sacramento Kings    102.0  Portland Trail Blazers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 46    108.0     False  16953.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 46   february         True          POR         SAC    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 46            6.0           -6.0  2025062POR
#
# [1 rows x 21 columns]
# Done with game #5
#          Date Start (ET)        AwayTeam  AwayPTS              HomeTeam  \
# 47 2025-02-06     10:30p  Indiana Pacers    119.0  Los Angeles Clippers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 47    112.0     False  13458.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 47   february         True          LAC         IND   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 47           -7.0            7.0  2025062LAC
#
# [1 rows x 21 columns]
# Done with game #6
#          Date Start (ET)           AwayTeam  AwayPTS           HomeTeam  \
# 48 2025-02-07      7:00p  San Antonio Spurs    116.0  Charlotte Hornets
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 48    117.0     False  19290.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 48   february         True          CHO         SAS    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 48            1.0           -1.0  2025072CHO
#
# [1 rows x 21 columns]
# Done with game #7
#          Date Start (ET)             AwayTeam  AwayPTS            HomeTeam  \
# 49 2025-02-07      7:00p  Cleveland Cavaliers    134.0  Washington Wizards
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 49    124.0     False  20385.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 49   february         True          WAS         CLE   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 49          -10.0           10.0  2025072WAS
#
# [1 rows x 21 columns]
# Done with game #8
#          Date Start (ET)         AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 50 2025-02-07      7:30p  Milwaukee Bucks    110.0  Atlanta Hawks    115.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 50     False  16378.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 50         True          ATL         MIL    True    False            5.0
#
#     AwayPointDiff      GameID
# 50           -5.0  2025072ATL
#
# [1 rows x 21 columns]
# Done with game #9
#          Date Start (ET)    AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 51 2025-02-07      7:30p  Miami Heat     86.0  Brooklyn Nets    102.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 51     False  17926.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 51         True          BRK         MIA    True    False           16.0
#
#     AwayPointDiff      GameID
# 51          -16.0  2025072BRK
#
# [1 rows x 21 columns]
# Done with game #10
#          Date Start (ET)            AwayTeam  AwayPTS         HomeTeam  \
# 52 2025-02-07      7:30p  Philadelphia 76ers    112.0  Detroit Pistons
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 52    125.0     False  19241.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 52   february         True          DET         PHI    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 52           13.0          -13.0  2025072DET
#
# [1 rows x 21 columns]
# Done with game #11
#          Date Start (ET)         AwayTeam  AwayPTS               HomeTeam  \
# 53 2025-02-07      8:00p  Toronto Raptors    109.0  Oklahoma City Thunder
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 53    121.0     False  18203.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 53   february         True          OKC         TOR    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 53           12.0          -12.0  2025072OKC
#
# [1 rows x 21 columns]
# Done with game #12
#          Date Start (ET)   AwayTeam  AwayPTS      HomeTeam  HomePTS  Overtime  \
# 54 2025-02-07     10:00p  Utah Jazz    127.0  Phoenix Suns    135.0      True
#
#     Attend.  InSeasonTournament  Year  ... Month#  MonthName GameFinished  \
# 54  17071.0               False  2025  ...      2   february         True
#
#     HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  AwayPointDiff  \
# 54          PHO         UTA    True    False            8.0           -8.0
#
#         GameID
# 54  2025072PHO
#
# [1 rows x 21 columns]
# Done with game #13
#          Date Start (ET)         AwayTeam  AwayPTS          HomeTeam  HomePTS  \
# 55 2025-02-08      3:00p  Houston Rockets    105.0  Dallas Mavericks    116.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 55     False  20303.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 55         True          DAL         HOU    True    False           11.0
#
#     AwayPointDiff      GameID
# 55          -11.0  2025082DAL
#
# [1 rows x 21 columns]
# Done with game #14
#          Date Start (ET)        AwayTeam  AwayPTS            HomeTeam  \
# 56 2025-02-08      4:00p  Indiana Pacers    117.0  Los Angeles Lakers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 56    124.0     False  18997.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 56   february         True          LAL         IND    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 56            7.0           -7.0  2025082LAL
#
# [1 rows x 21 columns]
# Done with game #15
#          Date Start (ET)           AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 57 2025-02-08      7:00p  San Antonio Spurs    111.0  Orlando Magic    112.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 57     False  19354.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 57         True          ORL         SAS    True    False            1.0
#
#     AwayPointDiff      GameID
# 57           -1.0  2025082ORL
#
# [1 rows x 21 columns]
# Done with game #16
#          Date Start (ET)       AwayTeam  AwayPTS            HomeTeam  HomePTS  \
# 58 2025-02-08      7:00p  Atlanta Hawks    125.0  Washington Wizards    111.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 58     False  16835.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 58         True          WAS         ATL   False     True          -14.0
#
#     AwayPointDiff      GameID
# 58           14.0  2025082WAS
#
# [1 rows x 21 columns]
# Done with game #17
#          Date Start (ET)               AwayTeam  AwayPTS       HomeTeam  \
# 59 2025-02-08      8:00p  Golden State Warriors    132.0  Chicago Bulls
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 59    111.0     False  21297.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 59   february         True          CHI         GSW   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 59          -21.0           21.0  2025082CHI
#
# [1 rows x 21 columns]
# Done with game #18
#          Date Start (ET)               AwayTeam  AwayPTS           HomeTeam  \
# 60 2025-02-08      8:00p  Oklahoma City Thunder    125.0  Memphis Grizzlies
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 60    112.0     False  17794.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 60   february         True          MEM         OKC   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 60          -13.0           13.0  2025082MEM
#
# [1 rows x 21 columns]
# Done with game #19
#          Date Start (ET)                AwayTeam  AwayPTS  \
# 61 2025-02-08      8:00p  Portland Trail Blazers     98.0
#
#                   HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 61  Minnesota Timberwolves    114.0     False  18978.0               False
#
#     Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  \
# 61  2025  ...      2   february         True          MIN         POR    True
#
#     AwayWin  HomePointDiff  AwayPointDiff      GameID
# 61    False           16.0          -16.0  2025082MIN
#
# [1 rows x 21 columns]
# Done with game #20
#          Date Start (ET)        AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 62 2025-02-08      8:30p  Boston Celtics    131.0  New York Knicks    104.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 62     False  19812.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 62         True          NYK         BOS   False     True          -27.0
#
#     AwayPointDiff      GameID
# 62           27.0  2025082NYK
#
# [1 rows x 21 columns]
# Done with game #21
#          Date Start (ET)        AwayTeam  AwayPTS      HomeTeam  HomePTS  \
# 63 2025-02-08      9:00p  Denver Nuggets    122.0  Phoenix Suns    105.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 63     False  17071.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 63         True          PHO         DEN   False     True          -17.0
#
#     AwayPointDiff      GameID
# 63           17.0  2025082PHO
#
# [1 rows x 21 columns]
# Done with game #22
#          Date Start (ET)              AwayTeam  AwayPTS          HomeTeam  \
# 64 2025-02-08     10:00p  New Orleans Pelicans    118.0  Sacramento Kings
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 64    123.0     False  17832.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 64   february         True          SAC         NOP    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 64            5.0           -5.0  2025082SAC
#
# [1 rows x 21 columns]
# Done with game #23
#          Date Start (ET)   AwayTeam  AwayPTS              HomeTeam  HomePTS  \
# 65 2025-02-08     10:30p  Utah Jazz    110.0  Los Angeles Clippers    130.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 65     False  15892.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 65         True          LAC         UTA    True    False           20.0
#
#     AwayPointDiff      GameID
# 65          -20.0  2025082LAC
#
# [1 rows x 21 columns]
# Done with game #24
#          Date Start (ET)           AwayTeam  AwayPTS         HomeTeam  \
# 66 2025-02-09      1:00p  Charlotte Hornets    102.0  Detroit Pistons
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 66    112.0     False  18740.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 66   february         True          DET         CHO    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 66           10.0          -10.0  2025092DET
#
# [1 rows x 21 columns]
# Done with game #25
#          Date Start (ET)         AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 67 2025-02-09      2:00p  Toronto Raptors     87.0  Houston Rockets     94.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 67     False  16829.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 67         True          HOU         TOR    True    False            7.0
#
#     AwayPointDiff      GameID
# 67           -7.0  2025092HOU
#
# [1 rows x 21 columns]
# Done with game #26
#          Date Start (ET)            AwayTeam  AwayPTS         HomeTeam  \
# 68 2025-02-09      2:00p  Philadelphia 76ers    127.0  Milwaukee Bucks
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 68    135.0     False  17341.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 68   february         True          MIL         PHI    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 68            8.0           -8.0  2025092MIL
#
# [1 rows x 21 columns]
# Done with game #27
#          Date Start (ET)                AwayTeam  AwayPTS  \
# 69 2025-02-10      7:00p  Minnesota Timberwolves    107.0
#
#                HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  Year  \
# 69  Cleveland Cavaliers    128.0     False  19432.0               False  2025
#
#     ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  \
# 69  ...      2   february         True          CLE         MIN    True
#
#     AwayWin  HomePointDiff  AwayPointDiff      GameID
# 69    False           21.0          -21.0  2025102CLE
#
# [1 rows x 21 columns]
# Done with game #28
#          Date Start (ET)       AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 70 2025-02-10      7:00p  Atlanta Hawks    112.0  Orlando Magic    106.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 70     False  18055.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 70         True          ORL         ATL   False     True           -6.0
#
#     AwayPointDiff      GameID
# 70            6.0  2025102ORL
#
# [1 rows x 21 columns]
# Done with game #29
#          Date Start (ET)           AwayTeam  AwayPTS            HomeTeam  \
# 71 2025-02-10      7:00p  San Antonio Spurs    131.0  Washington Wizards
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 71    121.0     False  17446.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 71   february         True          WAS         SAS   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 71          -10.0           10.0  2025102WAS
#
# [1 rows x 21 columns]
# Done with game #30
#          Date Start (ET)           AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 72 2025-02-10      7:30p  Charlotte Hornets     89.0  Brooklyn Nets     97.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 72     False  16013.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 72         True          BRK         CHO    True    False            8.0
#
#     AwayPointDiff      GameID
# 72           -8.0  2025102BRK
#
# [1 rows x 21 columns]
# Done with game #31
#          Date Start (ET)        AwayTeam  AwayPTS    HomeTeam  HomePTS  \
# 73 2025-02-10      7:30p  Boston Celtics    103.0  Miami Heat     85.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 73     False  19961.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 73         True          MIA         BOS   False     True          -18.0
#
#     AwayPointDiff      GameID
# 73           18.0  2025102MIA
#
# [1 rows x 21 columns]
# Done with game #32
#          Date Start (ET)               AwayTeam  AwayPTS         HomeTeam  \
# 74 2025-02-10      8:00p  Golden State Warriors    125.0  Milwaukee Bucks
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 74    111.0     False  17341.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 74   february         True          MIL         GSW   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 74          -14.0           14.0  2025102MIL
#
# [1 rows x 21 columns]
# Done with game #33
#          Date Start (ET)              AwayTeam  AwayPTS  \
# 75 2025-02-10      8:00p  New Orleans Pelicans    101.0
#
#                  HomeTeam  HomePTS  Overtime  Attend.  InSeasonTournament  \
# 75  Oklahoma City Thunder    137.0     False  17340.0               False
#
#     Year  ... Month#  MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  \
# 75  2025  ...      2   february         True          OKC         NOP    True
#
#     AwayWin  HomePointDiff  AwayPointDiff      GameID
# 75    False           36.0          -36.0  2025102OKC
#
# [1 rows x 21 columns]
# Done with game #34
#          Date Start (ET)          AwayTeam  AwayPTS          HomeTeam  \
# 76 2025-02-10      8:30p  Sacramento Kings    129.0  Dallas Mavericks
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 76    128.0      True  19726.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 76   february         True          DAL         SAC   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 76           -1.0            1.0  2025102DAL
#
# [1 rows x 21 columns]
# Done with game #35
#          Date Start (ET)                AwayTeam  AwayPTS        HomeTeam  \
# 77 2025-02-10      9:00p  Portland Trail Blazers    117.0  Denver Nuggets
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 77    146.0     False  19535.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 77   february         True          DEN         POR    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 77           29.0          -29.0  2025102DEN
#
# [1 rows x 21 columns]
# Done with game #36
#          Date Start (ET)   AwayTeam  AwayPTS            HomeTeam  HomePTS  \
# 78 2025-02-10     10:30p  Utah Jazz    113.0  Los Angeles Lakers    132.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 78     False  18997.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 78         True          LAL         UTA    True    False           19.0
#
#     AwayPointDiff      GameID
# 78          -19.0  2025102LAL
#
# [1 rows x 21 columns]
# Done with game #37
#          Date Start (ET)         AwayTeam  AwayPTS            HomeTeam  \
# 79 2025-02-11      7:00p  Toronto Raptors    106.0  Philadelphia 76ers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 79    103.0     False  19767.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 79   february         True          PHI         TOR   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 79           -3.0            3.0  2025112PHI
#
# [1 rows x 21 columns]
# Done with game #38
#          Date Start (ET)         AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 80 2025-02-11      7:30p  New York Knicks    128.0  Indiana Pacers    115.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 80     False  16685.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 80         True          IND         NYK   False     True          -13.0
#
#     AwayPointDiff      GameID
# 80           13.0  2025112IND
#
# [1 rows x 21 columns]
# Done with game #39
#          Date Start (ET)         AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 81 2025-02-11      8:00p  Detroit Pistons    132.0  Chicago Bulls     92.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 81     False  18321.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 81         True          CHI         DET   False     True          -40.0
#
#     AwayPointDiff      GameID
# 81           40.0  2025112CHI
#
# [1 rows x 21 columns]
# Done with game #40
#          Date Start (ET)           AwayTeam  AwayPTS      HomeTeam  HomePTS  \
# 82 2025-02-11     10:00p  Memphis Grizzlies    119.0  Phoenix Suns    112.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 82     False  17071.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 82         True          PHO         MEM   False     True           -7.0
#
#     AwayPointDiff      GameID
# 82            7.0  2025112PHO
#
# [1 rows x 21 columns]
# Done with game #41
#          Date Start (ET)           AwayTeam  AwayPTS        HomeTeam  HomePTS  \
# 83 2025-02-12      7:00p  San Antonio Spurs    103.0  Boston Celtics    116.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 83     False  19156.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 83         True          BOS         SAS    True    False           13.0
#
#     AwayPointDiff      GameID
# 83          -13.0  2025122BOS
#
# [1 rows x 21 columns]
# Done with game #42
#          Date Start (ET)           AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 84 2025-02-12      7:00p  Charlotte Hornets     86.0  Orlando Magic    102.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 84     False  18947.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 84         True          ORL         CHO    True    False           16.0
#
#     AwayPointDiff      GameID
# 84          -16.0  2025122ORL
#
# [1 rows x 21 columns]
# Done with game #43
#          Date Start (ET)        AwayTeam  AwayPTS            HomeTeam  \
# 85 2025-02-12      7:00p  Indiana Pacers    134.0  Washington Wizards
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 85    130.0      True  11457.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 85   february         True          WAS         IND   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 85           -4.0            4.0  2025122WAS
#
# [1 rows x 21 columns]
# Done with game #44
#          Date Start (ET)            AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 86 2025-02-12      7:30p  Philadelphia 76ers     96.0  Brooklyn Nets    100.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 86     False  16133.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 86         True          BRK         PHI    True    False            4.0
#
#     AwayPointDiff      GameID
# 86           -4.0  2025122BRK
#
# [1 rows x 21 columns]
# Done with game #45
#          Date Start (ET)       AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 87 2025-02-12      7:30p  Atlanta Hawks    148.0  New York Knicks    149.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 87      True  19812.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 87         True          NYK         ATL    True    False            1.0
#
#     AwayPointDiff      GameID
# 87           -1.0  2025122NYK
#
# [1 rows x 21 columns]
# Done with game #46
#          Date Start (ET)             AwayTeam  AwayPTS         HomeTeam  \
# 88 2025-02-12      7:30p  Cleveland Cavaliers    131.0  Toronto Raptors
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 88    108.0     False  16549.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 88   february         True          TOR         CLE   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 88          -23.0           23.0  2025122TOR
#
# [1 rows x 21 columns]
# Done with game #47
#          Date Start (ET)         AwayTeam  AwayPTS       HomeTeam  HomePTS  \
# 89 2025-02-12      8:00p  Detroit Pistons    128.0  Chicago Bulls    110.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 89     False  18916.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 89         True          CHI         DET   False     True          -18.0
#
#     AwayPointDiff      GameID
# 89           18.0  2025122CHI
#
# [1 rows x 21 columns]
# Done with game #48
#          Date Start (ET)         AwayTeam  AwayPTS                HomeTeam  \
# 90 2025-02-12      8:00p  Milwaukee Bucks    103.0  Minnesota Timberwolves
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 90    101.0     False  18978.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 90   february         True          MIN         MIL   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 90           -2.0            2.0  2025122MIN
#
# [1 rows x 21 columns]
# Done with game #49
#          Date Start (ET)          AwayTeam  AwayPTS              HomeTeam  \
# 91 2025-02-12      8:00p  Sacramento Kings    119.0  New Orleans Pelicans
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 91    111.0     False  17444.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 91   february         True          NOP         SAC   False     True
#
#     HomePointDiff  AwayPointDiff      GameID
# 91           -8.0            8.0  2025122NOP
#
# [1 rows x 21 columns]
# Done with game #50
#          Date Start (ET)    AwayTeam  AwayPTS               HomeTeam  HomePTS  \
# 92 2025-02-12      8:00p  Miami Heat    101.0  Oklahoma City Thunder    115.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 92     False  17835.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 92         True          OKC         MIA    True    False           14.0
#
#     AwayPointDiff      GameID
# 92          -14.0  2025122OKC
#
# [1 rows x 21 columns]
# Done with game #51
#          Date Start (ET)      AwayTeam  AwayPTS         HomeTeam  HomePTS  \
# 93 2025-02-12      8:30p  Phoenix Suns    111.0  Houston Rockets    119.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 93     False  16227.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 93         True          HOU         PHO    True    False            8.0
#
#     AwayPointDiff      GameID
# 93           -8.0  2025122HOU
#
# [1 rows x 21 columns]
# Done with game #52
#          Date Start (ET)                AwayTeam  AwayPTS        HomeTeam  \
# 94 2025-02-12      9:00p  Portland Trail Blazers    121.0  Denver Nuggets
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 94    132.0     False  19901.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 94   february         True          DEN         POR    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 94           11.0          -11.0  2025122DEN
#
# [1 rows x 21 columns]
# Done with game #53
#          Date Start (ET)            AwayTeam  AwayPTS   HomeTeam  HomePTS  \
# 95 2025-02-12      9:00p  Los Angeles Lakers    119.0  Utah Jazz    131.0
#
#     Overtime  Attend.  InSeasonTournament  Year  ... Month#  MonthName  \
# 95     False  18175.0               False  2025  ...      2   february
#
#    GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  HomePointDiff  \
# 95         True          UTA         LAL    True    False           12.0
#
#     AwayPointDiff      GameID
# 95          -12.0  2025122UTA
#
# [1 rows x 21 columns]
# Done with game #54
#          Date Start (ET)               AwayTeam  AwayPTS          HomeTeam  \
# 96 2025-02-12      9:30p  Golden State Warriors    107.0  Dallas Mavericks
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 96    111.0     False  20311.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 96   february         True          DAL         GSW    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 96            4.0           -4.0  2025122DAL
#
# [1 rows x 21 columns]
# Done with game #55
#          Date Start (ET)           AwayTeam  AwayPTS              HomeTeam  \
# 97 2025-02-12     10:30p  Memphis Grizzlies    114.0  Los Angeles Clippers
#
#     HomePTS  Overtime  Attend.  InSeasonTournament  Year  ... Month#  \
# 97    128.0     False  14997.0               False  2025  ...      2
#
#     MonthName GameFinished  HomeTeamAbv AwayTeamAbv HomeWin  AwayWin  \
# 97   february         True          LAC         MEM    True    False
#
#     HomePointDiff  AwayPointDiff      GameID
# 97           14.0          -14.0  2025122LAC
#
# [1 rows x 21 columns]
#             Date            Starters              TeamName  WonGame  Injured  \
# 0     2024-10-22       Mikal Bridges       New York Knicks    False    False
# 1     2024-10-22          OG Anunoby       New York Knicks    False    False
# 2     2024-10-22       Jalen Brunson       New York Knicks    False    False
# 3     2024-10-22           Josh Hart       New York Knicks    False    False
# 4     2024-10-22  Karl-Anthony Towns       New York Knicks    False    False
# ...          ...                 ...                   ...      ...      ...
# 28424 2025-02-12  Vince Williams Jr.     Memphis Grizzlies    False     True
# 28425 2025-02-12        Drew Eubanks  Los Angeles Clippers     True     True
# 28426 2025-02-12     Trentyn Flowers  Los Angeles Clippers     True     True
# 28427 2025-02-12       Jordan Miller  Los Angeles Clippers     True     True
# 28428 2025-02-12         Ben Simmons  Los Angeles Clippers     True     True
#
#        DidNotPlay  FantasyPoints      MPTimeDelta     MP   FG  ... Pos4 Pos5  \
# 0           False           10.0  0 days 00:34:37  34:37  7.0  ...  NaN  NaN
# 1           False           12.0  0 days 00:34:10  34:10  1.0  ...  NaN  NaN
# 2           False           10.5  0 days 00:24:30  24:30  9.0  ...  NaN  NaN
# 3           False           12.0  0 days 00:24:30  24:30  4.0  ...  NaN  NaN
# 4           False           16.5  0 days 00:23:37  23:37  5.0  ...  NaN  NaN
# ...           ...            ...              ...    ...  ...  ...  ...  ...
# 28424        True            0.0  0 days 00:00:00      0    0  ...  NaN  NaN
# 28425        True            0.0  0 days 00:00:00      0    0  ...  NaN  NaN
# 28426        True            0.0  0 days 00:00:00      0    0  ...  NaN  NaN
# 28427        True            0.0  0 days 00:00:00      0    0  ...  NaN  NaN
# 28428        True            0.0  0 days 00:00:00      0    0  ...  NaN  NaN
#
#        correct_positions       GameID          OpponentTeam OpponentTeamAbv  \
# 0                   True  20242210BOS        Boston Celtics             BOS
# 1                   True  20242210BOS        Boston Celtics             BOS
# 2                   True  20242210BOS        Boston Celtics             BOS
# 3                   True  20242210BOS        Boston Celtics             BOS
# 4                   True  20242210BOS        Boston Celtics             BOS
# ...                  ...          ...                   ...             ...
# 28424               True   2025122LAC  Los Angeles Clippers             LAC
# 28425               True   2025122LAC     Memphis Grizzlies             MEM
# 28426               True   2025122LAC     Memphis Grizzlies             MEM
# 28427              False   2025122LAC     Memphis Grizzlies             MEM
# 28428               True   2025122LAC     Memphis Grizzlies             MEM
#
#       InjTeamateCount Starting Top7InTeam  \
# 0                   3     True       True
# 1                   3     True       True
# 2                   3     True       True
# 3                   3     True       True
# 4                   3     True       True
# ...               ...      ...        ...
# 28424               5    False      False
# 28425               4    False      False
# 28426               4    False      False
# 28427               4    False      False
# 28428               4    False      False
#
#                                                PhotoLink
# 0      https://www.basketball-reference.com/req/20210...
# 1      https://www.basketball-reference.com/req/20210...
# 2      https://www.basketball-reference.com/req/20210...
# 3      https://www.basketball-reference.com/req/20210...
# 4      https://www.basketball-reference.com/req/20210...
# ...                                                  ...
# 28424  https://www.basketball-reference.com/req/20210...
# 28425  https://www.basketball-reference.com/req/20210...
# 28426  https://www.basketball-reference.com/req/20210...
# 28427  https://www.basketball-reference.com/req/20210...
# 28428  https://www.basketball-reference.com/req/20210...
#
# [28429 rows x 54 columns]
#       Pos1  AvgFantPoints team       date  WinPercentage  PointDiff  \
# 0       PF      15.833333  ATL 2024-10-25       1.000000        4.0
# 1       PG      13.250000  ATL 2024-10-25       1.000000        4.0
# 2       SF       8.500000  ATL 2024-10-25       1.000000        4.0
# 3       SG      33.500000  ATL 2024-10-25       1.000000        4.0
# 4      ALL      17.770833  ATL 2024-10-25       1.000000        4.0
# ...    ...            ...  ...        ...            ...        ...
# 19936   PF      18.300000  WAS 2025-02-12       0.169811     -721.0
# 19937   PG      21.921053  WAS 2025-02-12       0.169811     -721.0
# 19938   SF      20.013889  WAS 2025-02-12       0.169811     -721.0
# 19939   SG      16.691489  WAS 2025-02-12       0.169811     -721.0
# 19940  ALL      19.700564  WAS 2025-02-12       0.169811     -721.0
#
#        FantPointsAgainstRank
# 0                       10.0
# 1                        7.0
# 2                        3.0
# 3                       27.0
# 4                       15.0
# ...                      ...
# 19936                   26.0
# 19937                   30.0
# 19938                   30.0
# 19939                   22.0
# 19940                   30.0
#
# [19941 rows x 7 columns]
# Checkpoint1
#             Date            Starters              TeamName  WonGame  Injured  \
# 0     2024-10-22       Mikal Bridges       New York Knicks    False    False
# 1     2024-10-22          OG Anunoby       New York Knicks    False    False
# 2     2024-10-22       Jalen Brunson       New York Knicks    False    False
# 3     2024-10-22           Josh Hart       New York Knicks    False    False
# 4     2024-10-22  Karl-Anthony Towns       New York Knicks    False    False
# ...          ...                 ...                   ...      ...      ...
# 28424 2025-02-12  Vince Williams Jr.     Memphis Grizzlies    False     True
# 28425 2025-02-12        Drew Eubanks  Los Angeles Clippers     True     True
# 28426 2025-02-12     Trentyn Flowers  Los Angeles Clippers     True     True
# 28427 2025-02-12       Jordan Miller  Los Angeles Clippers     True     True
# 28428 2025-02-12         Ben Simmons  Los Angeles Clippers     True     True
#
#        DidNotPlay  FantasyPoints      MPTimeDelta     MP   FG  ...  \
# 0           False           10.0  0 days 00:34:37  34:37  7.0  ...
# 1           False           12.0  0 days 00:34:10  34:10  1.0  ...
# 2           False           10.5  0 days 00:24:30  24:30  9.0  ...
# 3           False           12.0  0 days 00:24:30  24:30  4.0  ...
# 4           False           16.5  0 days 00:23:37  23:37  5.0  ...
# ...           ...            ...              ...    ...  ...  ...
# 28424        True            0.0  0 days 00:00:00      0    0  ...
# 28425        True            0.0  0 days 00:00:00      0    0  ...
# 28426        True            0.0  0 days 00:00:00      0    0  ...
# 28427        True            0.0  0 days 00:00:00      0    0  ...
# 28428        True            0.0  0 days 00:00:00      0    0  ...
#
#             GameID          OpponentTeam  OpponentTeamAbv InjTeamateCount  \
# 0      20242210BOS        Boston Celtics              BOS               3
# 1      20242210BOS        Boston Celtics              BOS               3
# 2      20242210BOS        Boston Celtics              BOS               3
# 3      20242210BOS        Boston Celtics              BOS               3
# 4      20242210BOS        Boston Celtics              BOS               3
# ...            ...                   ...              ...             ...
# 28424   2025122LAC  Los Angeles Clippers              LAC               5
# 28425   2025122LAC     Memphis Grizzlies              MEM               4
# 28426   2025122LAC     Memphis Grizzlies              MEM               4
# 28427   2025122LAC     Memphis Grizzlies              MEM               4
# 28428   2025122LAC     Memphis Grizzlies              MEM               4
#
#       Starting Top7InTeam                                          PhotoLink  \
# 0         True       True  https://www.basketball-reference.com/req/20210...
# 1         True       True  https://www.basketball-reference.com/req/20210...
# 2         True       True  https://www.basketball-reference.com/req/20210...
# 3         True       True  https://www.basketball-reference.com/req/20210...
# 4         True       True  https://www.basketball-reference.com/req/20210...
# ...        ...        ...                                                ...
# 28424    False      False  https://www.basketball-reference.com/req/20210...
# 28425    False      False  https://www.basketball-reference.com/req/20210...
# 28426    False      False  https://www.basketball-reference.com/req/20210...
# 28427    False      False  https://www.basketball-reference.com/req/20210...
# 28428    False      False  https://www.basketball-reference.com/req/20210...
#
#       FantPointsAgainstRank PointDiff WinPercentage
# 0                       NaN       NaN           NaN
# 1                       NaN       NaN           NaN
# 2                       NaN       NaN           NaN
# 3                       NaN       NaN           NaN
# 4                       NaN       NaN           NaN
# ...                     ...       ...           ...
# 28424                  15.0     141.0      0.557692
# 28425                  21.0     419.0      0.679245
# 28426                  21.0     419.0      0.679245
# 28427                  21.0     419.0      0.679245
# 28428                  21.0     419.0      0.679245
#
# [28429 rows x 57 columns]
# Checkpoint2
#             Date            Starters              TeamName  WonGame  Injured  \
# 0     2024-10-22       Mikal Bridges       New York Knicks    False    False
# 1     2024-10-22          OG Anunoby       New York Knicks    False    False
# 2     2024-10-22       Jalen Brunson       New York Knicks    False    False
# 3     2024-10-22           Josh Hart       New York Knicks    False    False
# 4     2024-10-22  Karl-Anthony Towns       New York Knicks    False    False
# ...          ...                 ...                   ...      ...      ...
# 28424 2025-02-12  Vince Williams Jr.     Memphis Grizzlies    False     True
# 28425 2025-02-12        Drew Eubanks  Los Angeles Clippers     True     True
# 28426 2025-02-12     Trentyn Flowers  Los Angeles Clippers     True     True
# 28427 2025-02-12       Jordan Miller  Los Angeles Clippers     True     True
# 28428 2025-02-12         Ben Simmons  Los Angeles Clippers     True     True
#
#        DidNotPlay  FantasyPoints      MPTimeDelta     MP   FG  ...  \
# 0           False           10.0  0 days 00:34:37  34:37  7.0  ...
# 1           False           12.0  0 days 00:34:10  34:10  1.0  ...
# 2           False           10.5  0 days 00:24:30  24:30  9.0  ...
# 3           False           12.0  0 days 00:24:30  24:30  4.0  ...
# 4           False           16.5  0 days 00:23:37  23:37  5.0  ...
# ...           ...            ...              ...    ...  ...  ...
# 28424        True            0.0  0 days 00:00:00      0    0  ...
# 28425        True            0.0  0 days 00:00:00      0    0  ...
# 28426        True            0.0  0 days 00:00:00      0    0  ...
# 28427        True            0.0  0 days 00:00:00      0    0  ...
# 28428        True            0.0  0 days 00:00:00      0    0  ...
#
#                                                PhotoLink  \
# 0      https://www.basketball-reference.com/req/20210...
# 1      https://www.basketball-reference.com/req/20210...
# 2      https://www.basketball-reference.com/req/20210...
# 3      https://www.basketball-reference.com/req/20210...
# 4      https://www.basketball-reference.com/req/20210...
# ...                                                  ...
# 28424  https://www.basketball-reference.com/req/20210...
# 28425  https://www.basketball-reference.com/req/20210...
# 28426  https://www.basketball-reference.com/req/20210...
# 28427  https://www.basketball-reference.com/req/20210...
# 28428  https://www.basketball-reference.com/req/20210...
#
#       FantPointsAgainstRank  OpponentPointDiff OpponentWinPercentage  \
# 0                       NaN                NaN                   NaN
# 1                       NaN                NaN                   NaN
# 2                       NaN                NaN                   NaN
# 3                       NaN                NaN                   NaN
# 4                       NaN                NaN                   NaN
# ...                     ...                ...                   ...
# 28424                  15.0              141.0              0.557692
# 28425                  21.0              419.0              0.679245
# 28426                  21.0              419.0              0.679245
# 28427                  21.0              419.0              0.679245
# 28428                  21.0              419.0              0.679245
#
#       OppFantDefense: ALL OppFantDefense: C OppFantDefense: PF  \
# 0                     NaN               NaN                NaN
# 1                     NaN               NaN                NaN
# 2                     NaN               NaN                NaN
# 3                     NaN               NaN                NaN
# 4                     NaN               NaN                NaN
# ...                   ...               ...                ...
# 28424                 7.0              15.0                2.0
# 28425                18.0              21.0               28.0
# 28426                18.0              21.0               28.0
# 28427                18.0              21.0               28.0
# 28428                18.0              21.0               28.0
#
#       OppFantDefense: PG OppFantDefense: SF OppFantDefense: SG
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 28424               10.0               12.0               10.0
# 28425                5.0               21.0               17.0
# 28426                5.0               21.0               17.0
# 28427                5.0               21.0               17.0
# 28428                5.0               21.0               17.0
#
# [28429 rows x 63 columns]
# Checkpoint3
#             Date            Starters              TeamName  WonGame  Injured  \
# 0     2024-10-22       Mikal Bridges       New York Knicks    False    False
# 1     2024-10-22          OG Anunoby       New York Knicks    False    False
# 2     2024-10-22       Jalen Brunson       New York Knicks    False    False
# 3     2024-10-22           Josh Hart       New York Knicks    False    False
# 4     2024-10-22  Karl-Anthony Towns       New York Knicks    False    False
# ...          ...                 ...                   ...      ...      ...
# 28424 2025-02-12  Vince Williams Jr.     Memphis Grizzlies    False     True
# 28425 2025-02-12        Drew Eubanks  Los Angeles Clippers     True     True
# 28426 2025-02-12     Trentyn Flowers  Los Angeles Clippers     True     True
# 28427 2025-02-12       Jordan Miller  Los Angeles Clippers     True     True
# 28428 2025-02-12         Ben Simmons  Los Angeles Clippers     True     True
#
#        DidNotPlay  FantasyPoints     MPTimeDelta     MP   FG  ...  \
# 0           False           10.0 0 days 00:34:37  34:37  7.0  ...
# 1           False           12.0 0 days 00:34:10  34:10  1.0  ...
# 2           False           10.5 0 days 00:24:30  24:30  9.0  ...
# 3           False           12.0 0 days 00:24:30  24:30  4.0  ...
# 4           False           16.5 0 days 00:23:37  23:37  5.0  ...
# ...           ...            ...             ...    ...  ...  ...
# 28424        True            0.0 0 days 00:00:00      0    0  ...
# 28425        True            0.0 0 days 00:00:00      0    0  ...
# 28426        True            0.0 0 days 00:00:00      0    0  ...
# 28427        True            0.0 0 days 00:00:00      0    0  ...
# 28428        True            0.0 0 days 00:00:00      0    0  ...
#
#       AvgStealsLast10 AvgBlocks  AvgBlocksLast10 AvgTurnovers  \
# 0                 NaN       NaN              NaN          NaN
# 1                 NaN       NaN              NaN          NaN
# 2                 NaN       NaN              NaN          NaN
# 3                 NaN       NaN              NaN          NaN
# 4                 NaN       NaN              NaN          NaN
# ...               ...       ...              ...          ...
# 28424        0.333333  0.333333         0.333333     1.333333
# 28425        0.200000  0.825000         1.200000     0.775000
# 28426        0.000000  0.000000         0.000000     0.500000
# 28427        0.700000  0.166667         0.200000     0.733333
# 28428        0.600000  0.484848         0.400000     2.666667
#
#       AvgTurnoversLast10 AvgThreePointers AvgThreePointersLast10  \
# 0                    NaN              NaN                    NaN
# 1                    NaN              NaN                    NaN
# 2                    NaN              NaN                    NaN
# 3                    NaN              NaN                    NaN
# 4                    NaN              NaN                    NaN
# ...                  ...              ...                    ...
# 28424           1.333333         0.500000                    0.5
# 28425           0.400000         0.075000                    0.1
# 28426           0.500000         0.000000                    0.0
# 28427           0.500000         0.266667                    0.1
# 28428           2.400000         0.000000                    0.0
#
#       PrevInjuredCount OpponentInjTeamateCount OpponentPrevInjuredCount
# 0                  NaN                     4.0                      NaN
# 1                  3.0                     4.0                      NaN
# 2                  3.0                     4.0                      NaN
# 3                  3.0                     4.0                      NaN
# 4                  3.0                     4.0                      NaN
# ...                ...                     ...                      ...
# 28424              5.0                     4.0                      4.0
# 28425              4.0                     5.0                      5.0
# 28426              4.0                     5.0                      5.0
# 28427              4.0                     5.0                      5.0
# 28428              4.0                     5.0                      5.0
#
# [28429 rows x 80 columns]

# %%
new_df_2.columns

# %%
new_df_2.columns

# %%
new_df_2.groupby('Starters')['FantasyPoints'].mean().reset_index().sort_values('FantasyPoints', ascending=False).head(10)

# %%
new_df_2.sort_values('FantasyPoints', ascending = False)

# %%
existing_dataframe = pd.read_csv("../data/full_nba_data.csv")
existing_dataframe

# %%
all_games = all_games_season(2025)
all_games

# %%
all_games.to_csv('../data/nba_game_list.csv')
